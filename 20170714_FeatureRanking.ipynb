# %%
from os import listdir
from os.path import isfile, join

filepath = '.'

file_list = [f for f in listdir(filepath) if isfile(join(filepath, f))]
print(file_list)
# Out:
# ['FeatureRanking.ipynb', 'mutualdescriptive.zip', 'mutual_descriptive_ranking_choriod.txt', 'mutual_descriptive_ranking_homogenous.txt', 'mutual_descriptive_ranking_matching_pnt_homogenous_differece.txt', 'mutual_descriptive_ranking_match_points.txt', 'mutual_descriptive_ranking_retina.txt']

# %%
listdir(filepath)
# Out:
# ['.ipynb_checkpoints',
#  'FeatureRanking.ipynb',
#  'mutualdescriptive.zip',
#  'mutual_descriptive_ranking_choriod.txt',
#  'mutual_descriptive_ranking_homogenous.txt',
#  'mutual_descriptive_ranking_matching_pnt_homogenous_differece.txt',
#  'mutual_descriptive_ranking_match_points.txt',
#  'mutual_descriptive_ranking_retina.txt']

# %%
import pandas as pd
from os import listdir
from os.path import isfile, join

def get_key(filename):
    if 'difference' in filename:
        return 'Descriptiveness difference'
    elif 'choriod' in filename:
        return 'Choriod'
    elif 'retina' in filename:
        return 'Retina'
    elif 'homogenous' in filename:
        return 'Homogenous'
    elif 'match' in filename:
        return 'Match points'

def read_data_frames(file_path):
    file_list = [f for f in listdir(filepath) if isfile(join(filepath, f))]
    data_frames = dict()
    for f in file_list:
        file_parts = f.split('.')
        if file_parts[1] == 'txt':
            data = pd.read_csv(f);
            key = get_key(f)
            if f not in data_frames.keys(): data_frames[key] = data
    return data_frames

def merging_multilevel_dataframes(data_frames):
    multi_level_values = []
    for key, values in data_frames.items():
        values.columns = pd.MultiIndex.from_product([[key], values.columns])
        multi_level_values.append(values)
    return pd.concat(multi_level_values, axis = 1)

#data_frames[0].columns = pd.MultiIndex.from_product([['Homogenous'], data_frames[0].columns])
#data_frames[1].columns = pd.MultiIndex.from_product([['Retina'], data_frames[1].columns])
#merged_data = pd.concat([data_frames[0], data_frames[1]], axis = 1)
#print('{} {}'.format(merged_data, type(data_frames[0])))

filepath = '.'
data_frames = read_data_frames(filepath)
multi_level_data_frame = merging_multilevel_dataframes(data_frames)

multi_level_data_frame
# Out:
#     Choriod                   Homogenous                    \
#     Denoise Feature        MD    Denoise Feature        MD
# 0      None    AG18  0.484739       None     AG3  0.545378
# 1      None     AG9  0.483562       None     AG9  0.545190
# 2      None    AG12  0.483485       None     AG6  0.545189
# 3      None    AG15  0.483186       None    AG12  0.544923
# 4      None     AG6  0.482708       None    AG15  0.544803
# 5      None     AG3  0.482638       None    AG18  0.544373
# 6      None    AG17  0.474075       None     AG5  0.530310
# 7      None    AG11  0.473997       None     AG2  0.530273
# 8      None     AG8  0.473506       None    AG11  0.530216
# 9      None     AG5  0.472211       None     AG8  0.530166
# 10     None     AG2  0.471663       None    AG14  0.528057
# 11     None    AG14  0.470774       None    AG17  0.527653
# 12     None     RL9  0.465523       FNLM    COC5  0.485836
# 13     BM3D    AG18  0.445415       BM3D    COC5  0.473525
# 14     BM3D     AG9  0.443268       BM3D     AG3  0.467183
# 1                         FNLM   MIND9  0.352512         BM3D     RL9
# 2                         None   MIND9  0.285214         FNLM     RL9
# 3                         BM3D  MIND10  0.259629         None    AG11
# 4                         BM3D   MIND5  0.255502         None     AG8
# 5                         BM3D   MIND3  0.254044         None    AG17
# 6                         BM3D  MIND11  0.247209         None     AG5
# 7                         FNLM  MIND10  0.245487         FNLM     RL5
# 8                         FNLM   MIND5  0.243511         None     RL9
# 9                         FNLM   MIND3  0.241043         None     AG2
# 10                        FNLM  MIND11  0.228027         BM3D     AG8
# 11                        FNLM    COC1  0.224164         BM3D    AG11
# 12                        None  MIND10  0.214271         None    AG14
# 13                        BM3D    COC1  0.210546         BM3D     RL7
# 14                        None  MIND11  0.209418         BM3D     AG5
# 15                        None   MIND5  0.207285         BM3D     AG2
# 16                        None   MIND3  0.204686         BM3D    AG17
# 17                        FNLM     RL9  0.199887         None    AG12
# 18                        FNLM    COC6  0.199823         None     AG9
# 19                        BM3D     RL9  0.195645         None    AG18
# 20                        BM3D    COC3  0.180710         None     AG6
# 21                        FNLM     RL7  0.178553         BM3D    AG12
# 22                        FNLM    COC3  0.174936         BM3D    AG14
# 23                        None    COC1  0.158526         None     AG3
# 24                        BM3D   MIND2  0.158521         BM3D     AG9
# 25                        BM3D   MIND8  0.158299         None    AG15
# 26                        BM3D   MIND6  0.156162         FNLM     AG8
# 27                        None    COC3  0.153789         BM3D     RL5
# 28                        BM3D   MIND4  0.152677         FNLM    AG11
# 29                        FNLM     RL5  0.146263         BM3D     AG6
# ..                         ...     ...       ...          ...     ...
# 138                       FNLM     RL8 -0.019149         BM3D  MIND12
# 139                       BM3D     RL6 -0.021010         BM3D   MIND4
# 140                       None    AG12 -0.023888         FNLM    COC4
# 141                       FNLM     AG4 -0.024149         FNLM  MIND12
# 142                       FNLM     AG1 -0.024717         None    COC4
# 143                       None     AG9 -0.025125         FNLM   MIND2
# 144                       None    AG18 -0.025558         FNLM   MIND8
# 145                       None    AG10 -0.026118         BM3D    COC4
# 146                       None    AG16 -0.026712         FNLM   MIND6
# 147                       None     AG6 -0.027515         FNLM   MIND4
# 148                       None     AG7 -0.028117         None  MIND12
# 149                       None     AG3 -0.029846         None   MIND8
# 150                       None    AG15 -0.030537         None   MIND6
# 151                       FNLM    AG13 -0.031227         None   MIND2
# 152                       None    COC5 -0.031593         None   MIND4
# 153                       FNLM    RL10 -0.032210         BM3D  MIND14
# 154                       BM3D    RL10 -0.037304         BM3D  MIND13
# 155                       None    COC2 -0.044569         FNLM  MIND14
# 156                       BM3D     RL8 -0.046668         None    RL10
# 157                       FNLM    COC2 -0.049038         FNLM  MIND13
# 158                       None     RL2 -0.056835         None  MIND14
# 159                       None     AG1 -0.063654         None  MIND13
# 160                       None     AG4 -0.064613         FNLM   MIND1
# 161                       None    AG13 -0.069457         None   MIND1
# 162                       BM3D    COC2 -0.078836         FNLM   MIND7
# 163                       None     RL6 -0.085803         BM3D   MIND1
# 164                       None    RL10 -0.100810         None   MIND7
# 165                       None     RL8 -0.118522         BM3D   MIND7
# 166                       FNLM    COC5 -0.149506         BM3D    RL10
# 167                       BM3D    COC5 -0.165782         FNLM    RL10
#
#                Retina
#            MD Denoise Feature        MD
# 0    0.559006    None    AG11  0.521057
# 1    0.552657    None     AG5  0.520803
# 2    0.550896    None     AG2  0.520457
# 3    0.538789    None     AG8  0.520449
# 4    0.538673    None    AG17  0.519919
# 5    0.533676    None    AG14  0.519251
# 6    0.532883    None    AG18  0.511842
# 7    0.532614    None     AG9  0.511681
# 8    0.532424    None    AG12  0.511549
# 9    0.531487    None     AG3  0.511204
# 10   0.530137    None     AG6  0.511061
# 11   0.529487    None    AG15  0.510701
# 12   0.528928    FNLM     RL7  0.509713
# 13   0.525720    BM3D    AG11  0.497237
# 14   0.523464    BM3D     AG5  0.497129
# 15   0.521963    BM3D     AG2  0.496479
# 16   0.521711    BM3D    AG17  0.496438
# 17   0.521035    BM3D     AG8  0.496379
# 18   0.520065    BM3D    AG14  0.495905
# 19   0.518816    BM3D     AG9  0.489006
# 20   0.517674    BM3D    AG18  0.488957
# 21   0.516393    BM3D    AG12  0.488783
# 22   0.515805    BM3D     AG3  0.488522
# 23   0.515532    BM3D     AG6  0.488349
# 24   0.514439    BM3D    AG15  0.487876
# 25   0.514265    FNLM     AG5  0.475895
# 26   0.513389    FNLM    AG11  0.475590
# 27   0.513377    FNLM    AG14  0.475068
# 28   0.513308    FNLM     AG2  0.474874
# 29   0.511591    FNLM    AG17  0.474814
# ..        ...     ...     ...       ...
# 138  0.158518    BM3D    COC4  0.111629
# 139  0.156888    FNLM  MIND12  0.110727
# 140  0.155942    None  MIND12  0.100749
# 141  0.153423    FNLM    COC4  0.100639
# 142  0.146367    BM3D   MIND8  0.100190
# 143  0.145810    BM3D   MIND6  0.099376
# 144  0.145419    BM3D   MIND4  0.096742
# 145  0.144687    BM3D   MIND2  0.094785
# 146  0.143821    BM3D  MIND14  0.085244
# 147  0.142320    FNLM   MIND8  0.083709
# 148  0.137823    BM3D  MIND13  0.083324
# 149  0.129201    FNLM  MIND14  0.081279
# 150  0.127157    FNLM   MIND6  0.080864
# 151  0.123688    FNLM  MIND13  0.079456
# 152  0.118960    FNLM   MIND4  0.079084
# 153  0.115498    None   MIND8  0.078719
# 154  0.113833    FNLM   MIND2  0.078097
# 155  0.110548    None   MIND6  0.077708
# 156  0.110301    None   MIND4  0.076346
# 157  0.110287    None   MIND2  0.074760
# 158  0.096922    None  MIND14  0.070649
# 159  0.094356    None  MIND13  0.068586
# 160  0.052540    None   MIND1  0.038877
# 161  0.048590    FNLM   MIND1  0.037466
# 162  0.047404    BM3D   MIND1  0.035925
# 163  0.045572    None   MIND7  0.035734
# 164  0.042676    FNLM   MIND7  0.035125
# 165  0.039102    BM3D   MIND7  0.033304
# 166  0.000000    BM3D    RL10  0.000000
# 167  0.000000    FNLM    RL10  0.000000
#
# [168 rows x 15 columns]
