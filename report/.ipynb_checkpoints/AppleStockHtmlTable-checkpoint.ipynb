# %%
import plotly as py
import pandas as pd
import numpy as np
import pprint

from datetime import datetime
from datetime import time as dt_tm
from datetime import date as dt_date

import plotly.plotly as py
import plotly.tools as plotly_tools
from plotly.graph_objs import *

import os
import tempfile
os.environ['MPLCONFIGDIR'] = tempfile.mkdtemp()
#from matplotlib.finance import quotes_historical_yahoo
import matplotlib.pyplot as plt

from scipy.stats import gaussian_kde

from IPython.display import HTML

# %%
pd.set_option('display.max_colwidth', -1)
df = pd.read_csv('AAPL_temp.csv', header =0)
df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2018-05-07  185.179993  187.669998  184.750000  185.160004  184.448746
# 1   2018-05-08  184.990005  186.220001  183.669998  186.050003  185.335327
# 2   2018-05-09  186.550003  187.399994  185.220001  187.360001  186.640305
# 3   2018-05-10  187.740005  190.369995  187.649994  190.039993  189.309998
# 4   2018-05-11  189.490005  190.059998  187.449997  188.589996  188.589996
# 5   2018-05-14  189.009995  189.529999  187.860001  188.149994  188.149994
# 6   2018-05-15  186.779999  187.070007  185.100006  186.440002  186.440002
# 7   2018-05-16  186.070007  188.460007  186.000000  188.179993  188.179993
# 8   2018-05-17  188.000000  188.910004  186.360001  186.990005  186.990005
# 9   2018-05-18  187.190002  187.809998  186.130005  186.309998  186.309998
# 10  2018-05-21  188.000000  189.270004  186.910004  187.630005  187.630005
# 11  2018-05-22  188.380005  188.880005  186.779999  187.160004  187.160004
# 12  2018-05-23  186.350006  188.500000  185.759995  188.360001  188.360001
# 13  2018-05-24  188.770004  188.839996  186.210007  188.149994  188.149994
# 14  2018-05-25  188.229996  189.649994  187.649994  188.580002  188.580002
# 15  2018-05-29  187.600006  188.750000  186.869995  187.899994  187.899994
# 16  2018-05-30  187.720001  188.000000  186.779999  187.500000  187.500000
# 17  2018-05-31  187.220001  188.229996  186.139999  186.869995  186.869995
# 18  2018-06-01  187.990005  190.259995  187.750000  190.240005  190.240005
# 19  2018-06-04  191.639999  193.419998  191.350006  191.830002  191.830002
# 20  2018-06-05  193.070007  193.940002  192.360001  193.309998  193.309998
# 21  2018-06-06  193.630005  194.080002  191.919998  193.979996  193.979996
# 22  2018-06-07  194.139999  194.199997  192.335007  193.410004  193.410004
#
#       Volume  \
# 0   42451400
# 1   28402800
# 2   23211200
# 3   27989300
# 4   26212200
# 5   20778800
# 6   23695200
# 7   19183100
# 8   17294000
# 9   18297700
# 10  18400800
# 11  15240700
# 12  19467900
# 13  20401000
# 14  17461000
# 15  22369000
# 16  18690500
# 17  27482800
# 18  23250400
# 19  26132000
# 20  21566000
# 21  20835900
# 22  15998359
#
#                                                                 Images
# 0   backup_diagram_v_pi.png
# 1   C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 2   C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 3   C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 4   C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 5   C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 6   C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 7   C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 8   C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 9   C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 10  C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 11  C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 12  C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 13  C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 14  C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 15  C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 16  C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 17  C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 18  C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 19  C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 20  C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 21  C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png
# 22  C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png

# %%
folder = 'C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png'
img_str = '<img src=\"'+folder+'\" alt=\"\" border=3 height=100 width=100></img>'
print(img_str)
'<img src=\"%s\" alt=\"\" border=3 height=100 width=100></img>' % folder
# Out:
# <img src="C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png" alt="" border=3 height=100 width=100></img>
# '<img src="C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png" alt="" border=3 height=100 width=100></img>'

# %%
df['Images'] = df['Images'].apply(lambda x: '<img src=\"%s\" alt=\"\" border=3 height=100 width=100></img>' % x)
df['Images'][0]
# Out:
# '<img src="backup_diagram_v_pi.png" alt="" border=3 height=100 width=100></img>'

# %% [markdown]
# <img src="backup_diagram_v_pi.png" alt="" border=3 height=100 width=100></img>

# %%
df.to_html(notebook=False, escape=False)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Date</th>\n      <th>Open</th>\n      <th>High</th>\n      <th>Low</th>\n      <th>Close</th>\n      <th>Adj Close</th>\n      <th>Volume</th>\n      <th>Images</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>2018-05-07</td>\n      <td>185.179993</td>\n      <td>187.669998</td>\n      <td>184.750000</td>\n      <td>185.160004</td>\n      <td>184.448746</td>\n      <td>42451400</td>\n      <td><img src="backup_diagram_v_pi.png" alt="" border=3 height=100 width=100></img></td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>
td>\n'
#  '      <td><img '
#  'src="C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png" '
#  'alt="" border=3 height=100 width=100></img></td>\n'
#  '    </tr>\n'
#  '    <tr>\n'
#  '      <th>15</th>\n'
#  '      <td>2018-05-29</td>\n'
#  '      <td>187.600006</td>\n'
#  '      <td>188.750000</td>\n'
#  '      <td>186.869995</td>\n'
#  '      <td>187.899994</td>\n'
#  '      <td>187.899994</td>\n'
#  '      <td>22369000</td>\n'
#  '      <td><img '
#  'src="C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png" '
#  'alt="" border=3 height=100 width=100></img></td>\n'
#  '    </tr>\n'
#  '    <tr>\n'
#  '      <th>16</th>\n'
#  '      <td>2018-05-30</td>\n'
#  '      <td>187.720001</td>\n'
#  '      <td>188.000000</td>\n'
#  '      <td>186.779999</td>\n'
#  '      <td>187.500000</td>\n'
#  '      <td>187.500000</td>\n'
#  '      <td>18690500</td>\n'
#  '      <td><img '
#  'src="C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png" '
#  'alt="" border=3 height=100 width=100></img></td>\n'
#  '    </tr>\n'
#  '    <tr>\n'
#  '      <th>17</th>\n'
#  '      <td>2018-05-31</td>\n'
#  '      <td>187.220001</td>\n'
#  '      <td>188.229996</td>\n'
#  '      <td>186.139999</td>\n'
#  '      <td>186.869995</td>\n'
#  '      <td>186.869995</td>\n'
#  '      <td>27482800</td>\n'
#  '      <td><img '
#  'src="C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png" '
#  'alt="" border=3 height=100 width=100></img></td>\n'
#  '    </tr>\n'
#  '    <tr>\n'
#  '      <th>18</th>\n'
#  '      <td>2018-06-01</td>\n'
#  '      <td>187.990005</td>\n'
#  '      <td>190.259995</td>\n'
#  '      <td>187.750000</td>\n'
#  '      <td>190.240005</td>\n'
#  '      <td>190.240005</td>\n'
#  '      <td>23250400</td>\n'
#  '      <td><img '
#  'src="C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png" '
#  'alt="" border=3 height=100 width=100></img></td>\n'
#  '    </tr>\n'
#  '    <tr>\n'
#  '      <th>19</th>\n'
#  '      <td>2018-06-04</td>\n'
#  '      <td>191.639999</td>\n'
#  '      <td>193.419998</td>\n'
#  '      <td>191.350006</td>\n'
#  '      <td>191.830002</td>\n'
#  '      <td>191.830002</td>\n'
#  '      <td>26132000</td>\n'
#  '      <td><img '
#  'src="C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png" '
#  'alt="" border=3 height=100 width=100></img></td>\n'
#  '    </tr>\n'
#  '    <tr>\n'
#  '      <th>20</th>\n'
#  '      <td>2018-06-05</td>\n'
#  '      <td>193.070007</td>\n'
#  '      <td>193.940002</td>\n'
#  '      <td>192.360001</td>\n'
#  '      <td>193.309998</td>\n'
#  '      <td>193.309998</td>\n'
#  '      <td>21566000</td>\n'
#  '      <td><img '
#  'src="C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png" '
#  'alt="" border=3 height=100 width=100></img></td>\n'
#  '    </tr>\n'
#  '    <tr>\n'
#  '      <th>21</th>\n'
#  '      <td>2018-06-06</td>\n'
#  '      <td>193.630005</td>\n'
#  '      <td>194.080002</td>\n'
#  '      <td>191.919998</td>\n'
#  '      <td>193.979996</td>\n'
#  '      <td>193.979996</td>\n'
#  '      <td>20835900</td>\n'
#  '      <td><img '
#  'src="C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png" '
#  'alt="" border=3 height=100 width=100></img></td>\n'
#  '    </tr>\n'
#  '    <tr>\n'
#  '      <th>22</th>\n'
#  '      <td>2018-06-07</td>\n'
#  '      <td>194.139999</td>\n'
#  '      <td>194.199997</td>\n'
#  '      <td>192.335007</td>\n'
#  '      <td>193.410004</td>\n'
#  '      <td>193.410004</td>\n'
#  '      <td>15998359</td>\n'
#  '      <td><img '
#  'src="C:/D/dev/PyNotebook/reinforcement-learning/backup_diagram_v_pi.png" '
#  'alt="" border=3 height=100 width=100></img></td>\n'
#  '    </tr>\n'
#  '  </tbody>\n'
#  '</table>')

# %%
#table1 = df.describe()
#pprint.pprint(table1.to_html())
# table1 = df.describe()
# table2 = table1.to_html().replace('<table border="1" class="dataframe">','<table class="table table-striped">')

# %%
table2 = df.to_html(notebook=False, escape=False, max_rows=1000, max_cols=1000).replace('<table border="1" class="dataframe">','<table class="table table-striped">')
table3 = '''<table class="table table-striped">
<th>Ticker</th><th>Full name</th>
<tr>
    <td>AAPL</td>
    <td><a href="http://finance.yahoo.com/q?s=AAPL">Apple Inc</a></td>
</tr>
<tr>
    <td>GE</img></td>
    <td><a href="http://finance.yahoo.com/q?s=GE">General Electric Company</a></td>
</tr>
<tr>
    <td>IBM</td>
    <td><a href="http://finance.yahoo.com/q?s=IBM">International Business Machines Corp.</a></td>
</tr>
<tr>
    <td>KO</td>
    <td><a href="http://finance.yahoo.com/q?s=KO">The Coca-Cola Company</a></td>
</tr>
<tr>
    <td>MSFT</td>
    <td><a href="http://finance.yahoo.com/q?s=MSFT">Microsoft Corporation</a></td>
</tr>
<tr>
    <td>PEP</td>
    <td><a href="http://finance.yahoo.com/q?s=PEP">Pepsico, Inc.</a></td>
</tr>
</table>
'''
HTML(table3)
# Out:
# <table class="table table-striped">
# <th>Ticker</th><th>Full name</th>
# <tr>
#     <td>AAPL</td>
#     <td><a href="http://finance.yahoo.com/q?s=AAPL">Apple Inc</a></td>
# </tr>
# <tr>
#     <td>GE</img></td>
#     <td><a href="http://finance.yahoo.com/q?s=GE">General Electric Company</a></td>
# </tr>
# <tr>
#     <td>IBM</td>
#     <td><a href="http://finance.yahoo.com/q?s=IBM">International Business Machines Corp.</a></td>
# </tr>
# <tr>
#     <td>KO</td>
#     <td><a href="http://finance.yahoo.com/q?s=KO">The Coca-Cola Company</a></td>
# </tr>
# <tr>
#     <td>MSFT</td>
#     <td><a href="http://finance.yahoo.com/q?s=MSFT">Microsoft Corporation</a></td>
# </tr>
# <tr>
#     <td>PEP</td>
#     <td><a href="http://finance.yahoo.com/q?s=PEP">Pepsico, Inc.</a></td>
# </tr>
# </table>

# %%
first_plot_url = 'https://entropymag.org/wp-content/uploads/2015/01/Screen-Shot-2015-01-25-at-7.23.56-PM.png'
second_plot_url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Normal_Distribution_PDF.svg/360px-Normal_Distribution_PDF.svg.png'

html_string = '''
<html>
    <head>
        <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.1/css/bootstrap.min.css">
        <style>body{ margin:0 100; background:whitesmoke; }</style>
    </head>
    <body>
        <h1>2014 technology and CPG stock prices</h1>

        <!-- *** Section 1 *** --->
        <h2>Section 1: Apple Inc. (AAPL) stock in 2014</h2>
        <iframe width="1000" height="550" frameborder="0" seamless="seamless" scrolling="no" \
src="''' + first_plot_url + '''.embed?width=800&height=550"></iframe>
        <p>Apple stock price rose steadily through 2014.</p>
        
        <!-- *** Section 2 *** --->
        <h2>Section 2: AAPL compared to other 2014 stocks</h2>
        <iframe width="1000" height="1000" frameborder="0" seamless="seamless" scrolling="no" \
src="''' + second_plot_url + '''.embed?width=1000&height=1000"></iframe>
        <p>GE had the most predictable stock price in 2014. IBM had the highest mean stock price. \
The red lines are kernel density estimations of each stock price - the peak of each red lines \
corresponds to its mean stock price for 2014 on the x axis.</p>
        <h3>Reference table: stock tickers</h3>
        ''' + table3 + '''
        <h3>Summary table: 2014 stock statistics</h3>
        ''' + table2 + '''
    </body>
</html>'''

# %%
f = open('report.html','w')
f.write(html_string)
f.close()

# %%
# def as_escaped_unicode(thing, escape_chars=escape_chars):
#     # Unicode is fine, else we try to decode using utf-8 and 'replace'
#     # if that's not it either, we have no way of knowing and the user
#     # should deal with it himself.

#     try:
#         result = compat.text_type(thing)  # we should try this first
#     except UnicodeDecodeError:
#         # either utf-8 or we replace errors
#         result = str(thing).decode('utf-8', "replace")

#     translate = {'\t': r'\t', '\n': r'\n', '\r': r'\r', }
#     if isinstance(escape_chars, dict):
#         if default_escapes:
#             translate.update(escape_chars)
#         else:
#             translate = escape_chars
#         escape_chars = list(escape_chars.keys())
#     else:
#         escape_chars = escape_chars or tuple()
#     for c in escape_chars:
#         result = result.replace(c, translate[c])

#     return compat.text_type(result)

# as_escaped_unicode('pow', escape_chars=escape_chars)
