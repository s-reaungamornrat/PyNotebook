# %%
import os
import csv
import heapq
import numpy as np

# %%
class Node:
    
    def __init__(self, parent = None, color= None, index = -1, degree = -1):
        
        self.color = color
        self.index = index
        self.degree = degree
        self.parent = parent
        self.child_indices = []
        self.depth = 0
        if parent:
            self.depth = parent.depth+1    
            
    def __repr__(self):
        """Use by calling repr(node)"""
        return "Node(c: " + repr(self.color) + ", idx: " + repr(self.index) + ", deg: " + repr(self.degree) + ")"    
    
    def expand(self, index):
        if index in self.child_indices:
            #print('Index already exists in the children list')
            return False
        else:
            self.child_indices.append(index)
            #print('Node %d: add child index %d' % (self.index, index))
            return True
            
    def set_color(self, color):
        self.color = color
        
    def __lt__(self, other):
        return self.degree > other.degree
    
class Graph:# undirected
    
    def __init__(self, edges=None, root=None):
        self.edges = None
        self.root = None
        self.vertices = dict()#[]# index to the list denotes the vertex index
        #self.vertex_info = []# heapq collecting index and degree
        
    def add_vertex(self, index, child):
        #print('In add_vertex, ', self.vertices ) 
        if index in self.vertices: #index < len(self.vertices):
            self.vertices[index].degree += 1
            #self.vertex_info[index].degree +=1
            #print('In add_vertex, Add degree to vertex %d' % index)
            #print('Index %d, Vertex degree %d' % (index, self.vertices[index].degree))
        else:
            parent, color, degree = None, None, 1
            self.vertices[index] = Node(parent, color, index, degree)
            #self.vertex_info.append(NodeInfo(index, degree))
            #print('Index {}, Node {}'.format(index, self.vertices[index]))
            #print('In add_vertex, Add new vertex %d' % index)
        self.vertices[index].expand(child)
        
        #print('Vertices \n', self.vertices)
        #heapq.heapify(self.vertices)
        #print('Vertex Info\n', self.vertex_info)        
            
    def set_edges(self,edges):
        self.edges = edges
        for edge in edges:
            # build a list of vertices
            self.add_vertex(edge[0], edge[1])
            self.add_vertex(edge[1], edge[0])
            
        #print('Vertices \n', self.vertices)
        #heapq.heapify(self.vertices)
        #print('Vertex Info\n', self.vertex_info)
        
    def print_graph(self):
        for index, vertex in self.vertices.items():
            rep = "Index " + str(index) + ", Node(c: " + str(vertex.color) + ", idx: " + str(vertex.index) + ", deg: " + str(vertex.degree)
            if vertex.child_indices:
                rep = rep + ", children: "+','.join([ str(child) for child in vertex.child_indices]) + ' )'
            print(rep)

# %%
# child have different color than parent
def print_graph(vertices):
    
    for index, vertex in vertices.items():
        rep = "Index " + str(index) + ", Node(c: " + str(vertex.color) + ", idx: " + str(vertex.index) + ", deg: " + str(vertex.degree)
        if vertex.child_indices:
            rep = rep + ", children: "+','.join([ str(child) for child in vertex.child_indices]) + ' )'
        print(rep)

def get_color(colors, lower_bound=None, upper_bound=None):
    
    color = None
    if not colors: color = 0
    else: color = max(colors)+1
    
    #if color <= lower_bound or color > upper_bound:
    if upper_bound and color > upper_bound:
        raise ValueError('Color is below the lower bound or over the upper bound')
        
    return color

def get_usable_color(index, vertices, colors):
    
    child_colors = set([vertices[cidx].color for cidx in vertices[index].child_indices if vertices[cidx].color != None])
    color, usable_colors = None, None
    
    return colors.difference(child_colors)

def update_color_frequency(color, color_frequency):
    if color in color_frequency: color_frequency[color] += 1
    else: color_frequency[color] = 0

def child_node_checking(cindex, pindex, colors, vertices,color_frequency):
    """
        cindex is child index and 
        pindex is parent index
        if child degree > parent degree and if 
        there is only 1 existing color usable for the child node, set that color to child node
    """
    
    if vertices[cindex].color != None: 
        #print('Vertex %d already explored' % index)
        return False
    if vertices[cindex].degree < vertices[pindex].degree:
        return False
    

    usable_colors = get_usable_color(cindex, vertices, colors)
    if len(usable_colors) != 1:  
        return False
    
    print('In child_node_checking, vertex {}, color {}'.format(cindex, vertices[cindex].color))
    #print('-------------------------Use old color for child node')
    color = usable_colors.pop() 
        
    vertices[cindex].color = color
    colors.add(color)    
    
    update_color_frequency(color, color_frequency)
#     if color in color_frequency: color_frequency[color] += 1
#     else: color_frequency[color] = 0
    print('In child_node_checking, parent vertex %d with degree %d, child vertex %d with degree %d set to color %d' %
          (pindex, vertices[pindex].degree, cindex, vertices[cindex].degree, color))
    
    return True       
        
def node_coloring(index, colors, vertices, lower_bound, upper_bound, color_frequency):
    
    print('In node_coloring, vertex {}, color {}'.format(index, vertices[index].color))
    if vertices[index].color != None: 
        #print('Vertex %d already explored' % index)
        return False
        
#     child_colors = set([vertices[cidx].color for cidx in vertices[index].child_indices if vertices[cidx].color != None])
#     color, usable_colors = None, None
    
#     usable_colors = colors.difference(child_colors)
    usable_colors = get_usable_color(index, vertices, colors)
    
    #print('\nIn vertex {}, Num children {}'.format(index, len(vertices[index].child_indices)))
    #print('Colors {}, Child colors {}, Usable color {}'.format(colors,child_colors,usable_colors))
        
    if len(usable_colors) > 1:    
        print('-------------------------More than 1 color is available to use')
        return False
#     elif not colors:
#         print('-------------------------Get new color')
#         color = get_color(colors, lower_bound, upper_bound)
    elif not usable_colors:
        return False
    else:
        print('-------------------------Use old color')
        color = usable_colors.pop() 
        
    vertices[index].color = color
    colors.add(color)    
    
    update_color_frequency(color, color_frequency)
#     if color in color_frequency: color_frequency[color] += 1
#     else: color_frequency[color] = 0
    print('In node_coloring, vertex %d with degree %d set to color %d' % (index, vertices[index].degree, color))
    
    return True

def graph_coloring_probe(colors, vertices, color_frequency, explored):
    
    vertex_info = []
    for idx, v in vertices.items():
        heapq.heappush(vertex_info, (-v.degree, v.index))
        #vertex_info.append((-v.degree, v.index))
        
    lower_bound, upper_bound = -vertex_info[0][0], len(vertex_info)
    #print('Lower c bound %d, higher bound %d ' % (lower_bound, upper_bound))
    
    print('In graph_coloring_probe, info:{}'.format(vertex_info))
    while vertex_info:

        vinfo = heapq.heappop(vertex_info)
        #print('\n\n New vertex %d with degree %d' % (vinfo[1], -vinfo[0]))
        print('In graph_coloring_probe, pop:{}, info:{}'.format(vinfo, vertex_info))
        
        index = vinfo[1]
        if index in explored: continue
            
        flag = node_coloring(index, colors, vertices, lower_bound, upper_bound, color_frequency)
        if flag: explored.add(index)
            
        for cidx in vertices[index].child_indices:
            # if there is a child with higher degree and can only have 1 value to assigned
            flag = child_node_checking(cidx, index, colors, vertices,color_frequency)
            if flag: explored.add(cidx)
            #flag = node_coloring(cidx, colors, vertices, lower_bound, upper_bound, color_frequency)
            #if flag: explored.add(cidx)
                
        #print('Explored node indices ', explored)
        #print('Used colors ', colors)
        #print_graph(vertices)    
    
def graph_coloring(vertices):
    
    explored = set()
    colors = set()
    color_frequency = dict()
    #heapq.heapify(vertex_info)
    vertex_info = []
    for idx, v in vertices.items():
        heapq.heappush(vertex_info, (-v.degree, v.index))
        #vertex_info.append((-v.degree, v.index))
        
    selected_colors = [v.color for i, v in vertices.items()]
    while not all(selected_colors) and vertex_info:
        vinfo = heapq.heappop(vertex_info)
        print('In graph_coloring, pop:{}, info:{}'.format(vinfo, vertex_info))
        index = vinfo[1]
        if vertices[index].color != None:
            continue
        else:
            color = get_color(colors)
            vertices[index].color = color
            print('In graph_coloring, index {} with degree {} set color {}'.format(index, vertices[index].degree, vertices[index].color))
            colors.add(color) 
            explored.add(index)
            update_color_frequency(color, color_frequency)
            graph_coloring_probe(colors, vertices, color_frequency, explored)
        selected_colors = [v.color for i, v in vertices.items()]
    #print('Original vertices\n', vertices)
    #print('Sorted vertex info\n', vertex_info)
    
    #selected_colors = [vertices[i].color for i in range(len(vertices))]
    return len(colors), [vertices[i].color for i in range(len(vertices))]#, vertices, color_frequency

# %%
def solve_it(input_data):
    # Modify this code to run your optimization algorithm

    # parse the input
    lines = input_data.split('\n')

    first_line = lines[0].split()
    node_count = int(first_line[0])
    edge_count = int(first_line[1])
    #print('Node count %d, edge count %d' % (node_count, edge_count))

    edges = []
    for i in range(1, edge_count + 1):
        line = lines[i]
        parts = line.split()
        edges.append((int(parts[0]), int(parts[1])))
        
    #### play with graph
    graph = Graph()
    graph.set_edges(edges)
    #graph.print_graph()
    print('---------------Start graph coloring ------------------')
    #num_colors, solution, vertices, color_frequency = graph_coloring(graph.vertices)
    num_colors, solution = graph_coloring(graph.vertices)
    #print('Vertices ', vertices)
    #vertex_colors = [(v.index, v.color) for k, v in vertices.items()]
    #print('Vertex color', [(v.index, v.color) for v in vertices])
    
    #######
    # build a trivial solution
    # every node has its own color

    # prepare the solution in the specified output format
    output_data = str(num_colors) + ' ' + str(0) + '\n'
    output_data += ' '.join(map(str, solution))

    return output_data#, vertex_colors, color_frequency

# %%
data_folder = 'C:/D/coursera/discrete_opt/coloring/data'
filename = os.path.join(data_folder,'gc_100_7')
with open(filename, 'r') as input_data_file:
    input_data = input_data_file.read()
    
output=solve_it(input_data)
#print('\n\nVertex colors\n', vertex_colors)
#print('\n\nColors frequence\n', color_frequency)
print('\n\n Output\n', output)
# Out:
# ---------------Start graph coloring ------------------
# In graph_coloring, pop:(-79, 74), info:[(-77, 24), (-77, 69), (-77, 47), (-75, 64), (-75, 80), (-76, 29), (-76, 56), (-74, 8), (-72, 35), (-73, 9), (-74, 89), (-74, 14), (-75, 54), (-75, 2), (-74, 62), (-71, 17), (-74, 32), (-71, 73), (-72, 76), (-73, 20), (-70, 19), (-72, 88), (-72, 92), (-74, 48), (-69, 23), (-69, 52), (-71, 25), (-68, 27), (-68, 57), (-69, 60), (-73, 0), (-70, 63), (-66, 15), (-70, 34), (-74, 70), (-69, 72), (-70, 71), (-70, 75), (-71, 78), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-71, 43), (-70, 45), (-68, 46), (-69, 96), (-69, 5), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-69, 53), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-67, 61), (-65, 3), (-68, 31), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-71, 68), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-68, 77), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10), (-67, 87), (-66, 21), (-68, 90), (-57, 91), (-66, 22), (-61, 93), (-68, 94), (-66, 95), (-68, 11), (-69, 97), (-61, 98)]
# In graph_coloring, index 74 with degree 79 set color 0
# In graph_coloring_probe, info:[(-79, 74), (-77, 24), (-77, 47), (-77, 69), (-75, 80), (-76, 29), (-76, 56), (-74, 8), (-75, 64), (-73, 9), (-74, 89), (-74, 14), (-75, 54), (-75, 2), (-74, 62), (-71, 17), (-74, 32), (-72, 35), (-72, 76), (-73, 20), (-70, 19), (-72, 88), (-72, 92), (-74, 48), (-69, 23), (-69, 52), (-71, 25), (-68, 27), (-68, 57), (-69, 60), (-73, 0), (-70, 63), (-66, 15), (-70, 34), (-74, 70), (-69, 72), (-71, 73), (-70, 75), (-71, 78), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-71, 43), (-70, 45), (-68, 46), (-69, 96), (-69, 5), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-69, 53), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-67, 61), (-65, 3), (-68, 31), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-71, 68), (-67, 7), (-68, 4), (-65, 36), (-70, 71), (-63, 18), (-67, 38), (-66, 37), (-68, 77), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10), (-67, 87), (-66, 21), (-68, 90), (-57, 91), (-66, 22), (-61, 93), (-68, 94), (-66, 95), (-68, 11), (-69, 97), (-61, 98), (-67, 99)]
# In graph_coloring_probe, pop:(-79, 74), info:[(-77, 24), (-77, 69), (-77, 47), (-75, 64), (-75, 80), (-76, 29), (-76, 56), (-74, 8), (-72, 35), (-73, 9), (-74, 89), (-74, 14), (-75, 54), (-75, 2), (-74, 62), (-71, 17), (-74, 32), (-71, 73), (-72, 76), (-73, 20), (-70, 19), (-72, 88), (-72, 92), (-74, 48), (-69, 23), (-69, 52), (-71, 25), (-68, 27), (-68, 57), (-69, 60), (-73, 0), (-70, 63), (-66, 15), (-70, 34), (-74, 70), (-69, 72), (-70, 71), (-70, 75), (-71, 78), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-71, 43), (-70, 45), (-68, 46), (-69, 96), (-69, 5), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-69, 53), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-67, 61), (-65, 3), (-68, 31), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-71, 68), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-68, 77), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10), (-67, 87), (-66, 21), (-68, 90), (-57, 91), (-66, 22), (-61, 93), (-68, 94), (-66, 95), (-68, 11), (-69, 97), (-61, 98)]
# In graph_coloring_probe, pop:(-77, 24), info:[(-77, 47), (-77, 69), (-76, 29), (-75, 64), (-75, 80), (-75, 54), (-76, 56), (-74, 8), (-72, 35), (-73, 9), (-74, 89), (-74, 14), (-71, 25), (-75, 2), (-74, 62), (-71, 17), (-74, 32), (-71, 73), (-72, 76), (-73, 20), (-70, 19), (-72, 88), (-72, 92), (-74, 48), (-69, 23), (-69, 52), (-69, 53), (-68, 27), (-68, 57), (-69, 60), (-73, 0), (-70, 63), (-66, 15), (-70, 34), (-74, 70), (-69, 72), (-70, 71), (-70, 75), (-71, 78), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-71, 43), (-70, 45), (-68, 46), (-69, 96), (-69, 5), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-67, 61), (-65, 3), (-68, 31), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-71, 68), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-68, 77), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10), (-67, 87), (-66, 21), (-68, 90), (-57, 91), (-66, 22), (-61, 93), (-68, 94), (-66, 95), (-68, 11), (-69, 97)]
# In node_coloring, vertex 24, color None
# In graph_coloring_probe, pop:(-77, 47), info:[(-77, 69), (-75, 64), (-76, 29), (-74, 8), (-75, 80), (-75, 54), (-76, 56), (-74, 32), (-72, 35), (-73, 9), (-74, 89), (-74, 14), (-71, 25), (-75, 2), (-74, 62), (-71, 17), (-74, 70), (-71, 73), (-72, 76), (-73, 20), (-70, 19), (-72, 88), (-72, 92), (-74, 48), (-69, 23), (-69, 52), (-69, 53), (-68, 27), (-68, 57), (-69, 60), (-73, 0), (-70, 63), (-66, 15), (-70, 34), (-71, 68), (-69, 72), (-70, 71), (-70, 75), (-71, 78), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-71, 43), (-70, 45), (-68, 46), (-69, 96), (-69, 5), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-67, 61), (-65, 3), (-68, 31), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-69, 97), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-68, 77), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10), (-67, 87), (-66, 21), (-68, 90), (-57, 91), (-66, 22), (-61, 93), (-68, 94), (-66, 95), (-68, 11)]
# In node_coloring, vertex 47, color None
# In graph_coloring_probe, pop:(-77, 69), info:[(-76, 29), (-75, 64), (-76, 56), (-74, 8), (-75, 80), (-75, 54), (-75, 2), (-74, 32), (-72, 35), (-73, 9), (-74, 89), (-74, 14), (-71, 25), (-68, 11), (-74, 62), (-71, 17), (-74, 70), (-71, 73), (-72, 76), (-73, 20), (-70, 19), (-72, 88), (-72, 92), (-74, 48), (-69, 23), (-69, 52), (-69, 53), (-68, 27), (-68, 57), (-69, 60), (-73, 0), (-70, 63), (-66, 15), (-70, 34), (-71, 68), (-69, 72), (-70, 71), (-70, 75), (-71, 78), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-71, 43), (-70, 45), (-68, 46), (-69, 96), (-69, 5), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-67, 61), (-65, 3), (-68, 31), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-69, 97), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-68, 77), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10), (-67, 87), (-66, 21), (-68, 90), (-57, 91), (-66, 22), (-61, 93), (-68, 94), (-66, 95)]
# In node_coloring, vertex 69, color None
# In graph_coloring_probe, pop:(-76, 29), info:[(-76, 56), (-75, 64), (-75, 2), (-74, 8), (-75, 80), (-75, 54), (-74, 62), (-74, 32), (-72, 35), (-73, 9), (-74, 89), (-74, 14), (-71, 25), (-68, 11), (-73, 0), (-71, 17), (-74, 70), (-71, 73), (-72, 76), (-73, 20), (-70, 19), (-72, 88), (-72, 92), (-74, 48), (-69, 23), (-69, 52), (-69, 53), (-68, 27), (-68, 57), (-69, 60), (-67, 61), (-70, 63), (-66, 15), (-70, 34), (-71, 68), (-69, 72), (-70, 71), (-70, 75), (-71, 78), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-71, 43), (-70, 45), (-68, 46), (-69, 96), (-69, 5), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-66, 95), (-65, 3), (-68, 31), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-69, 97), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-68, 77), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10), (-67, 87), (-66, 21), (-68, 90), (-57, 91), (-66, 22), (-61, 93), (-68, 94)]
# In node_coloring, vertex 29, color None
# In child_node_checking, vertex 56, color None
# In child_node_checking, parent vertex 29 with degree 76, child vertex 56 with degree 76 set to color 0
# In graph_coloring_probe, pop:(-76, 56), info:[(-75, 2), (-75, 64), (-75, 54), (-74, 8), (-75, 80), (-74, 14), (-74, 62), (-74, 32), (-72, 35), (-73, 9), (-74, 89), (-74, 48), (-71, 25), (-68, 11), (-73, 0), (-71, 17), (-74, 70), (-71, 73), (-72, 76), (-73, 20), (-70, 19), (-72, 88), (-72, 92), (-69, 5), (-69, 23), (-69, 52), (-69, 53), (-68, 27), (-68, 57), (-69, 60), (-67, 61), (-70, 63), (-66, 15), (-70, 34), (-71, 68), (-69, 72), (-70, 71), (-70, 75), (-71, 78), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-71, 43), (-70, 45), (-68, 46), (-69, 96), (-68, 94), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-66, 95), (-65, 3), (-68, 31), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-69, 97), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-68, 77), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10), (-67, 87), (-66, 21), (-68, 90), (-57, 91), (-66, 22), (-61, 93)]
# In graph_coloring_probe, pop:(-75, 2), info:[(-75, 54), (-75, 64), (-74, 14), (-74, 8), (-75, 80), (-74, 48), (-74, 62), (-74, 32), (-72, 35), (-73, 9), (-74, 89), (-69, 5), (-71, 25), (-68, 11), (-73, 0), (-71, 17), (-74, 70), (-71, 73), (-72, 76), (-73, 20), (-70, 19), (-72, 88), (-72, 92), (-69, 96), (-69, 23), (-69, 52), (-69, 53), (-68, 27), (-68, 57), (-69, 60), (-67, 61), (-70, 63), (-66, 15), (-70, 34), (-71, 68), (-69, 72), (-70, 71), (-70, 75), (-71, 78), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-71, 43), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-66, 95), (-65, 3), (-68, 31), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-69, 97), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-68, 77), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10), (-67, 87), (-66, 21), (-68, 90), (-57, 91), (-66, 22)]
# In node_coloring, vertex 2, color None
# In graph_coloring_probe, pop:(-75, 54), info:[(-75, 64), (-75, 80), (-74, 14), (-74, 8), (-74, 89), (-74, 48), (-74, 62), (-74, 32), (-72, 35), (-73, 9), (-72, 88), (-69, 5), (-71, 25), (-68, 11), (-73, 0), (-71, 17), (-74, 70), (-71, 73), (-72, 76), (-73, 20), (-70, 19), (-71, 43), (-72, 92), (-69, 96), (-69, 23), (-69, 52), (-69, 53), (-68, 27), (-68, 57), (-69, 60), (-67, 61), (-70, 63), (-66, 15), (-70, 34), (-71, 68), (-69, 72), (-70, 71), (-70, 75), (-71, 78), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-68, 90), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-66, 95), (-65, 3), (-68, 31), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-69, 97), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-68, 77), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10), (-67, 87), (-66, 21), (-66, 22), (-57, 91)]
# In node_coloring, vertex 54, color None
# In graph_coloring_probe, pop:(-75, 64), info:[(-75, 80), (-74, 8), (-74, 14), (-74, 32), (-74, 89), (-74, 48), (-74, 62), (-74, 70), (-72, 35), (-73, 9), (-72, 88), (-69, 5), (-71, 25), (-68, 11), (-73, 0), (-71, 17), (-71, 68), (-71, 73), (-72, 76), (-73, 20), (-70, 19), (-71, 43), (-72, 92), (-69, 96), (-69, 23), (-69, 52), (-69, 53), (-68, 27), (-68, 57), (-69, 60), (-67, 61), (-70, 63), (-66, 15), (-70, 34), (-69, 97), (-69, 72), (-70, 71), (-70, 75), (-71, 78), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-68, 90), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-66, 95), (-65, 3), (-68, 31), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-68, 77), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10), (-67, 87), (-66, 21), (-66, 22)]
# In node_coloring, vertex 64, color None
# In graph_coloring_probe, pop:(-75, 80), info:[(-74, 8), (-74, 32), (-74, 14), (-74, 70), (-74, 89), (-74, 48), (-74, 62), (-71, 17), (-72, 35), (-73, 9), (-72, 88), (-69, 5), (-71, 25), (-68, 11), (-73, 0), (-70, 63), (-71, 68), (-71, 73), (-72, 76), (-73, 20), (-70, 19), (-71, 43), (-72, 92), (-69, 96), (-69, 23), (-69, 52), (-69, 53), (-68, 27), (-68, 57), (-69, 60), (-67, 61), (-68, 31), (-66, 15), (-70, 34), (-69, 97), (-69, 72), (-70, 71), (-70, 75), (-71, 78), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-68, 90), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-68, 77), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10), (-67, 87), (-66, 21)]
# In node_coloring, vertex 80, color None
# In graph_coloring_probe, pop:(-74, 8), info:[(-74, 14), (-74, 32), (-74, 48), (-74, 70), (-74, 89), (-71, 25), (-74, 62), (-71, 17), (-72, 35), (-73, 9), (-72, 88), (-69, 5), (-69, 52), (-68, 11), (-73, 0), (-70, 63), (-71, 68), (-71, 73), (-72, 76), (-73, 20), (-70, 19), (-71, 43), (-72, 92), (-69, 96), (-69, 23), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-69, 60), (-67, 61), (-68, 31), (-66, 15), (-70, 34), (-69, 97), (-69, 72), (-70, 71), (-70, 75), (-71, 78), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-68, 90), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-68, 77), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10), (-67, 87)]
# In node_coloring, vertex 8, color None
# -------------------------Use old color
# In node_coloring, vertex 8 with degree 74 set to color 0
# In graph_coloring_probe, pop:(-74, 14), info:[(-74, 32), (-74, 70), (-74, 48), (-72, 35), (-74, 89), (-71, 25), (-74, 62), (-71, 17), (-72, 76), (-73, 9), (-72, 88), (-69, 5), (-69, 52), (-68, 11), (-73, 0), (-70, 63), (-71, 68), (-71, 73), (-71, 78), (-73, 20), (-70, 19), (-71, 43), (-72, 92), (-69, 96), (-69, 23), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-69, 60), (-67, 61), (-68, 31), (-66, 15), (-70, 34), (-69, 97), (-69, 72), (-70, 71), (-70, 75), (-68, 77), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-68, 90), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-67, 6), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-67, 87), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42), (-61, 10)]
# In node_coloring, vertex 14, color None
# In graph_coloring_probe, pop:(-74, 32), info:[(-74, 48), (-74, 70), (-74, 62), (-72, 35), (-74, 89), (-71, 25), (-73, 0), (-71, 17), (-72, 76), (-73, 9), (-72, 88), (-69, 5), (-69, 52), (-68, 11), (-69, 60), (-70, 63), (-71, 68), (-71, 73), (-71, 78), (-73, 20), (-70, 19), (-71, 43), (-72, 92), (-69, 96), (-69, 23), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-70, 34), (-69, 97), (-69, 72), (-70, 71), (-70, 75), (-68, 77), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-68, 90), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-67, 87), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85), (-68, 42)]
# In node_coloring, vertex 32, color None
# In graph_coloring_probe, pop:(-74, 48), info:[(-74, 62), (-74, 70), (-73, 0), (-72, 35), (-74, 89), (-71, 25), (-69, 60), (-71, 17), (-72, 76), (-73, 9), (-72, 88), (-69, 5), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (-71, 68), (-71, 73), (-71, 78), (-73, 20), (-70, 19), (-71, 43), (-72, 92), (-69, 96), (-69, 23), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-70, 34), (-69, 97), (-69, 72), (-70, 71), (-70, 75), (-68, 77), (-70, 40), (-72, 81), (-68, 84), (-69, 86), (-68, 44), (-68, 90), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-67, 87), (-57, 79), (-65, 1), (-69, 39), (-67, 82), (-63, 41), (-67, 83), (-66, 85)]
# In node_coloring, vertex 48, color None
# In graph_coloring_probe, pop:(-74, 62), info:[(-74, 70), (-74, 89), (-73, 0), (-72, 35), (-73, 9), (-71, 25), (-69, 60), (-71, 17), (-72, 76), (-73, 20), (-72, 88), (-69, 5), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (-71, 68), (-71, 73), (-71, 78), (-72, 81), (-70, 19), (-71, 43), (-72, 92), (-69, 96), (-69, 23), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-70, 34), (-69, 97), (-69, 72), (-70, 71), (-70, 75), (-68, 77), (-70, 40), (-69, 39), (-68, 84), (-69, 86), (-68, 44), (-68, 90), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-67, 87), (-57, 79), (-65, 1), (-66, 85), (-67, 82), (-63, 41), (-67, 83)]
# In node_coloring, vertex 62, color None
# In graph_coloring_probe, pop:(-74, 70), info:[(-74, 89), (-73, 9), (-73, 0), (-72, 35), (-73, 20), (-71, 25), (-69, 60), (-71, 17), (-72, 76), (-72, 81), (-72, 88), (-69, 5), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (-71, 68), (-71, 73), (-71, 78), (-70, 40), (-70, 19), (-71, 43), (-72, 92), (-69, 96), (-69, 23), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-70, 34), (-69, 97), (-69, 72), (-70, 71), (-70, 75), (-68, 77), (-67, 83), (-69, 39), (-68, 84), (-69, 86), (-68, 44), (-68, 90), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-69, 49), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-67, 87), (-57, 79), (-65, 1), (-66, 85), (-67, 82), (-63, 41)]
# In node_coloring, vertex 70, color None
# In graph_coloring_probe, pop:(-74, 89), info:[(-73, 0), (-73, 9), (-71, 25), (-72, 35), (-73, 20), (-69, 5), (-69, 60), (-71, 17), (-72, 76), (-72, 81), (-72, 88), (-69, 23), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (-71, 68), (-71, 73), (-71, 78), (-70, 40), (-70, 19), (-71, 43), (-72, 92), (-69, 96), (-69, 49), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-70, 34), (-69, 97), (-69, 72), (-70, 71), (-70, 75), (-68, 77), (-67, 83), (-69, 39), (-68, 84), (-69, 86), (-68, 44), (-68, 90), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-67, 87), (-57, 79), (-65, 1), (-66, 85), (-67, 82)]
# In node_coloring, vertex 89, color None
# In graph_coloring_probe, pop:(-73, 0), info:[(-73, 9), (-73, 20), (-71, 25), (-72, 35), (-72, 81), (-69, 5), (-69, 60), (-71, 17), (-72, 76), (-70, 19), (-72, 88), (-69, 23), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (-71, 68), (-71, 73), (-71, 78), (-70, 40), (-69, 86), (-71, 43), (-72, 92), (-69, 96), (-69, 49), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-70, 34), (-69, 97), (-69, 72), (-70, 71), (-70, 75), (-68, 77), (-67, 83), (-69, 39), (-68, 84), (-67, 82), (-68, 44), (-68, 90), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-67, 99), (-63, 18), (-67, 38), (-66, 37), (-67, 87), (-57, 79), (-65, 1), (-66, 85)]
# In node_coloring, vertex 0, color None
# In graph_coloring_probe, pop:(-73, 9), info:[(-73, 20), (-72, 35), (-71, 25), (-72, 76), (-72, 81), (-69, 5), (-69, 60), (-71, 17), (-71, 73), (-70, 19), (-72, 88), (-69, 23), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (-71, 68), (-70, 71), (-71, 78), (-70, 40), (-69, 86), (-71, 43), (-72, 92), (-69, 96), (-69, 49), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-70, 34), (-69, 97), (-69, 72), (-67, 99), (-70, 75), (-68, 77), (-67, 83), (-69, 39), (-68, 84), (-67, 82), (-68, 44), (-68, 90), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-69, 67), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-66, 85), (-63, 18), (-67, 38), (-66, 37), (-67, 87), (-57, 79), (-65, 1)]
# In node_coloring, vertex 9, color None
# In graph_coloring_probe, pop:(-73, 20), info:[(-72, 35), (-72, 76), (-71, 25), (-71, 17), (-72, 81), (-69, 5), (-69, 60), (-71, 68), (-71, 73), (-70, 19), (-72, 88), (-69, 23), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (-70, 34), (-70, 71), (-71, 78), (-70, 40), (-69, 86), (-71, 43), (-72, 92), (-69, 96), (-69, 49), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-69, 67), (-69, 97), (-69, 72), (-67, 99), (-70, 75), (-68, 77), (-67, 83), (-69, 39), (-68, 84), (-67, 82), (-68, 44), (-68, 90), (-70, 45), (-68, 46), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-65, 1), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-66, 85), (-63, 18), (-67, 38), (-66, 37), (-67, 87), (-57, 79)]
# In node_coloring, vertex 20, color None
# In graph_coloring_probe, pop:(-72, 35), info:[(-72, 76), (-72, 81), (-71, 25), (-71, 17), (-72, 88), (-69, 5), (-69, 60), (-71, 68), (-71, 73), (-70, 19), (-72, 92), (-69, 23), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (-70, 34), (-70, 71), (-71, 78), (-70, 40), (-69, 86), (-71, 43), (-70, 45), (-69, 96), (-69, 49), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-69, 67), (-69, 97), (-69, 72), (-67, 99), (-70, 75), (-68, 77), (-67, 83), (-69, 39), (-68, 84), (-67, 82), (-68, 44), (-68, 90), (-57, 79), (-68, 46), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-65, 1), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-66, 85), (-63, 18), (-67, 38), (-66, 37), (-67, 87)]
# In node_coloring, vertex 35, color None
# In graph_coloring_probe, pop:(-72, 76), info:[(-72, 81), (-72, 88), (-71, 25), (-71, 17), (-72, 92), (-69, 5), (-69, 60), (-71, 68), (-71, 73), (-70, 19), (-71, 43), (-69, 23), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (-70, 34), (-70, 71), (-71, 78), (-70, 40), (-69, 86), (-68, 44), (-70, 45), (-69, 96), (-69, 49), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-69, 67), (-69, 97), (-69, 72), (-67, 99), (-70, 75), (-68, 77), (-67, 83), (-69, 39), (-68, 84), (-67, 82), (-67, 87), (-68, 90), (-57, 79), (-68, 46), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-65, 1), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-66, 85), (-63, 18), (-67, 38), (-66, 37)]
# In node_coloring, vertex 76, color None
# In graph_coloring_probe, pop:(-72, 81), info:[(-72, 88), (-72, 92), (-71, 25), (-71, 17), (-71, 43), (-69, 5), (-69, 60), (-71, 68), (-71, 73), (-70, 19), (-70, 45), (-69, 23), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (-70, 34), (-70, 71), (-71, 78), (-70, 40), (-69, 86), (-68, 44), (-68, 46), (-69, 96), (-69, 49), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-69, 67), (-69, 97), (-69, 72), (-67, 99), (-70, 75), (-68, 77), (-67, 83), (-69, 39), (-68, 84), (-67, 82), (-67, 87), (-68, 90), (-57, 79), (-66, 37), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-65, 1), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-66, 85), (-63, 18), (-67, 38)]
# In node_coloring, vertex 81, color None
# In graph_coloring_probe, pop:(-72, 88), info:[(-72, 92), (-71, 17), (-71, 25), (-71, 68), (-71, 43), (-69, 5), (-69, 60), (-70, 34), (-71, 73), (-70, 19), (-70, 45), (-69, 23), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (-69, 67), (-70, 71), (-71, 78), (-70, 40), (-69, 86), (-68, 44), (-68, 46), (-69, 96), (-69, 49), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-67, 38), (-69, 97), (-69, 72), (-67, 99), (-70, 75), (-68, 77), (-67, 83), (-69, 39), (-68, 84), (-67, 82), (-67, 87), (-68, 90), (-57, 79), (-66, 37), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-65, 1), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-66, 85), (-63, 18)]
# In node_coloring, vertex 88, color None
# In graph_coloring_probe, pop:(-72, 92), info:[(-71, 17), (-71, 43), (-71, 25), (-71, 68), (-70, 19), (-69, 5), (-69, 60), (-70, 34), (-71, 73), (-70, 40), (-70, 45), (-69, 23), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (-69, 67), (-70, 71), (-71, 78), (-69, 39), (-69, 86), (-68, 44), (-68, 46), (-69, 96), (-69, 49), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-67, 38), (-69, 97), (-69, 72), (-67, 99), (-70, 75), (-68, 77), (-67, 83), (-63, 18), (-68, 84), (-67, 82), (-67, 87), (-68, 90), (-57, 79), (-66, 37), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-65, 1), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36), (-66, 85)]
# In node_coloring, vertex 92, color None
# In graph_coloring_probe, pop:(-71, 17), info:[(-71, 25), (-71, 43), (-69, 5), (-71, 68), (-70, 19), (-69, 23), (-69, 60), (-70, 34), (-71, 73), (-70, 40), (-70, 45), (-69, 49), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (-69, 67), (-70, 71), (-71, 78), (-69, 39), (-69, 86), (-68, 44), (-68, 46), (-69, 96), (-66, 85), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-68, 31), (-66, 15), (-67, 38), (-69, 97), (-69, 72), (-67, 99), (-70, 75), (-68, 77), (-67, 83), (-63, 18), (-68, 84), (-67, 82), (-67, 87), (-68, 90), (-57, 79), (-66, 37), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66), (-63, 16), (-65, 1), (-65, 33), (-57, 91), (-67, 7), (-68, 4), (-65, 36)]
# In node_coloring, vertex 17, color None
# In graph_coloring_probe, pop:(-71, 25), info:[(-71, 43), (-71, 68), (-69, 5), (-71, 73), (-70, 19), (-69, 23), (-69, 60), (-70, 34), (-71, 78), (-70, 40), (-70, 45), (-69, 49), (-69, 52), (-68, 11), (-68, 42), (-70, 63), (
(-67, 87), (-65, 1), (-57, 79), (-66, 37), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65), (-60, 66)]
# In node_coloring, vertex 34, color None
# In graph_coloring_probe, pop:(-70, 40), info:[(-70, 45), (-70, 63), (-69, 5), (-70, 71), (-69, 39), (-69, 23), (-69, 60), (-69, 67), (-70, 75), (-69, 86), (-68, 44), (-69, 49), (-69, 52), (-68, 11), (-68, 42), (-68, 31), (-69, 97), (-69, 72), (-68, 77), (-67, 83), (-68, 84), (-68, 90), (-68, 46), (-69, 96), (-66, 85), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-67, 7), (-66, 15), (-67, 38), (-65, 33), (-68, 4), (-67, 99), (-65, 36), (-60, 66), (-57, 91), (-63, 18), (-63, 16), (-67, 82), (-67, 87), (-65, 1), (-57, 79), (-66, 37), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22), (-64, 65)]
# In node_coloring, vertex 40, color None
# In graph_coloring_probe, pop:(-70, 45), info:[(-70, 63), (-70, 71), (-69, 5), (-70, 75), (-69, 39), (-69, 23), (-69, 60), (-69, 67), (-69, 72), (-69, 86), (-68, 44), (-69, 49), (-69, 52), (-68, 11), (-68, 42), (-68, 31), (-69, 97), (-68, 4), (-68, 77), (-67, 83), (-68, 84), (-68, 90), (-68, 46), (-69, 96), (-66, 85), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-67, 7), (-66, 15), (-67, 38), (-65, 33), (-64, 65), (-67, 99), (-65, 36), (-60, 66), (-57, 91), (-63, 18), (-63, 16), (-67, 82), (-67, 87), (-65, 1), (-57, 79), (-66, 37), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3), (-66, 22)]
# In node_coloring, vertex 45, color None
# In graph_coloring_probe, pop:(-70, 63), info:[(-70, 71), (-70, 75), (-69, 5), (-69, 67), (-69, 39), (-69, 23), (-69, 60), (-69, 97), (-69, 72), (-69, 86), (-68, 44), (-69, 49), (-69, 52), (-68, 11), (-68, 42), (-68, 31), (-67, 38), (-68, 4), (-68, 77), (-67, 83), (-68, 84), (-68, 90), (-68, 46), (-69, 96), (-66, 85), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-67, 7), (-66, 15), (-66, 22), (-65, 33), (-64, 65), (-67, 99), (-65, 36), (-60, 66), (-57, 91), (-63, 18), (-63, 16), (-67, 82), (-67, 87), (-65, 1), (-57, 79), (-66, 37), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95), (-65, 3)]
# In node_coloring, vertex 63, color None
# In graph_coloring_probe, pop:(-70, 71), info:[(-70, 75), (-69, 39), (-69, 5), (-69, 67), (-69, 86), (-69, 23), (-69, 60), (-69, 97), (-69, 72), (-68, 84), (-68, 44), (-69, 49), (-69, 52), (-68, 11), (-68, 42), (-68, 31), (-67, 38), (-68, 4), (-68, 77), (-67, 83), (-67, 82), (-68, 90), (-68, 46), (-69, 96), (-66, 85), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-67, 7), (-66, 15), (-66, 22), (-65, 33), (-64, 65), (-67, 99), (-65, 36), (-60, 66), (-57, 91), (-63, 18), (-63, 16), (-65, 3), (-67, 87), (-65, 1), (-57, 79), (-66, 37), (-61, 93), (-68, 94), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30), (-66, 95)]
# In node_coloring, vertex 71, color None
# In graph_coloring_probe, pop:(-70, 75), info:[(-69, 5), (-69, 39), (-69, 23), (-69, 67), (-69, 86), (-69, 49), (-69, 60), (-69, 97), (-69, 72), (-68, 84), (-68, 44), (-69, 96), (-69, 52), (-68, 11), (-68, 42), (-68, 31), (-67, 38), (-68, 4), (-68, 77), (-67, 83), (-67, 82), (-68, 90), (-68, 46), (-68, 94), (-66, 85), (-66, 21), (-69, 53), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-67, 7), (-66, 15), (-66, 22), (-65, 33), (-64, 65), (-67, 99), (-65, 36), (-60, 66), (-57, 91), (-63, 18), (-63, 16), (-65, 3), (-67, 87), (-65, 1), (-57, 79), (-66, 37), (-61, 93), (-66, 95), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-64, 26), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10), (-59, 30)]
# In node_coloring, vertex 75, color None
# In graph_coloring_probe, pop:(-69, 5), info:[(-69, 23), (-69, 39), (-69, 49), (-69, 67), (-69, 86), (-69, 52), (-69, 60), (-69, 97), (-69, 72), (-68, 84), (-68, 44), (-69, 96), (-69, 53), (-68, 11), (-68, 42), (-68, 31), (-67, 38), (-68, 4), (-68, 77), (-67, 83), (-67, 82), (-68, 90), (-68, 46), (-68, 94), (-66, 85), (-66, 21), (-64, 26), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-67, 7), (-66, 15), (-66, 22), (-65, 33), (-64, 65), (-67, 99), (-65, 36), (-60, 66), (-57, 91), (-63, 18), (-63, 16), (-65, 3), (-67, 87), (-65, 1), (-57, 79), (-66, 37), (-61, 93), (-66, 95), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-59, 30), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59), (-61, 10)]
# In node_coloring, vertex 5, color None
# In graph_coloring_probe, pop:(-69, 23), info:[(-69, 39), (-69, 67), (-69, 49), (-69, 72), (-69, 86), (-69, 52), (-69, 60), (-69, 97), (-68, 4), (-68, 84), (-68, 44), (-69, 96), (-69, 53), (-68, 11), (-68, 42), (-68, 31), (-67, 38), (-67, 99), (-68, 77), (-67, 83), (-67, 82), (-68, 90), (-68, 46), (-68, 94), (-66, 85), (-66, 21), (-64, 26), (-68, 27), (-68, 57), (-67, 6), (-67, 61), (-67, 7), (-66, 15), (-66, 22), (-65, 33), (-64, 65), (-61, 10), (-65, 36), (-60, 66), (-57, 91), (-63, 18), (-63, 16), (-65, 3), (-67, 87), (-65, 1), (-57, 79), (-66, 37), (-61, 93), (-66, 95), (-63, 41), (-61, 50), (-63, 12), (-65, 51), (-59, 30), (-61, 98), (-63, 55), (-65, 13), (-67, 28), (-60, 58), (-66, 59)]
# In node_coloring, vertex 23, color None
# In graph_coloring_probe, pop:(-69, 39), info:[(-69, 49), (-69, 67), (-69, 52), (-69, 72), (-69, 86), (-69, 53), (-69, 60), (-69, 97), (-68, 4), (-68, 84), (-68, 44), (-69, 96), (-66, 21), (-68, 11), (-68, 42), (-68, 31), (-67, 38), (-67, 99), (-68, 77), (-67, 83), (-67, 82), (-68, 90), (-68, 46), (
# In graph_coloring_probe, pop:(-63, 41), info:[(-63, 55), (-61, 98), (-61, 10), (-60, 66), (-60, 58), (-61, 50), (-61, 93), (-57, 91), (-57, 79), (-59, 30)]
# In graph_coloring_probe, pop:(-63, 55), info:[(-61, 10), (-61, 98), (-61, 50), (-60, 66), (-60, 58), (-59, 30), (-61, 93), (-57, 91), (-57, 79)]
# In graph_coloring_probe, pop:(-61, 10), info:[(-61, 50), (-61, 98), (-61, 93), (-60, 66), (-60, 58), (-59, 30), (-57, 79), (-57, 91)]
# In graph_coloring_probe, pop:(-61, 50), info:[(-61, 93), (-61, 98), (-59, 30), (-60, 66), (-60, 58), (-57, 91), (-57, 79)]
# In graph_coloring_probe, pop:(-61, 93), info:[(-61, 98), (-60, 58), (-59, 30), (-60, 66), (-57, 79), (-57, 91)]
# In graph_coloring_probe, pop:(-61, 98), info:[(-60, 58), (-60, 66), (-59, 30), (-57, 91), (-57, 79)]
# In graph_coloring_probe, pop:(-60, 58), info:[(-60, 66), (-57, 79), (-59, 30), (-57, 91)]
# In graph_coloring_probe, pop:(-60, 66), info:[(-59, 30), (-57, 79), (-57, 91)]
# In graph_coloring_probe, pop:(-59, 30), info:[(-57, 79), (-57, 91)]
# In graph_coloring_probe, pop:(-57, 79), info:[(-57, 91)]
# In graph_coloring_probe, pop:(-57, 91), info:[]
# In graph_coloring, pop:(-57, 91), info:[]
#
#
#  Output
#  28 0
# 2 18 4 21 15 7 20 19 0 9 21 17 20 23 3 21 7 12 9 12 10 22 22 15 1 1 24 18 18 3 23 19 4 20 2 8 22 24 21 3 4 10 17 13 19 14 15 2 6 14 1 25 6 16 5 5 0 20 10 24 9 22 7 8 5 25 20 3 10 2 8 8 17 12 0 15 9 2 13 27 1 5 18 23 7 25 14 23 11 6 14 13 11 26 11 13 16 6 4 16

# %%
data_folder = 'C:/D/coursera/discrete_opt/coloring/data'
filename = os.path.join(data_folder,'gc_1000_7')
with open(filename, 'r') as input_data_file:
    input_data = input_data_file.read()
    
output, vertex_colors, color_frequency = solve_it(input_data)
print('\n\nVertex colors\n', vertex_colors)
print('\n\nColors frequence\n', color_frequency)
print('\n\n Output\n', output)
# Out:
# ---------------Start graph coloring ------------------
# In node_coloring, vertex 579, color None
# -------------------------Get new color
# In node_coloring, vertex 579 with degree 743 set to color 0
# In node_coloring, vertex 176, color None
# In node_coloring, vertex 524, color None
# In node_coloring, vertex 930, color None
# In node_coloring, vertex 636, color None
# In node_coloring, vertex 77, color None
# -------------------------Use old color
# In node_coloring, vertex 77 with degree 733 set to color 0
# In node_coloring, vertex 220, color None
# In node_coloring, vertex 680, color None
# In node_coloring, vertex 754, color None
# In node_coloring, vertex 6, color None
# -------------------------Use old color
# In node_coloring, vertex 6 with degree 731 set to color 0
# In node_coloring, vertex 500, color None
# In node_coloring, vertex 977, color None
# In node_coloring, vertex 96, color None
# In node_coloring, vertex 800, color None
# In node_coloring, vertex 60, color None
# In node_coloring, vertex 206, color None
# In node_coloring, vertex 336, color None
# In node_coloring, vertex 412, color None
# In node_coloring, vertex 438, color None
# In node_coloring, vertex 545, color None
# In node_coloring, vertex 583, color None
# In node_coloring, vertex 592, color None
# In node_coloring, vertex 267, color None
# In node_coloring, vertex 376, color None
# In node_coloring, vertex 576, color None
# In node_coloring, vertex 692, color None
# In node_coloring, vertex 71, color None
# In node_coloring, vertex 244, color None
# In node_coloring, vertex 266, color None
# In node_coloring, vertex 369, color None
# In node_coloring, vertex 506, color None
# In node_coloring, vertex 286, color None
# In node_coloring, vertex 739, color None
# In node_coloring, vertex 828, color None
# In node_coloring, vertex 23, color None
# In node_coloring, vertex 28, color None
# In node_coloring, vertex 110, color None
# In node_coloring, vertex 255, color None
# In node_coloring, vertex 319, color None
# In node_coloring, vertex 321, color None
# In node_coloring, vertex 813, color None
# In node_coloring, vertex 818, color None
# In node_coloring, vertex 838, color None
# In node_coloring, vertex 881, color None
# In node_coloring, vertex 980, color None
# In node_coloring, vertex 988, color None
# In node_coloring, vertex 16, color None
# In node_coloring, vertex 119, color None
# In node_coloring, vertex 130, color None
# In node_coloring, vertex 247, color None
# In node_coloring, vertex 274, color None
# In node_coloring, vertex 475, color None
# In node_coloring, vertex 632, color None
# In node_coloring, vertex 655, color None
# In node_coloring, vertex 699, color None
# In node_coloring, vertex 784, color None
# In node_coloring, vertex 858, color None
# In node_coloring, vertex 3, color None
# In node_coloring, vertex 68, color None
# In node_coloring, vertex 139, color None
# In node_coloring, vertex 182, color None
# In node_coloring, vertex 284, color None
# In node_coloring, vertex 371, color None
# In node_coloring, vertex 480, color None
# In node_coloring, vertex 578, color None
# In node_coloring, vertex 625, color None
# In node_coloring, vertex 652, color None
# In node_coloring, vertex 682, color None
# In node_coloring, vertex 845, color None
# In node_coloring, vertex 970, color None
# In node_coloring, vertex 35, color None
# In node_coloring, vertex 254, color None
# In node_coloring, vertex 329, color None
# In node_coloring, vertex 361, color None
# In node_coloring, vertex 497, color None
# In node_coloring, vertex 566, color None
# In node_coloring, vertex 581, color None
# In node_coloring, vertex 669, color None
# In node_coloring, vertex 773, color None
# In node_coloring, vertex 926, color None
# In node_coloring, vertex 32, color None
# In node_coloring, vertex 66, color None
# In node_coloring, vertex 363, color None
# In node_coloring, vertex 420, color None
# In node_coloring, vertex 665, color None
# In node_coloring, vertex 667, color None
# In node_coloring, vertex 851, color None
# In node_coloring, vertex 857, color None
# In node_coloring, vertex 49, color None
# In node_coloring, vertex 87, color None
# In node_coloring, vertex 348, color None
# In node_coloring, vertex 403, color None
# In node_coloring, vertex 508, color None
# In node_coloring, vertex 569, color None
# In node_coloring, vertex 617, color None
# In node_coloring, vertex 677, color None
# In node_coloring, vertex 707, color None
# In node_coloring, vertex 749, color None
# In node_coloring, vertex 810, color None
# In node_coloring, vertex 1, color None
# In node_coloring, vertex 166, color None
# In child_node_checking, vertex 870, color None
# In child_node_checking, parent vertex 166 with degree 718, child vertex 870 with degree 718 set to color 0
# In node_coloring, vertex 224, color None
# In node_coloring, vertex 262, color None
# In node_coloring, vertex 318, color None
# In node_coloring, vertex 342, color None
# In node_coloring, vertex 454, color None
# In node_coloring, vertex 484, color None
# In node_coloring, vertex 541, color None
# In node_coloring, vertex 725, color None
# In node_coloring, vertex 744, color None
# In node_coloring, vertex 898, color None
# In node_coloring, vertex 910, color None
# In node_coloring, vertex 29, color None
# In child_node_checking, vertex 44, color None
# In child_node_checking, parent vertex 29 with degree 717, child vertex 44 with degree 717 set to color 0
# In node_coloring, vertex 90, color None
# In node_coloring, vertex 128, color None
# In node_coloring, vertex 167, color None
# In node_coloring, vertex 291, color None
# In node_coloring, vertex 328, color None
# In node_coloring, vertex 424, color None
# In node_coloring, vertex 461, color None
# In node_coloring, vertex 498, color None
# In node_coloring, vertex 509, color None
# In node_coloring, vertex 540, color None
# In node_coloring, vertex 653, color None
# In node_coloring, vertex 742, color None
# In node_coloring, vertex 747, color None
# In node_coloring, vertex 899, color None
# In node_coloring, vertex 996, color None
# In node_coloring, vertex 15, color None
# In node_coloring, vertex 18, color None
# In node_coloring, vertex 37, color None
# In node_coloring, vertex 39, color None
# In node_coloring, vertex 55, color None
# In node_coloring, vertex 95, color None
# In node_coloring, vertex 191, color None
# In node_coloring, vertex 359, color None
# In node_coloring, vertex 440, color None
# In node_coloring, vertex 469, color None
# In node_coloring, vertex 537, color None
# In node_coloring, vertex 564, color None
# In node_coloring, vertex 577, color None
# In node_coloring, vertex 628, color None
# In node_coloring, vertex 684, color None
# In node_coloring, vertex 758, color None
# In node_coloring, vertex 821, color None
# In node_coloring, vertex 896, color None
# In node_coloring, vertex 967, color None
# In node_coloring, vertex 999, color None
# In node_coloring, vertex 8, color None
# In node_coloring, vertex 59, color None
# In node_coloring, vertex 106, color None
# In node_coloring, vertex 185, color None
# In node_coloring, vertex 197, color None
# In node_coloring, vertex 226, color None
# In node_coloring, vertex 236, color None
# In node_coloring, vertex 251, color None
# In node_coloring, vertex 343, color None
# In node_coloring, vertex 495, color None
# In node_coloring, vertex 542, color None
# In node_coloring, vertex 616, color None
# In node_coloring, vertex 645, color None
# In node_coloring, vertex 710, color None
# In node_coloring, vertex 716, color None
# In node_coloring, vertex 753, color None
# In node_coloring, vertex 787, color None
# In node_coloring, vertex 76, color None
# In node_coloring, vertex 132, color None
# In node_coloring, vertex 164, color None
# In node_coloring, vertex 272, color None
# In node_coloring, vertex 488, color None
# In node_coloring, vertex 489, color None
# In node_coloring, vertex 520, color None
# In node_coloring, vertex 567, color None
# In node_coloring, vertex 894, color None
# In node_coloring, vertex 923, color None
# In node_coloring, vertex 952, color None
# In node_coloring, vertex 85, color None
# In node_coloring, vertex 86, color None
# In node_coloring, vertex 237, color None
# In node_coloring, vertex 333, color None
# In node_coloring, vertex 459, color None
# In node_coloring, vertex 473, color None
# In node_coloring, vertex 494, color None
# In node_coloring, vertex 513, color None
# In node_coloring, vertex 548, color None
# In node_coloring, vertex 558, color None
# In node_coloring, vertex 640, color None
# In node_coloring, vertex 673, color None
# In node_coloring, vertex 717, color None
# In node_coloring, vertex 748, color None
# In node_coloring, vertex 878, color None
# In node_coloring, vertex 885, color None
# In node_coloring, vertex 12, color None
# In node_coloring, vertex 121, color None
# In node_coloring, vertex 204, color None
# In node_coloring, vertex 230, color None
# In node_coloring, vertex 231, color None
# In node_coloring, vertex 551, color None
# In node_coloring, vertex 561, color None
# In node_coloring, vertex 740, color None
# In node_coloring, vertex 802, color None
# In node_coloring, vertex 809, color None
# In node_coloring, vertex 863, color None
# In node_coloring, vertex 916, color None
# In node_coloring, vertex 919, color None
# In node_coloring, vertex 955, color None
# In node_coloring, vertex 4, color None
# In node_coloring, vertex 38, color None
# In node_coloring, vertex 108, color None
# In node_coloring, vertex 142, color None
# In node_coloring, vertex 144, color None
# In node_coloring, vertex 173, color None
# In node_coloring, vertex 337, color None
# In node_coloring, vertex 421, color None
# In node_coloring, vertex 437, color None
# In node_coloring, vertex 546, color None
# In node_coloring, vertex 709, color None
# In node_coloring, vertex 825, color None
# In node_coloring, vertex 867, color None
# In node_coloring, vertex 873, color None
# In node_coloring, vertex 882, color None
# In node_coloring, vertex 935, color None
# In node_coloring, vertex 975, color None
# In node_coloring, vertex 11, color None
# In node_coloring, vertex 102, color None
# In node_coloring, vertex 126, color None
# In node_coloring, vertex 152, color None
# In node_coloring, vertex 180, color None
# In node_coloring, vertex 202, color None
# In node_coloring, vertex 219, color None
# In node_coloring, vertex 288, color None
# In node_coloring, vertex 290, color None
# In node_coloring, vertex 374, color None
# In node_coloring, vertex 381, color None
# In node_coloring, vertex 397, color None
# In node_coloring, vertex 415, color None
# In node_coloring, vertex 417, color None
# In node_coloring, vertex 457, color None
# In node_coloring, vertex 493, color None
# In node_coloring, vertex 496, color None
# In node_coloring, vertex 507, color None
# In node_coloring, vertex 623, color None
# In node_coloring, vertex 683, color None
# In node_coloring, vertex 704, color None
# In node_coloring, vertex 789, color None
# In node_coloring, vertex 805, color None
# In node_coloring, vertex 875, color None
# In node_coloring, vertex 943, color None
# In node_coloring, vertex 979, color None
# In node_coloring, vertex 22, color None
# In node_coloring, vertex 154, color None
# In node_coloring, vertex 211, color None
# In node_coloring, vertex 233, color None
# In node_coloring, vertex 245, color None
# In node_coloring, vertex 252, color None
# In node_coloring, vertex 315, color None
# In node_coloring, vertex 377, color None
# In node_coloring, vertex 384, color None
# In node_coloring, vertex 393, color None
# In node_coloring, vertex 515, color None
# In node_coloring, vertex 536, color None
# In node_coloring, vertex 565, color None
# In node_coloring, vertex 588, color None
# In node_coloring, vertex 589, color None
# In node_coloring, vertex 650, color None
# In node_coloring, vertex 690, color None
# In node_coloring, vertex 714, color None
# In node_coloring, vertex 806, color None
# In node_coloring, vertex 861, color None
# In node_coloring, vertex 879, color None
# In node_coloring, vertex 915, color None
# In node_coloring, vertex 927, color None
# In node_coloring, vertex 969, color None
# In node_coloring, vertex 971, color None
# In node_coloring, vertex 20, color None
# In node_coloring, vertex 25, color None
# In node_coloring, vertex 99, color None
# In node_coloring, vertex 280, color None
# In node_coloring, vertex 331, color None
# In node_coloring, vertex 550, color None
# In node_coloring, vertex 631, color None
# In node_coloring, vertex 641, color None
# In node_coloring, vertex 647, color None
# In node_coloring, vertex 759, color None
# In node_coloring, vertex 764, color None
# In node_coloring, vertex 768, color None
# In node_coloring, vertex 785, color None
# In node_coloring, vertex 815, color None
# In node_coloring, vertex 820, color None
# In node_coloring, vertex 829, color None
# In node_coloring, vertex 843, color None
# In node_coloring, vertex 991, color None
# In node_coloring, vertex 5, color None
# In node_coloring, vertex 54, color None
# In node_coloring, vertex 97, color None
# In node_coloring, vertex 147, color None
# In node_coloring, vertex 277, color None
# In node_coloring, vertex 282, color None
# In node_coloring, vertex 325, color None
# In node_coloring, vertex 349, color None
# In node_coloring, vertex 351, color None
# In node_coloring, vertex 510, color None
# In node_coloring, vertex 672, color None
# In node_coloring, vertex 675, color None
# In node_coloring, vertex 706, color None
# In node_coloring, vertex 726, color None
# In node_coloring, vertex 738, color None
# In node_coloring, vertex 819, color None
# In node_coloring, vertex 850, color None
# In node_coloring, vertex 856, color None
# In node_coloring, vertex 868, color None
# In node_coloring, vertex 887, color None
# In node_coloring, vertex 891, color None
# In node_coloring, vertex 109, color None
# In node_coloring, vertex 143, color None
# In node_coloring, vertex 165, color None
# In node_coloring, vertex 168, color None
# In node_coloring, vertex 209, color None
# In node_coloring, vertex 221, color None
# In node_coloring, vertex 259, color None
# In node_coloring, vertex 260, color None
# In node_coloring, vertex 273, color None
# In node_coloring, vertex 278, color None
# In node_coloring, vertex 302, color None
# In node_coloring, vertex 303, color None
# In node_coloring, vertex 364, color None
# In node_coloring, vertex 366, color None
# In node_coloring, vertex 400, color None
# In node_coloring, vertex 502, color None
# In node_coloring, vertex 527, color None
# In node_coloring, vertex 534, color None
# In node_coloring, vertex 554, color None
# In node_coloring, vertex 598, color None
# In node_coloring, vertex 614, color None
# In node_coloring, vertex 668, color None
# In node_coloring, vertex 723, color None
# In node_coloring, vertex 921, color None
# In node_coloring, vertex 964, color None
# In node_coloring, vertex 53, color None
# In node_coloring, vertex 70, color None
# In node_coloring, vertex 101, color None
# In node_coloring, vertex 193, color None
# In node_coloring, vertex 241, color None
# In node_coloring, vertex 294, color None
# In node_coloring, vertex 356, color None
# In node_coloring, vertex 395, color None
# In node_coloring, vertex 465, color None
# In node_coloring, vertex 605, color None
# In node_coloring, vertex 648, color None
# In node_coloring, vertex 662, color None
# In node_coloring, vertex 697, color None
# In node_coloring, vertex 778, color None
# In node_coloring, vertex 797, color None
# In node_coloring, vertex 807, color None
# In node_coloring, vertex 831, color None
# In node_coloring, vertex 884, color None
# In node_coloring, vertex 993, color None
# In node_coloring, vertex 13, color None
# In node_coloring, vertex 51, color None
# In node_coloring, vertex 65, color None
# In node_coloring, vertex 79, color None
# In node_coloring, vertex 111, color None
# In node_coloring, vertex 196, color None
# In node_coloring, vertex 223, color None
# In node_coloring, vertex 281, color None
# In node_coloring, vertex 311, color None
# In node_coloring, vertex 332, color None
# In node_coloring, vertex 446, color None
# In node_coloring, vertex 499, color None
# In node_coloring, vertex 501, color None
# In node_coloring, vertex 512, color None
# In node_coloring, vertex 532, color None
# In node_coloring, vertex 535, color None
# In node_coloring, vertex 611, color None
# In node_coloring, vertex 626, color None
# In node_coloring, vertex 646, color None
# In node_coloring, vertex 681, color None
# In node_coloring, vertex 762, color None
# In node_coloring, vertex 767, color None
# In node_coloring, vertex 774, color None
# In node_coloring, vertex 848, color None
# In node_coloring, vertex 880, color None
# In node_coloring, vertex 901, color None
# In node_coloring, vertex 903, color None
# In node_coloring, vertex 924, color None
# In node_coloring, vertex 931, color None
# In node_coloring, vertex 960, color None
# In node_coloring, vertex 972, color None
# In node_coloring, vertex 983, color None
# In node_coloring, vertex 52, color None
# In node_coloring, vertex 94, color None
# In node_coloring, vertex 98, color None
# In node_coloring, vertex 150, color None
# In node_coloring, vertex 169, color None
# In node_coloring, vertex 178, color None
# In node_coloring, vertex 227, color None
# In node_coloring, vertex 334, color None
# In node_coloring, vertex 335, color None
# In node_coloring, vertex 434, color None
# In node_coloring, vertex 445, color None
# In node_coloring, vertex 522, color None
# In node_coloring, vertex 572, color None
# In node_coloring, vertex 590, color None
# In node_coloring, vertex 599, color None
# In node_coloring, vertex 609, color None
# In node_coloring, vertex 644, color None
# In node_coloring, vertex 694, color None
# In node_coloring, vertex 733, color None
# In node_coloring, vertex 751, color None
# In node_coloring, vertex 846, color None
# In node_coloring, vertex 962, color None
# In node_coloring, vertex 986, color None
# In node_coloring, vertex 125, color None
# In node_coloring, vertex 149, color None
# In node_coloring, vertex 153, color None
# In node_coloring, vertex 177, color None
# In node_coloring, vertex 205, color None
# In node_coloring, vertex 324, color None
# In node_coloring, vertex 353, color None
# In node_coloring, vertex 390, color None
# In node_coloring, vertex 431, color None
# In node_coloring, vertex 468, color None
# In node_coloring, vertex 518, color None
# In node_coloring, vertex 556, color None
# In node_coloring, vertex 619, color None
# In node_coloring, vertex 635, color None
# In node_coloring, vertex 649, color None
# In node_coloring, vertex 670, color None
# In node_coloring, vertex 698, color None
# In node_coloring, vertex 715, color None
# In node_coloring, vertex 756, color None
# In node_coloring, vertex 782, color None
# In node_coloring, vertex 795, color None
# In node_coloring, vertex 804, color None
# In node_coloring, vertex 830, color None
# In node_coloring, vertex 841, color None
# In node_coloring, vertex 859, color None
# In node_coloring, vertex 954, color None
# In node_coloring, vertex 973, color None
# In node_coloring, vertex 81, color None
# In node_coloring, vertex 170, color None
# In node_coloring, vertex 175, color None
# In node_coloring, vertex 188, color None
# In node_coloring, vertex 248, color None
# In node_coloring, vertex 270, color None
# In node_coloring, vertex 313, color None
# In node_coloring, vertex 352, color None
# In node_coloring, vertex 358, color None
# In node_coloring, vertex 410, color None
# In node_coloring, vertex 472, color None
# In node_coloring, vertex 479, color None
# In node_coloring, vertex 505, color None
# In node_coloring, vertex 516, color None
# In node_coloring, vertex 582, color None
# In node_coloring, vertex 676, color None
# In node_coloring, vertex 700, color None
# In node_coloring, vertex 703, color None
# In node_coloring, vertex 779, color None
# In node_coloring, vertex 792, color None
# In node_coloring, vertex 814, color None
# In node_coloring, vertex 876, color None
# In node_coloring, vertex 890, color None
# In node_coloring, vertex 906, color None
# In node_coloring, vertex 912, color None
# In node_coloring, vertex 940, color None
# In node_coloring, vertex 0, color None
# In node_coloring, vertex 36, color None
# In node_coloring, vertex 83, color None
# In node_coloring, vertex 134, color None
# In node_coloring, vertex 161, color None
# In node_coloring, vertex 187, color None
# In node_coloring, vertex 263, color None
# In node_coloring, vertex 264, color None
# In node_coloring, vertex 287, color None
# In node_coloring, vertex 404, color None
# In node_coloring, vertex 425, color None
# In node_coloring, vertex 481, color None
# In node_coloring, vertex 560, color None
# In node_coloring, vertex 613, color None
# In node_coloring, vertex 627, color None
# In node_coloring, vertex 678, color None
# In node_coloring, vertex 728, color None
# In node_coloring, vertex 780, color None
# In node_coloring, vertex 826, color None
# In node_coloring, vertex 945, color None
# In node_coloring, vertex 965, color None
# In node_coloring, vertex 995, color None
# In node_coloring, vertex 27, color None
# In node_coloring, vertex 62, color None
# In node_coloring, vertex 64, color None
# In node_coloring, vertex 129, color None
# In node_coloring, vertex 195, color None
# In node_coloring, vertex 203, color None
# In node_coloring, vertex 217, color None
# In node_coloring, vertex 225, color None
# In node_coloring, vertex 289, color None
# In node_coloring, vertex 293, color None
# In node_coloring, vertex 300, color None
# In node_coloring, vertex 301, color None
# In node_coloring, vertex 305, color None
# In node_coloring, vertex 322, color None
# In node_coloring, vertex 323, color None
# In node_coloring, vertex 385, color None
# In node_coloring, vertex 394, color None
# In node_coloring, vertex 398, color None
# In node_coloring, vertex 411, color None
# In node_coloring, vertex 418, color None
# In node_coloring, vertex 439, color None
# In node_coloring, vertex 466, color None
# In node_coloring, vertex 476, color None
# In node_coloring, vertex 538, color None
# In node_coloring, vertex 571, color None
# In node_coloring, vertex 585, color None
# In node_coloring, vertex 597, color None
# In node_coloring, vertex 638, color None
# In node_coloring, vertex 642, color None
# In node_coloring, vertex 656, color None
# In node_coloring, vertex 702, color None
# In node_coloring, vertex 745, color None
# In node_coloring, vertex 812, color None
# In node_coloring, vertex 823, color None
# In node_coloring, vertex 853, color None
# In node_coloring, vertex 869, color None
# In node_coloring, vertex 909, color None
# In node_coloring, vertex 989, color None
# In node_coloring, vertex 992, color None
# In node_coloring, vertex 151, color None
# In node_coloring, vertex 189, color None
# In node_coloring, vertex 192, color None
# In node_coloring, vertex 194, color None
# In node_coloring, vertex 213, color None
# In node_coloring, vertex 243, color None
# In node_coloring, vertex 269, color None
# In node_coloring, vertex 295, color None
# In node_coloring, vertex 309, color None
# In node_coloring, vertex 320, color None
# In node_coloring, vertex 405, color None
# In node_coloring, vertex 455, color None
# In node_coloring, vertex 543, color None
# In node_coloring, vertex 557, color None
# In node_coloring, vertex 594, color None
# In node_coloring, vertex 633, color None
# In node_coloring, vertex 661, color None
# In node_coloring, vertex 685, color None
# In node_coloring, vertex 693, color None
# In node_coloring, vertex 711, color None
# In node_coloring, vertex 765, color None
# In node_coloring, vertex 796, color None
# In node_coloring, vertex 834, color None
# In node_coloring, vertex 907, color None
# In node_coloring, vertex 913, color None
# In node_coloring, vertex 920, color None
# In node_coloring, vertex 961, color None
# In node_coloring, vertex 67, color None
# In node_coloring, vertex 116, color None
# In node_coloring, vertex 120, color None
# In node_coloring, vertex 123, color None
# In node_coloring, vertex 137, color None
# In node_coloring, vertex 184, color None
# In node_coloring, vertex 200, color None
# In node_coloring, vertex 232, color None
# In node_coloring, vertex 258, color None
# In node_coloring, vertex 276, color None
# In node_coloring, vertex 298, color None
# In node_coloring, vertex 326, color None
# In node_coloring, vertex 386, color None
# In node_coloring, vertex 396, color None
# In node_coloring, vertex 409, color None
# In node_coloring, vertex 444, color None
# In node_coloring, vertex 450, color None
# In node_coloring, vertex 490, color None
# In node_coloring, vertex 519, color None
# In node_coloring, vertex 521, color None
# In node_coloring, vertex 573, color None
# In node_coloring, vertex 602, color None
# In node_coloring, vertex 666, color None
# In node_coloring, vertex 724, color None
# In node_coloring, vertex 769, color None
# In node_coloring, vertex 777, color None
# In node_coloring, vertex 860, color None
# In node_coloring, vertex 893, color None
# In node_coloring, vertex 958, color None
# In node_coloring, vertex 997, color None
# In node_coloring, vertex 57, color None
# In node_coloring, vertex 88, color None
# In node_coloring, vertex 136, color None
# In node_coloring, vertex 240, color None
# In node_coloring, vertex 271, color None
# In node_coloring, vertex 283, color None
# In node_coloring, vertex 307, color None
# In node_coloring, vertex 340, color None
# In node_coloring, vertex 375, color None
# In node_coloring, vertex 389, color None
# In node_coloring, vertex 392, color None
# In node_coloring, vertex 406, color None
# In node_coloring, vertex 453, color None
# In node_coloring, vertex 477, color None
# In node_coloring, vertex 487, color None
# In node_coloring, vertex 517, color None
# In node_coloring, vertex 555, color None
# In node_coloring, vertex 559, color None
# In node_coloring, vertex 574, color None
# In node_coloring, vertex 591, color None
# In node_coloring, vertex 603, color None
# In node_coloring, vertex 607, color None
# In node_coloring, vertex 610, color None
# In node_coloring, vertex 637, color None
# In node_coloring, vertex 679, color None
# In node_coloring, vertex 686, color None
# In node_coloring, vertex 688, color None
# In node_coloring, vertex 705, color None
# In node_coloring, vertex 746, color None
# In node_coloring, vertex 757, color None
# In node_coloring, vertex 788, color None
# In node_coloring, vertex 822, color None
# In node_coloring, vertex 847, color None
# In node_coloring, vertex 871, color None
# In node_coloring, vertex 929, color None
# In node_coloring, vertex 984, color None
# In node_coloring, vertex 40, color None
# In node_coloring, vertex 45, color None
# In node_coloring, vertex 47, color None
# In node_coloring, vertex 50, color None
# In node_coloring, vertex 72, color None
# In node_coloring, vertex 82, color None
# In node_coloring, vertex 198, color None
# In node_coloring, vertex 215, color None
# In node_coloring, vertex 407, color None
# In node_coloring, vertex 430, color None
# In node_coloring, vertex 523, color None
# In node_coloring, vertex 528, color None
# In node_coloring, vertex 663, color None
# In node_coloring, vertex 689, color None
# In node_coloring, vertex 718, color None
# In node_coloring, vertex 849, color None
# In node_coloring, vertex 872, color None
# In node_coloring, vertex 883, color None
# In node_coloring, vertex 928, color None
# In node_coloring, vertex 963, color None
# In node_coloring, vertex 978, color None
# In node_coloring, vertex 41, color None
# In node_coloring, vertex 46, color None
# In node_coloring, vertex 61, color None
# In node_coloring, vertex 80, color None
# In node_coloring, vertex 103, color None
# In node_coloring, vertex 107, color None
# In node_coloring, vertex 159, color None
# In node_coloring, vertex 210, color None
# In node_coloring, vertex 238, color None
# In node_coloring, vertex 310, color None
# In node_coloring, vertex 345, color None
# In node_coloring, vertex 347, color None
# In node_coloring, vertex 360, color None
# In node_coloring, vertex 463, color None
# In node_coloring, vertex 547, color None
# In node_coloring, vertex 563, color None
# In node_coloring, vertex 570, color None
# In node_coloring, vertex 587, color None
# In node_coloring, vertex 622, color None
# In node_coloring, vertex 713, color None
# In node_coloring, vertex 735, color None
# In node_coloring, vertex 743, color None
# In node_coloring, vertex 752, color None
# In node_coloring, vertex 811, color None
# In node_coloring, vertex 840, color None
# In node_coloring, vertex 908, color None
# In node_coloring, vertex 998, color None
# In node_coloring, vertex 17, color None
# In node_coloring, vertex 78, color None
# In node_coloring, vertex 91, color None
# In node_coloring, vertex 122, color None
# In node_coloring, vertex 216, color None
# In node_coloring, vertex 249, color None
# In node_coloring, vertex 253, color None
# In node_coloring, vertex 256, color None
# In node_coloring, vertex 292, color None
# In node_coloring, vertex 372, color None
# In node_coloring, vertex 399, color None
# In node_coloring, vertex 422, color None
# In node_coloring, vertex 432, color None
# In node_coloring, vertex 458, color None
# In node_coloring, vertex 462, color None
# In node_coloring, vertex 483, color None
# In node_coloring, vertex 485, color None
# In node_coloring, vertex 552, color None
# In node_coloring, vertex 737, color None
# In node_coloring, vertex 770, color None
# In node_coloring, vertex 837, color None
# In node_coloring, vertex 855, color None
# In node_coloring, vertex 900, color None
# In node_coloring, vertex 902, color None
# In node_coloring, vertex 951, color None
# In node_coloring, vertex 956, color None
# In node_coloring, vertex 976, color None
# In node_coloring, vertex 31, color None
# In node_coloring, vertex 42, color None
# In node_coloring, vertex 63, color None
# In node_coloring, vertex 89, color None
# In node_coloring, vertex 100, color None
# In node_coloring, vertex 162, color None
# In node_coloring, vertex 186, color None
# In node_coloring, vertex 242, color None
# In node_coloring, vertex 306, color None
# In node_coloring, vertex 314, color None
# In node_coloring, vertex 330, color None
# In node_coloring, vertex 354, color None
# In node_coloring, vertex 362, color None
# In node_coloring, vertex 423, color None
# In node_coloring, vertex 482, color None
# In node_coloring, vertex 491, color None
# In node_coloring, vertex 511, color None
# In node_coloring, vertex 580, color None
# In node_coloring, vertex 629, color None
# In node_coloring, vertex 643, color None
# In node_coloring, vertex 651, color None
# In node_coloring, vertex 793, color None
# In node_coloring, vertex 799, color None
# In node_coloring, vertex 803, color None
# In node_coloring, vertex 839, color None
# In node_coloring, vertex 854, color None
# In node_coloring, vertex 864, color None
# In node_coloring, vertex 21, color None
# In node_coloring, vertex 48, color None
# In node_coloring, vertex 73, color None
# In node_coloring, vertex 157, color None
# In node_coloring, vertex 171, color None
# In node_coloring, vertex 297, color None
# In node_coloring, vertex 312, color None
# In node_coloring, vertex 316, color None
# In node_coloring, vertex 373, color None
# In node_coloring, vertex 387, color None
# In node_coloring, vertex 391, color None
# In node_coloring, vertex 413, color None
# In node_coloring, vertex 426, color None
# In node_coloring, vertex 427, color None
# In node_coloring, vertex 428, color None
# In node_coloring, vertex 435, color None
# In node_coloring, vertex 503, color None
# In node_coloring, vertex 504, color None
# In node_coloring, vertex 596, color None
# In node_coloring, vertex 604, color None
# In node_coloring, vertex 608, color None
# In node_coloring, vertex 621, color None
# In node_coloring, vertex 761, color None
# In node_coloring, vertex 874, color None
# In node_coloring, vertex 905, color None
# In node_coloring, vertex 932, color None
# In node_coloring, vertex 957, color None
# In node_coloring, vertex 58, color None
# In node_coloring, vertex 93, color None
# In node_coloring, vertex 148, color None
# In node_coloring, vertex 181, color None
# In node_coloring, vertex 382, color None
# In node_coloring, vertex 436, color None
# In node_coloring, vertex 526, color None
# In node_coloring, vertex 531, color None
# In node_coloring, vertex 584, color None
# In node_coloring, vertex 593, color None
# In node_coloring, vertex 719, color None
# In node_coloring, vertex 720, color None
# In node_coloring, vertex 781, color None
# In node_coloring, vertex 790, color None
# In node_coloring, vertex 794, color None
# In node_coloring, vertex 801, color None
# In node_coloring, vertex 889, color None
# In node_coloring, vertex 941, color None
# In node_coloring, vertex 944, color None
# In node_coloring, vertex 947, color None
# In node_coloring, vertex 948, color None
# In node_coloring, vertex 966, color None
# In node_coloring, vertex 75, color None
# In node_coloring, vertex 127, color None
# In node_coloring, vertex 279, color None
# In node_coloring, vertex 285, color None
# In node_coloring, vertex 449, color None
# In node_coloring, vertex 544, color None
# In node_coloring, vertex 562, color None
# In node_coloring, vertex 659, color None
# In node_coloring, vertex 674, color None
# In node_coloring, vertex 772, color None
# In node_coloring, vertex 783, color None
# In node_coloring, vertex 865, color None
# In node_coloring, vertex 914, color None
# In node_coloring, vertex 917, color None
# In node_coloring, vertex 949, color None
# In node_coloring, vertex 968, color None
# In node_coloring, vertex 14, color None
# In node_coloring, vertex 19, color None
# In node_coloring, vertex 124, color None
# In node_coloring, vertex 163, color None
# In node_coloring, vertex 207, color None
# In node_coloring, vertex 212, color None
# In node_coloring, vertex 246, color None
# In node_coloring, vertex 456, color None
# In node_coloring, vertex 529, color None
# In node_coloring, vertex 612, color None
# In node_coloring, vertex 634, color None
# In node_coloring, vertex 664, color None
# In node_coloring, vertex 722, color None
# In node_coloring, vertex 755, color None
# In node_coloring, vertex 775, color None
# In node_coloring, vertex 817, color None
# In node_coloring, vertex 904, color None
# In node_coloring, vertex 918, color None
# In node_coloring, vertex 105, color None
# In node_coloring, vertex 114, color None
# In node_coloring, vertex 239, color None
# In node_coloring, vertex 250, color None
# In node_coloring, vertex 341, color None
# In node_coloring, vertex 380, color None
# In node_coloring, vertex 383, color None
# In node_coloring, vertex 691, color None
# In node_coloring, vertex 708, color None
# In node_coloring, vertex 721, color None
# In node_coloring, vertex 766, color None
# In node_coloring, vertex 833, color None
# In node_coloring, vertex 922, color None
# In node_coloring, vertex 985, color None
# In node_coloring, vertex 987, color None
# In node_coloring, vertex 33, color None
# In node_coloring, vertex 84, color None
# In child_node_checking, vertex 816, color None
# In child_node_checking, parent vertex 84 with degree 686, child vertex 816 with degree 686 set to color 0
# In node_coloring, vertex 118, color None
# In node_coloring, vertex 146, color None
# In node_coloring, vertex 257, color None
# In node_coloring, vertex 338, color None
# In node_coloring, vertex 414, color None
# In node_coloring, vertex 416, color None
# In node_coloring, vertex 419, color None
# In node_coloring, vertex 471, color None
# In node_coloring, vertex 601, color None
# In node_coloring, vertex 630, color None
# In node_coloring, vertex 760, color None
# In node_coloring, vertex 862, color None
# In node_coloring, vertex 892, color None
# In node_coloring, vertex 953, color None
# In node_coloring, vertex 7, color None
# In node_coloring, vertex 112, color None
# In node_coloring, vertex 117, color None
# In node_coloring, vertex 160, color None
# In node_coloring, vertex 199, color None
# In node_coloring, vertex 201, color None
# In node_coloring, vertex 208, color None
# In node_coloring, vertex 222, color None
# In node_coloring, vertex 304, color None
# In node_coloring, vertex 441, color None
# In node_coloring, vertex 443, color None
# In node_coloring, vertex 492, color None
# In node_coloring, vertex 514, color None
# In node_coloring, vertex 553, color None
# In node_coloring, vertex 687, color None
# In node_coloring, vertex 741, color None
# In node_coloring, vertex 827, color None
# In node_coloring, vertex 852, color None
# In node_coloring, vertex 942, color None
# In node_coloring, vertex 24, color None
# In node_coloring, vertex 26, color None
# In node_coloring, vertex 56, color None
# In node_coloring, vertex 113, color None
# In node_coloring, vertex 133, color None
# In node_coloring, vertex 183, color None
# In node_coloring, vertex 190, color None
# In node_coloring, vertex 344, color None
# In node_coloring, vertex 478, color None
# In node_coloring, vertex 486, color None
# In node_coloring, vertex 575, color None
# In node_coloring, vertex 618, color None
# In node_coloring, vertex 727, color None
# In node_coloring, vertex 824, color None
# In node_coloring, vertex 886, color None
# In node_coloring, vertex 959, color None
# In node_coloring, vertex 994, color None
# In node_coloring, vertex 138, color None
# In node_coloring, vertex 156, color None
# In node_coloring, vertex 172, color None
# In node_coloring, vertex 268, color None
# In node_coloring, vertex 308, color None
# In node_coloring, vertex 350, color None
# In node_coloring, vertex 530, color None
# In node_coloring, vertex 595, color None
# In node_coloring, vertex 615, color None
# In node_coloring, vertex 791, color None
# In node_coloring, vertex 808, color None
# In node_coloring, vertex 897, color None
# In node_coloring, vertex 933, color None
# In node_coloring, vertex 937, color None
# In node_coloring, vertex 946, color None
# In node_coloring, vertex 982, color None
# In node_coloring, vertex 179, color None
# In node_coloring, vertex 228, color None
# In node_coloring, vertex 265, color None
# In node_coloring, vertex 402, color None
# In node_coloring, vertex 600, color None
# In node_coloring, vertex 620, color None
# In node_coloring, vertex 624, color None
# In node_coloring, vertex 654, color None
# In node_coloring, vertex 712, color None
# In node_coloring, vertex 729, color None
# In node_coloring, vertex 734, color None
# In node_coloring, vertex 925, color None
# In node_coloring, vertex 145, color None
# In node_coloring, vertex 367, color None
# In node_coloring, vertex 378, color None
# In node_coloring, vertex 452, color None
# In node_coloring, vertex 467, color None
# In node_coloring, vertex 525, color None
# In node_coloring, vertex 701, color None
# In node_coloring, vertex 798, color None
# In node_coloring, vertex 9, color None
# In node_coloring, vertex 30, color None
# In node_coloring, vertex 74, color None
# In node_coloring, vertex 104, color None
# In node_coloring, vertex 131, color None
# In node_coloring, vertex 155, color None
# In node_coloring, vertex 346, color None
# In node_coloring, vertex 355, color None
# In node_coloring, vertex 357, color None
# In node_coloring, vertex 370, color None
# In node_coloring, vertex 442, color None
# In node_coloring, vertex 470, color None
# In node_coloring, vertex 660, color None
# In node_coloring, vertex 750, color None
# In node_coloring, vertex 836, color None
# In node_coloring, vertex 229, color None
# In node_coloring, vertex 317, color None
# In node_coloring, vertex 401, color None
# In node_coloring, vertex 447, color None
# In node_coloring, vertex 671, color None
# In node_coloring, vertex 844, color None
# In node_coloring, vertex 938, color None
# In node_coloring, vertex 43, color None
# In node_coloring, vertex 69, color None
# In node_coloring, vertex 339, color None
# In node_coloring, vertex 368, color None
# In node_coloring, vertex 433, color None
# In node_coloring, vertex 696, color None
# In node_coloring, vertex 776, color None
# In node_coloring, vertex 832, color None
# In node_coloring, vertex 877, color None
# In node_coloring, vertex 950, color None
# In node_coloring, vertex 981, color None
# In node_coloring, vertex 10, color None
# In node_coloring, vertex 234, color None
# In node_coloring, vertex 299, color None
# In node_coloring, vertex 141, color None
# In node_coloring, vertex 539, color None
# In node_coloring, vertex 586, color None
# In node_coloring, vertex 606, color None
# In node_coloring, vertex 736, color None
# In node_coloring, vertex 771, color None
# In node_coloring, vertex 786, color None
# In node_coloring, vertex 934, color None
# In node_coloring, vertex 939, color None
# In node_coloring, vertex 92, color None
# In node_coloring, vertex 158, color None
# In node_coloring, vertex 174, color None
# In node_coloring, vertex 275, color None
# In node_coloring, vertex 451, color None
# In node_coloring, vertex 568, color None
# In node_coloring, vertex 732, color None
# In node_coloring, vertex 866, color None
# In node_coloring, vertex 214, color None
# In node_coloring, vertex 218, color None
# In node_coloring, vertex 296, color None
# In node_coloring, vertex 448, color None
# In node_coloring, vertex 911, color None
# In node_coloring, vertex 2, color None
# In node_coloring, vertex 460, color None
# In node_coloring, vertex 695, color None
# In node_coloring, vertex 731, color None
# In node_coloring, vertex 936, color None
# In node_coloring, vertex 990, color None
# In node_coloring, vertex 408, color None
# In node_coloring, vertex 474, color None
# In node_coloring, vertex 639, color None
# In node_coloring, vertex 895, color None
# In node_coloring, vertex 365, color None
# In node_coloring, vertex 261, color None
# In node_coloring, vertex 429, color None
# In node_coloring, vertex 533, color None
# In node_coloring, vertex 549, color None
# In node_coloring, vertex 835, color None
# In node_coloring, vertex 888, color None
# In node_coloring, vertex 327, color None
# In node_coloring, vertex 388, color None
# In node_coloring, vertex 657, color None
# In node_coloring, vertex 34, color None
# In node_coloring, vertex 115, color None
# In node_coloring, vertex 135, color None
# In node_coloring, vertex 379, color None
# In node_coloring, vertex 140, color None
# In node_coloring, vertex 974, color None
# In node_coloring, vertex 464, color None
# In node_coloring, vertex 842, color None
# In node_coloring, vertex 235, color None
# In node_coloring, vertex 730, color None
# In node_coloring, vertex 658, color None
# In node_coloring, vertex 763, color None
#
#
# Vertex colors
