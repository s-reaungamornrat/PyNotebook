# %%
import os
import csv
import heapq
import numpy as np

# %%
data_folder = 'C:/D/coursera/discrete_opt/coloring/data'
data_files = None
for dirpath, dirnames, filenames in os.walk(data_folder):
    data_files = [os.path.join(dirpath, fname) for fname in filenames if fname[:2] == 'gc' and fname[-3:] != 'txt'\
                 and fname[-3:] != 'put']
    
filepaths = list(reversed(data_files))
print('File paths \n', filepaths)
# Out:
# File paths
#  ['C:/D/coursera/discrete_opt/coloring/data\\gc_70_9', 'C:/D/coursera/discrete_opt/coloring/data\\gc_70_7', 'C:/D/coursera/discrete_opt/coloring/data\\gc_70_5', 'C:/D/coursera/discrete_opt/coloring/data\\gc_70_3', 'C:/D/coursera/discrete_opt/coloring/data\\gc_70_1', 'C:/D/coursera/discrete_opt/coloring/data\\gc_50_9', 'C:/D/coursera/discrete_opt/coloring/data\\gc_50_7', 'C:/D/coursera/discrete_opt/coloring/data\\gc_50_5', 'C:/D/coursera/discrete_opt/coloring/data\\gc_50_3', 'C:/D/coursera/discrete_opt/coloring/data\\gc_50_1', 'C:/D/coursera/discrete_opt/coloring/data\\gc_500_9', 'C:/D/coursera/discrete_opt/coloring/data\\gc_500_7', 'C:/D/coursera/discrete_opt/coloring/data\\gc_500_5', 'C:/D/coursera/discrete_opt/coloring/data\\gc_500_3', 'C:/D/coursera/discrete_opt/coloring/data\\gc_500_1', 'C:/D/coursera/discrete_opt/coloring/data\\gc_4_1', 'C:/D/coursera/discrete_opt/coloring/data\\gc_250_9', 'C:/D/coursera/discrete_opt/coloring/data\\gc_250_7', 'C:/D/coursera/discrete_opt/coloring/data\\gc_250_5', 'C:/D/coursera/discrete_opt/coloring/data\\gc_250_3', 'C:/D/coursera/discrete_opt/coloring/data\\gc_250_1', 'C:/D/coursera/discrete_opt/coloring/data\\gc_20_9', 'C:/D/coursera/discrete_opt/coloring/data\\gc_20_7', 'C:/D/coursera/discrete_opt/coloring/data\\gc_20_5', 'C:/D/coursera/discrete_opt/coloring/data\\gc_20_3', 'C:/D/coursera/discrete_opt/coloring/data\\gc_20_1', 'C:/D/coursera/discrete_opt/coloring/data\\gc_11_16', 'C:/D/coursera/discrete_opt/coloring/data\\gc_100_9', 'C:/D/coursera/discrete_opt/coloring/data\\gc_100_7', 'C:/D/coursera/discrete_opt/coloring/data\\gc_100_5', 'C:/D/coursera/discrete_opt/coloring/data\\gc_100_3', 'C:/D/coursera/discrete_opt/coloring/data\\gc_100_1', 'C:/D/coursera/discrete_opt/coloring/data\\gc_1000_9', 'C:/D/coursera/discrete_opt/coloring/data\\gc_1000_7', 'C:/D/coursera/discrete_opt/coloring/data\\gc_1000_5', 'C:/D/coursera/discrete_opt/coloring/data\\gc_1000_3', 'C:/D/coursera/discrete_opt/coloring/data\\gc_1000_1']

# %%
class Node:
    
    def __init__(self, parent = None, color= None, index = -1, degree = -1):
        
        self.color = color
        self.index = index
        self.degree = degree
        self.parent = parent
        self.child_indices = []
        self.depth = 0
        if parent:
            self.depth = parent.depth+1    
            
    def __repr__(self):
        """Use by calling repr(node)"""
        return "Node(c: " + repr(self.color) + ", idx: " + repr(self.index) + ", deg: " + repr(self.degree) + ")"    
    
    def expand(self, index):
        if index in self.child_indices:
            #print('Index already exists in the children list')
            return False
        else:
            self.child_indices.append(index)
            #print('Node %d: add child index %d' % (self.index, index))
            return True
            
    def set_color(self, color):
        self.color = color
        
    def __lt__(self, other):
        return self.degree > other.degree
    
# class NodeInfo:
    
#     def __init__(self, index=-1, degree=-1):
#         self.index = index
#         self.degree = degree
       
#     def __repr__(self):
#         """Use by calling repr(node)"""
#         return "Node info(idx: " + repr(self.index) + ", deg: " + repr(self.degree) + ")"      
        
#     def __lt__(self, other):
#         return self.degree > other.degree
    
class Graph:# undirected
    
    def __init__(self, edges=None, root=None):
        self.edges = None
        self.root = None
        self.vertices = dict()#[]# index to the list denotes the vertex index
        #self.vertex_info = []# heapq collecting index and degree
        
    def add_vertex(self, index, child):
        #print('In add_vertex, ', self.vertices ) 
        if index in self.vertices: #index < len(self.vertices):
            self.vertices[index].degree += 1
            #self.vertex_info[index].degree +=1
            #print('In add_vertex, Add degree to vertex %d' % index)
            #print('Index %d, Vertex degree %d' % (index, self.vertices[index].degree))
        else:
            parent, color, degree = None, None, 1
            self.vertices[index] = Node(parent, color, index, degree)
            #self.vertex_info.append(NodeInfo(index, degree))
            #print('Index {}, Node {}'.format(index, self.vertices[index]))
            #print('In add_vertex, Add new vertex %d' % index)
        self.vertices[index].expand(child)
        
        #print('Vertices \n', self.vertices)
        #heapq.heapify(self.vertices)
        #print('Vertex Info\n', self.vertex_info)        
            
    def set_edges(self,edges):
        self.edges = edges
        for edge in edges:
            # build a list of vertices
            self.add_vertex(edge[0], edge[1])
            self.add_vertex(edge[1], edge[0])
            
        #print('Vertices \n', self.vertices)
        #heapq.heapify(self.vertices)
        #print('Vertex Info\n', self.vertex_info)
        
    def print_graph(self):
        for index, vertex in self.vertices.items():
            rep = "Index " + str(index) + ", Node(c: " + str(vertex.color) + ", idx: " + str(vertex.index) + ", deg: " + str(vertex.degree)
            if vertex.child_indices:
                rep = rep + ", children: "+','.join([ str(child) for child in vertex.child_indices]) + ' )'
            print(rep)

# %%
# child have different color than parent
def print_graph(vertices):
    
    for index, vertex in vertices.items():
        rep = "Index " + str(index) + ", Node(c: " + str(vertex.color) + ", idx: " + str(vertex.index) + ", deg: " + str(vertex.degree)
        if vertex.child_indices:
            rep = rep + ", children: "+','.join([ str(child) for child in vertex.child_indices]) + ' )'
        print(rep)

def get_color(colors, lower_bound, upper_bound):
    
    color = None
    if not colors: color = 0
    else: color = max(colors)+1
    
    #if color <= lower_bound or color > upper_bound:
    if color > upper_bound:
        raise ValueError('Color is below the lower bound or over the upper bound')
        
    return color
                
def node_coloring(index, colors, vertices, lower_bound, upper_bound, color_frequency):
    
    #print('In node_coloring, vertex {}, color {}'.format(index, vertices[index].color))
    if vertices[index].color != None: 
        #print('Vertex %d already explored' % index)
        return False
        
    child_colors = set([vertices[cidx].color for cidx in vertices[index].child_indices if vertices[cidx].color != None])
    color, usable_colors = None, None
    
    usable_colors = colors.difference(child_colors)
    
    #print('\nIn vertex {}, Num children {}'.format(index, len(vertices[index].child_indices)))
    #print('Colors {}, Child colors {}, Usable color {}'.format(colors,child_colors,usable_colors))
    
    if usable_colors:    
    
        frequency, np_usable_color = [], None
        for u in usable_colors:
            frequency.append(color_frequency[u])
        sorted_indices = sorted(range(len(frequency)), key=lambda k: frequency[k], reverse=True)
        np_usable_color = np.asarray(list(usable_colors))
        np_usable_color = np_usable_color[sorted_indices]
        
        if np_usable_color.size > 0: color = np_usable_color[0] # [-1] --> 216
        else: color = usable_colors.pop()
        #print('Use existing color %d' % color)
    else: # every color in children are in colors
        color = get_color(colors, lower_bound, upper_bound)
        #print('Use new color %d' % color)
    if color in color_frequency: color_frequency[color] += 1
    else: color_frequency[color] = 0
    #print('In vertex %d, color %d' % (index, color))
            
    vertices[index].color = color
    colors.add(color)
    #print_graph(vertices)
    
    return True
    
def graph_coloring(vertices):
    
    explored = set()
    colors = set()
    color_frequency = dict()
    #heapq.heapify(vertex_info)
    vertex_info = []
    for idx, v in vertices.items():
        heapq.heappush(vertex_info, (-v.degree, v.index))
        
    #print('Original vertices\n', vertices)
    #print('Sorted vertex info\n', vertex_info)
    
    lower_bound, upper_bound = -vertex_info[0][0], len(vertex_info)
    #print('Lower c bound %d, higher bound %d ' % (lower_bound, upper_bound))
    
    while vertex_info:

        vinfo = heapq.heappop(vertex_info)
        #print('\n\n New vertex %d with degree %d' % (vinfo[1], -vinfo[0]))
        
        index = vinfo[1]
        if index in explored: continue
            
        flag = node_coloring(index, colors, vertices, lower_bound, upper_bound, color_frequency)
        if flag: explored.add(index)
            
        for cidx in vertices[index].child_indices:
            flag = node_coloring(cidx, colors, vertices, lower_bound, upper_bound, color_frequency)
            if flag: explored.add(cidx)
                
        #print('Explored node indices ', explored)
        #print('Used colors ', colors)
        #print_graph(vertices)
    
    #selected_colors = [vertices[i].color for i in range(len(vertices))]
    return len(colors), [vertices[i].color for i in range(len(vertices))], vertices, color_frequency

# %%
def solve_it(input_data):
    # Modify this code to run your optimization algorithm

    # parse the input
    lines = input_data.split('\n')

    first_line = lines[0].split()
    node_count = int(first_line[0])
    edge_count = int(first_line[1])
    #print('Node count %d, edge count %d' % (node_count, edge_count))

    edges = []
    for i in range(1, edge_count + 1):
        line = lines[i]
        parts = line.split()
        edges.append((int(parts[0]), int(parts[1])))
        
    #### play with graph
    graph = Graph()
    graph.set_edges(edges)
    #graph.print_graph()
    #print('---------------Start graph coloring ------------------')
    num_colors, solution, vertices, color_frequency = graph_coloring(graph.vertices)
    #print('Vertices ', vertices)
    vertex_colors = [(v.index, v.color) for k, v in vertices.items()]
    #print('Vertex color', [(v.index, v.color) for v in vertices])
    
    #######
    # build a trivial solution
    # every node has its own color

    # prepare the solution in the specified output format
    output_data = str(num_colors) + ' ' + str(0) + '\n'
    output_data += ' '.join(map(str, solution))

    return output_data#, vertex_colors, color_frequency

# %%
filename = os.path.join(data_folder,'gc_1000_7')
with open(filename, 'r') as input_data_file:
    input_data = input_data_file.read()
    
output, vertex_colors, color_frequency = solve_it(input_data)
print('\n\nVertex colors\n', vertex_colors)
print('\n\nColors frequence\n', color_frequency)
print('\n\n Output\n', output)
# Out:
# ---------------Start graph coloring ------------------
# In node_coloring, vertex 579, color None
# In vertex 579, color 0
# In node_coloring, vertex 0, color None
# In vertex 0, color 1
# In node_coloring, vertex 1, color None
# In vertex 1, color 2
# In node_coloring, vertex 2, color None
# In vertex 2, color 3
# In node_coloring, vertex 3, color None
# In vertex 3, color 4
# In node_coloring, vertex 4, color None
# In vertex 4, color 1
# In node_coloring, vertex 7, color None
# In vertex 7, color 2
# In node_coloring, vertex 8, color None
# In vertex 8, color 5
# In node_coloring, vertex 9, color None
# In vertex 9, color 3
# In node_coloring, vertex 10, color None
# In vertex 10, color 6
# In node_coloring, vertex 11, color None
# In vertex 11, color 4
# In node_coloring, vertex 12, color None
# In vertex 12, color 3
# In node_coloring, vertex 13, color None
# In vertex 13, color 6
# In node_coloring, vertex 14, color None
# In vertex 14, color 7
# In node_coloring, vertex 15, color None
# In vertex 15, color 8
# In node_coloring, vertex 16, color None
# In vertex 16, color 8
# In node_coloring, vertex 17, color None
# In vertex 17, color 2
# In node_coloring, vertex 18, color None
# In vertex 18, color 9
# In node_coloring, vertex 19, color None
# In vertex 19, color 7
# In node_coloring, vertex 20, color None
# In vertex 20, color 10
# In node_coloring, vertex 21, color None
# In vertex 21, color 1
# In node_coloring, vertex 22, color None
# In vertex 22, color 4
# In node_coloring, vertex 23, color None
# In vertex 23, color 3
# In node_coloring, vertex 24, color None
# In vertex 24, color 9
# In node_coloring, vertex 25, color None
# In vertex 25, color 11
# In node_coloring, vertex 26, color None
# In vertex 26, color 8
# In node_coloring, vertex 27, color None
# In vertex 27, color 5
# In node_coloring, vertex 28, color None
# In vertex 28, color 11
# In node_coloring, vertex 29, color None
# In vertex 29, color 2
# In node_coloring, vertex 32, color None
# In vertex 32, color 11
# In node_coloring, vertex 33, color None
# In vertex 33, color 12
# In node_coloring, vertex 34, color None
# In vertex 34, color 12
# In node_coloring, vertex 36, color None
# In vertex 36, color 9
# In node_coloring, vertex 37, color None
# In vertex 37, color 13
# In node_coloring, vertex 38, color None
# In vertex 38, color 13
# In node_coloring, vertex 39, color None
# In vertex 39, color 4
# In node_coloring, vertex 40, color None
# In vertex 40, color 14
# In node_coloring, vertex 45, color None
# In vertex 45, color 15
# In node_coloring, vertex 46, color None
# In vertex 46, color 12
# In node_coloring, vertex 47, color None
# In vertex 47, color 16
# In node_coloring, vertex 48, color None
# In vertex 48, color 14
# In node_coloring, vertex 49, color None
# In vertex 49, color 7
# In node_coloring, vertex 50, color None
# In vertex 50, color 17
# In node_coloring, vertex 51, color None
# In vertex 51, color 18
# In node_coloring, vertex 52, color None
# In vertex 52, color 17
# In node_coloring, vertex 53, color None
# In vertex 53, color 5
# In node_coloring, vertex 54, color None
# In vertex 54, color 12
# In node_coloring, vertex 55, color None
# In vertex 55, color 17
# In node_coloring, vertex 57, color None
# In vertex 57, color 14
# In node_coloring, vertex 58, color None
# In vertex 58, color 13
# In node_coloring, vertex 63, color None
# In vertex 63, color 18
# In node_coloring, vertex 64, color None
# In vertex 64, color 9
# In node_coloring, vertex 65, color None
# In vertex 65, color 19
# In node_coloring, vertex 66, color None
# In vertex 66, color 10
# In node_coloring, vertex 68, color None
# In vertex 68, color 19
# In node_coloring, vertex 69, color None
# In vertex 69, color 16
# In node_coloring, vertex 70, color None
# In vertex 70, color 6
# In node_coloring, vertex 72, color None
# In vertex 72, color 11
# In node_coloring, vertex 73, color None
# In vertex 73, color 15
# In node_coloring, vertex 74, color None
# In vertex 74, color 14
# In node_coloring, vertex 75, color None
# In vertex 75, color 20
# In node_coloring, vertex 76, color None
# In vertex 76, color 15
# In node_coloring, vertex 79, color None
# In vertex 79, color 19
# In node_coloring, vertex 80, color None
# In vertex 80, color 15
# In node_coloring, vertex 81, color None
# In vertex 81, color 20
# In node_coloring, vertex 83, color None
# In vertex 83, color 5
# In node_coloring, vertex 84, color None
# In vertex 84, color 16
# In node_coloring, vertex 85, color None
# In vertex 85, color 17
# In node_coloring, vertex 86, color None
# In vertex 86, color 16
# In node_coloring, vertex 87, color None
# In vertex 87, color 21
# In node_coloring, vertex 88, color None
# In vertex 88, color 22
# In node_coloring, vertex 89, color None
# In vertex 89, color 21
# In node_coloring, vertex 90, color None
# In vertex 90, color 23
# In node_coloring, vertex 92, color None
# In vertex 92, color 18
# In node_coloring, vertex 93, color None
# In vertex 93, color 23
# In node_coloring, vertex 94, color None
# In vertex 94, color 24
# In node_coloring, vertex 96, color None
# In vertex 96, color 24
# In node_coloring, vertex 98, color None
# In vertex 98, color 10
# In node_coloring, vertex 99, color None
# In vertex 99, color 20
# In node_coloring, vertex 100, color None
# In vertex 100, color 24
# In node_coloring, vertex 101, color None
# In vertex 101, color 25
# In node_coloring, vertex 102, color None
# In vertex 102, color 22
# In node_coloring, vertex 103, color None
# In vertex 103, color 17
# In node_coloring, vertex 104, color None
# In vertex 104, color 7
# In node_coloring, vertex 105, color None
# In vertex 105, color 5
# In node_coloring, vertex 108, color None
# In vertex 108, color 26
# In node_coloring, vertex 110, color None
# In vertex 110, color 27
# In node_coloring, vertex 111, color None
# In vertex 111, color 23
# In node_coloring, vertex 113, color None
# In vertex 113, color 13
# In node_coloring, vertex 115, color None
# In vertex 115, color 10
# In node_coloring, vertex 116, color None
# In vertex 116, color 28
# In node_coloring, vertex 117, color None
# In vertex 117, color 24
# In node_coloring, vertex 118, color None
# In vertex 118, color 22
# In node_coloring, vertex 119, color None
# In vertex 119, color 19
# In node_coloring, vertex 120, color None
# In vertex 120, color 26
# In node_coloring, vertex 121, color None
# In vertex 121, color 21
# In node_coloring, vertex 122, color None
# In vertex 122, color 29
# In node_coloring, vertex 123, color None
# In vertex 123, color 25
# In node_coloring, vertex 126, color None
# In vertex 126, color 28
# In node_coloring, vertex 128, color None
# In vertex 128, color 30
# In node_coloring, vertex 129, color None
# In vertex 129, color 27
# In node_coloring, vertex 131, color None
# In vertex 131, color 13
# In node_coloring, vertex 132, color None
# In vertex 132, color 8
# In node_coloring, vertex 134, color None
# In vertex 134, color 26
# In node_coloring, vertex 135, color None
# In vertex 135, color 30
# In node_coloring, vertex 136, color None
# In vertex 136, color 21
# In node_coloring, vertex 137, color None
# In vertex 137, color 29
# In node_coloring, vertex 138, color None
# In vertex 138, color 31
# In node_coloring, vertex 139, color None
# In vertex 139, color 32
# In node_coloring, vertex 140, color None
# In vertex 140, color 4
# In node_coloring, vertex 141, color None
# In vertex 141, color 22
# In node_coloring, vertex 142, color None
# In vertex 142, color 31
# In node_coloring, vertex 143, color None
# In vertex 143, color 25
# In node_coloring, vertex 146, color None
# In vertex 146, color 9
# In node_coloring, vertex 147, color None
# In vertex 147, color 25
# In node_coloring, vertex 149, color None
# In vertex 149, color 33
# In node_coloring, vertex 150, color None
# In vertex 150, color 31
# In node_coloring, vertex 151, color None
# In vertex 151, color 30
# In node_coloring, vertex 152, color None
# In vertex 152, color 25
# In node_coloring, vertex 153, color None
# In vertex 153, color 4
# In node_coloring, vertex 155, color None
# In vertex 155, color 34
# In node_coloring, vertex 157, color None
# In vertex 157, color 27
# In node_coloring, vertex 159, color None
# In vertex 159, color 27
# In node_coloring, vertex 160, color None
# In vertex 160, color 23
# In node_coloring, vertex 161, color None
# In vertex 161, color 35
# In node_coloring, vertex 163, color None
# In vertex 163, color 32
# In node_coloring, vertex 164, color None
# In vertex 164, color 34
# In node_coloring, vertex 165, color None
# In vertex 165, color 36
# In node_coloring, vertex 166, color None
# In vertex 166, color 37
# In node_coloring, vertex 167, color None
# In vertex 167, color 33
# In node_coloring, vertex 168, color None
# In vertex 168, color 28
# In node_coloring, vertex 170, color None
# In vertex 170, color 29
# In node_coloring, vertex 173, color None
# In vertex 173, color 34
# In node_coloring, vertex 174, color None
# In vertex 174, color 37
# In node_coloring, vertex 175, color None
# In vertex 175, color 38
# In node_coloring, vertex 176, color None
# In vertex 176, color 38
# In node_coloring, vertex 178, color None
# In vertex 178, color 1
# In node_coloring, vertex 181, color None
# In vertex 181, color 30
# In node_coloring, vertex 182, color None
# In vertex 182, color 39
# In node_coloring, vertex 183, color None
# In vertex 183, color 40
# In node_coloring, vertex 185, color None
# In vertex 185, color 37
# In node_coloring, vertex 187, color None
# In vertex 187, color 29
# In node_coloring, vertex 189, color None
# In vertex 189, color 39
# In node_coloring, vertex 190, color None
# In vertex 190, color 40
# In node_coloring, vertex 192, color None
# In vertex 192, color 41
# In node_coloring, vertex 193, color None
# In vertex 193, color 18
# In node_coloring, vertex 194, color None
# In vertex 194, color 32
# In node_coloring, vertex 195, color None
# In vertex 195, color 40
# In node_coloring, vertex 196, color None
# In vertex 196, color 35
# In node_coloring, vertex 197, color None
# In vertex 197, color 33
# In node_coloring, vertex 198, color None
# In vertex 198, color 41
# In node_coloring, vertex 199, color None
# In vertex 199, color 12
# In node_coloring, vertex 200, color None
# In vertex 200, color 39
# In node_coloring, vertex 201, color None
# In vertex 201, color 42
# In node_coloring, vertex 202, color None
# In vertex 202, color 19
# In node_coloring, vertex 203, color None
# In vertex 203, color 43
# In node_coloring, vertex 205, color None
# In vertex 205, color 26
# In node_coloring, vertex 206, color None
# In vertex 206, color 31
# In node_coloring, vertex 209, color None
# In vertex 209, color 44
# In node_coloring, vertex 210, color None
# In vertex 210, color 35
# In node_coloring, vertex 211, color None
# In vertex 211, color 42
# In node_coloring, vertex 214, color None
# In vertex 214, color 34
# In node_coloring, vertex 215, color None
# In vertex 215, color 43
# In node_coloring, vertex 216, color None
# In vertex 216, color 37
# In node_coloring, vertex 217, color None
# In vertex 217, color 36
# In node_coloring, vertex 220, color None
# In vertex 220, color 45
# In node_coloring, vertex 223, color None
# In vertex 223, color 35
# In node_coloring, vertex 224, color None
# In vertex 224, color 46
# In node_coloring, vertex 226, color None
# In vertex 226, color 47
# In node_coloring, vertex 227, color None
# In vertex 227, color 28
# In node_coloring, vertex 230, color None
# In vertex 230, color 47
# In node_coloring, vertex 231, color None
# In vertex 231, color 45
# In node_coloring, vertex 233, color None
# In vertex 233, color 48
# In node_coloring, vertex 235, color None
# In vertex 235, color 7
# In node_coloring, vertex 236, color None
# In vertex 236, color 46
# In node_coloring, vertex 237, color None
# In vertex 237, color 33
# In node_coloring, vertex 238, color None
# In vertex 238, color 48
# In node_coloring, vertex 239, color None
# In vertex 239, color 49
# In node_coloring, vertex 240, color None
# In vertex 240, color 50
# In node_coloring, vertex 241, color None
# In vertex 241, color 51
# In node_coloring, vertex 242, color None
# In vertex 242, color 52
# In node_coloring, vertex 243, color None
# In vertex 243, color 23
# In node_coloring, vertex 244, color None
# In vertex 244, color 36
# In node_coloring, vertex 245, color None
# In vertex 245, color 20
# In node_coloring, vertex 246, color None
# In vertex 246, color 50
# In node_coloring, vertex 247, color None
# In vertex 247, color 51
# In node_coloring, vertex 249, color None
# In vertex 249, color 48
# In node_coloring, vertex 251, color None
# In vertex 251, color 42
# In node_coloring, vertex 252, color None
# In vertex 252, color 22
# In node_coloring, vertex 253, color None
# In vertex 253, color 22
# In node_coloring, vertex 255, color None
# In vertex 255, color 49
# In node_coloring, vertex 256, color None
# In vertex 256, color 49
# In node_coloring, vertex 258, color None
# In vertex 258, color 32
# In node_coloring, vertex 259, color None
# In vertex 259, color 20
# In node_coloring, vertex 260, color None
# In vertex 260, color 35
# In node_coloring, vertex 261, color None
# In vertex 261, color 46
# In node_coloring, vertex 262, color None
# In vertex 262, color 51
# In node_coloring, vertex 263, color None
# In vertex 263, color 14
# In node_coloring, vertex 265, color None
# In vertex 265, color 41
# In node_coloring, vertex 266, color None
# In vertex 266, color 53
# In node_coloring, vertex 267, color None
# In vertex 267, color 45
# In node_coloring, vertex 268, color None
# In vertex 268, color 6
# In node_coloring, vertex 269, color None
# In vertex 269, color 53
# In node_coloring, vertex 271, color None
# In vertex 271, color 40
# In node_coloring, vertex 273, color None
# In vertex 273, color 43
# In node_coloring, vertex 275, color None
# In vertex 275, color 52
# In node_coloring, vertex 276, color None
# In vertex 276, color 37
# In node_coloring, vertex 277, color None
# In vertex 277, color 44
# In node_coloring, vertex 278, color None
# In vertex 278, color 36
# In node_coloring, vertex 280, color None
# In vertex 280, color 3
# In node_coloring, vertex 281, color None
# In vertex 281, color 54
# In node_coloring, vertex 282, color None
# In vertex 282, color 47
# In node_coloring, vertex 283, color None
# In vertex 283, color 45
# In node_coloring, vertex 285, color None
# In vertex 285, color 15
# In node_coloring, vertex 287, color None
# In vertex 287, color 6
# In node_coloring, vertex 288, color None
# In vertex 288, color 40
# In node_coloring, vertex 290, color None
# In vertex 290, color 43
# In node_coloring, vertex 291, color None
# In vertex 291, color 50
# In node_coloring, vertex 293, color None
# In vertex 293, color 44
# In node_coloring, vertex 294, color None
# In vertex 294, color 47
# In node_coloring, vertex 295, color None
# In vertex 295, color 1
# In node_coloring, vertex 296, color None
# In vertex 296, color 19
# In node_coloring, vertex 299, color None
# In vertex 299, color 55
# In node_coloring, vertex 300, color None
# In vertex 300, color 38
# In node_coloring, vertex 301, color None
# In vertex 301, color 55
# In node_coloring, vertex 304, color None
# In vertex 304, color 52
# In node_coloring, vertex 305, color None
# In vertex 305, color 44
# In node_coloring, vertex 306, color None
# In vertex 306, color 51
# In node_coloring, vertex 308, color None
# In vertex 308, color 31
# In node_coloring, vertex 309, color None
# In vertex 309, color 56
# In node_coloring, vertex 312, color None
# In vertex 312, color 55
# In node_coloring, vertex 313, color None
# In vertex 313, color 41
# In node_coloring, vertex 314, color None
# In vertex 314, color 57
# In node_coloring, vertex 315, color None
# In vertex 315, color 16
# In node_coloring, vertex 316, color None
# In vertex 316, color 53
# In node_coloring, vertex 318, color None
# In vertex 318, color 58
# In node_coloring, vertex 319, color None
# In vertex 319, color 38
# In node_coloring, vertex 320, color None
# In vertex 320, color 49
# In node_coloring, vertex 321, color None
# In vertex 321, color 50
# In node_coloring, vertex 322, color None
# In vertex 322, color 56
# In node_coloring, vertex 325, color None
# In vertex 325, color 57
# In node_coloring, vertex 326, color None
# In vertex 326, color 59
# In node_coloring, vertex 327, color None
# In vertex 327, color 41
# In node_coloring, vertex 328, color None
# In vertex 328, color 58
# In node_coloring, vertex 329, color None
# In vertex 329, color 60
# In node_coloring, vertex 330, color None
# In vertex 330, color 39
# In node_coloring, vertex 331, color None
# In vertex 331, color 46
# In node_coloring, vertex 332, color None
# In vertex 332, color 54
# In node_coloring, vertex 333, color None
# In vertex 333, color 28
# In node_coloring, vertex 334, color None
# In vertex 334, color 48
# In node_coloring, vertex 335, color None
# In vertex 335, color 61
# In node_coloring, vertex 336, color None
# In vertex 336, color 59
# In node_coloring, vertex 337, color None
# In vertex 337, color 57
# In node_coloring, vertex 338, color None
# In vertex 338, color 62
# In node_coloring, vertex 339, color None
# In vertex 339, color 63
# In node_coloring, vertex 340, color None
# In vertex 340, color 62
# In node_coloring, vertex 343, color None
# In vertex 343, color 64
# In node_coloring, vertex 345, color None
# In vertex 345, color 61
# In node_coloring, vertex 346, color None
# In vertex 346, color 52
# In node_coloring, vertex 347, color None
# In vertex 347, color 58
# In node_coloring, vertex 348, color None
# In vertex 348, color 53
# In node_coloring, vertex 349, color None
# In vertex 349, color 64
# In node_coloring, vertex 350, color None
# In vertex 350, color 60
# In node_coloring, vertex 351, color None
# In vertex 351, color 65
# In node_coloring, vertex 352, color None
# In vertex 352, color 66
# In node_coloring, vertex 354, color None
# In vertex 354, color 56
# In node_coloring, vertex 355, color None
# In vertex 355, color 36
# In node_coloring, vertex 356, color None
# In vertex 356, color 55
# In node_coloring, vertex 357, color None
# In vertex 357, color 67
# In node_coloring, vertex 358, color None
# In vertex 358, color 66
# In node_coloring, vertex 359, color None
# In vertex 359, color 65
# In node_coloring, vertex 360, color None
# In vertex 360, color 68
# In node_coloring, vertex 361, color None
# In vertex 361, color 49
# In node_coloring, vertex 362, color None
# In vertex 362, color 39
# In node_coloring, vertex 363, color None
# In vertex 363, color 64
# In node_coloring, vertex 364, color None
# In vertex 364, color 58
# In node_coloring, vertex 367, color None
# In vertex 367, color 50
# In node_coloring, vertex 368, color None
# In vertex 368, color 42
# In node_coloring, vertex 369, color None
# In vertex 369, color 5
# In node_coloring, vertex 370, color None
# In vertex 370, color 61
# In node_coloring, vertex 372, color None
# In vertex 372, color 24
# In node_coloring, vertex 373, color None
# In vertex 373, color 65
# In node_coloring, vertex 375, color None
# In vertex 375, color 33
# In node_coloring, vertex 376, color None
# In vertex 376, color 67
# In node_coloring, vertex 377, color None
# In vertex 377, color 11
# In node_coloring, vertex 378, color None
# In vertex 378, color 30
# In node_coloring, vertex 379, color None
# In vertex 379, color 64
# In node_coloring, vertex 380, color None
# In vertex 380, color 65
# In node_coloring, vertex 382, color None
# In vertex 382, color 27
# In node_coloring, vertex 383, color None
# In vertex 383, color 60
# In node_coloring, vertex 386, color None
# In vertex 386, color 68
# In node_coloring, vertex 387, color None
# In vertex 387, color 59
# In node_coloring, vertex 389, color None
# In vertex 389, color 68
# In node_coloring, vertex 391, color None
# In vertex 391, color 67
# In node_coloring, vertex 392, color None
# In vertex 392, color 61
# In node_coloring, vertex 393, color None
# In vertex 393, color 69
# In node_coloring, vertex 394, color None
# In vertex 394, color 70
# In node_coloring, vertex 396, color None
# In vertex 396, color 66
# In node_coloring, vertex 397, color None
# In vertex 397, color 69
# In node_coloring, vertex 399, color None
# In vertex 399, color 71
# In node_coloring, vertex 401, color None
# In vertex 401, color 70
# In node_coloring, vertex 402, color None
# In vertex 402, color 66
# In node_coloring, vertex 403, color None
# In vertex 403, color 72
# In node_coloring, vertex 404, color None
# In vertex 404, color 73
# In node_coloring, vertex 406, color None
# In vertex 406, color 72
# In node_coloring, vertex 407, color None
# In vertex 407, color 70
# In node_coloring, vertex 408, color None
# In vertex 408, color 43
# In node_coloring, vertex 409, color None
# In vertex 409, color 70
# In node_coloring, vertex 410, color None
# In vertex 410, color 74
# In node_coloring, vertex 411, color None
# In vertex 411, color 73
# In node_coloring, vertex 414, color None
# In vertex 414, color 72
# In node_coloring, vertex 415, color None
# In vertex 415, color 57
# In node_coloring, vertex 417, color None
# In vertex 417, color 63
# In node_coloring, vertex 418, color None
# In vertex 418, color 73
# In node_coloring, vertex 419, color None
# In vertex 419, color 46
# In node_coloring, vertex 420, color None
# In vertex 420, color 63
# In node_coloring, vertex 422, color None
# In vertex 422, color 59
# In node_coloring, vertex 423, color None
# In vertex 423, color 59
# In node_coloring, vertex 424, color None
# In vertex 424, color 66
# In node_coloring, vertex 425, color None
# In vertex 425, color 74
# In node_coloring, vertex 426, color None
# In vertex 426, color 57
# In node_coloring, vertex 427, color None
# In vertex 427, color 75
# In node_coloring, vertex 428, color None
# In vertex 428, color 69
# In node_coloring, vertex 429, color None
# In vertex 429, color 69
# In node_coloring, vertex 431, color None
# In vertex 431, color 76
# In node_coloring, vertex 432, color None
# In vertex 432, color 73
# In node_coloring, vertex 433, color None
# In vertex 433, color 56
# In node_coloring, vertex 434, color None
# In vertex 434, color 75
# In node_coloring, vertex 435, color None
# In vertex 435, color 75
# In node_coloring, vertex 436, color None
# In vertex 436, color 71
# In node_coloring, vertex 437, color None
# In vertex 437, color 70
# In node_coloring, vertex 438, color None
# In vertex 438, color 45
# In node_coloring, vertex 439, color None
# In vertex 439, color 8
# In node_coloring, vertex 441, color None
# In vertex 441, color 11
# In node_coloring, vertex 442, color None
# In vertex 442, color 74
# In node_coloring, vertex 443, color None
# In vertex 443, color 54
# In node_coloring, vertex 445, color None
# In vertex 445, color 77
# In node_coloring, vertex 446, color None
# In vertex 446, color 76
# In node_coloring, vertex 447, color None
# In vertex 447, color 75
# In node_coloring, vertex 448, color None
# In vertex 448, color 75
# In node_coloring, vertex 449, color None
# In vertex 449, color 71
# In node_coloring, vertex 450, color None
# In vertex 450, color 62
# In node_coloring, vertex 451, color None
# In vertex 451, color 29
# In node_coloring, vertex 453, color None
# In vertex 453, color 78
# In node_coloring, vertex 455, color None
# In vertex 455, color 79
# In node_coloring, vertex 456, color None
# In vertex 456, color 49
# In node_coloring, vertex 457, color None
# In vertex 457, color 60
# In node_coloring, vertex 458, color None
# In vertex 458, color 78
# In node_coloring, vertex 459, color None
# In vertex 459, color 79
# In node_coloring, vertex 464, color None
# In vertex 464, color 80
# In node_coloring, vertex 465, color None
# In vertex 465, color 23
# In node_coloring, vertex 466, color None
# In vertex 466, color 81
# In node_coloring, vertex 467, color None
# In vertex 467, color 23
# In node_coloring, vertex 468, color None
# In vertex 468, color 80
# In node_coloring, vertex 469, color None
# In vertex 469, color 76
# In node_coloring, vertex 472, color None
# In vertex 472, color 81
# In node_coloring, vertex 473, color None
# In vertex 473, color 68
# In node_coloring, vertex 475, color None
# In vertex 475, color 77
# In node_coloring, vertex 476, color None
# In vertex 476, color 80
# In node_coloring, vertex 477, color None
# In vertex 477, color 63
# In node_coloring, vertex 478, color None
# In vertex 478, color 72
# In node_coloring, vertex 479, color None
# In vertex 479, color 54
# In node_coloring, vertex 480, color None
# In vertex 480, color 76
# In node_coloring, vertex 481, color None
# In vertex 481, color 78
# In node_coloring, vertex 483, color None
# In vertex 483, color 82
# In node_coloring, vertex 484, color None
# In vertex 484, color 1
# In node_coloring, vertex 486, color None
# In vertex 486, color 65
# In node_coloring, vertex 487, color None
# In vertex 487, color 81
# In node_coloring, vertex 488, color None
# In vertex 488, color 74
# In node_coloring, vertex 489, color None
# In vertex 489, color 69
# In node_coloring, vertex 490, color None
# In vertex 490, color 82
# In node_coloring, vertex 491, color None
# In vertex 491, color 83
# In node_coloring, vertex 492, color None
# In vertex 492, color 28
# In node_coloring, vertex 493, color None
# In vertex 493, color 84
# In node_coloring, vertex 494, color None
# In vertex 494, color 77
# In node_coloring, vertex 495, color None
# In vertex 495, color 79
# In node_coloring, vertex 496, color None
# In vertex 496, color 62
# In node_coloring, vertex 498, color None
# In vertex 498, color 85
# In node_coloring, vertex 499, color None
# In vertex 499, color 85
# In node_coloring, vertex 500, color None
# In vertex 500, color 86
# In node_coloring, vertex 502, color None
# In vertex 502, color 87
# In node_coloring, vertex 503, color None
# In vertex 503, color 68
# In node_coloring, vertex 504, color None
# In vertex 504, color 88
# In node_coloring, vertex 505, color None
# In vertex 505, color 82
# In node_coloring, vertex 506, color None
# In vertex 506, color 51
# In node_coloring, vertex 507, color None
# In vertex 507, color 84
# In node_coloring, vertex 508, color None
# In vertex 508, color 83
# In node_coloring, vertex 510, color None
# In vertex 510, color 55
# In node_coloring, vertex 519, color None
# In vertex 519, color 84
# In node_coloring, vertex 521, color None
# In vertex 521, color 89
# In node_coloring, vertex 523, color None
# In vertex 523, color 80
# In node_coloring, vertex 524, color None
# In vertex 524, color 90
# In node_coloring, vertex 525, color None
# In vertex 525, color 74
# In node_coloring, vertex 526, color None
# In vertex 526, color 89
# In node_coloring, vertex 527, color None
# In vertex 527, color 89
# In node_coloring, vertex 528, color None
# In vertex 528, color 91
# In node_coloring, vertex 529, color None
# In vertex 529, color 79
# In node_coloring, vertex 533, color None
# In vertex 533, color 18
# In node_coloring, vertex 534, color None
# In vertex 534, color 88
# In node_coloring, vertex 536, color None
# In vertex 536, color 83
# In node_coloring, vertex 540, color None
# In vertex 540, color 19
# In node_coloring, vertex 541, color None
# In vertex 541, color 90
# In node_coloring, vertex 542, color None
# In vertex 542, color 77
# In node_coloring, vertex 543, color None
# In vertex 543, color 64
# In node_coloring, vertex 544, color None
# In vertex 544, color 77
# In node_coloring, vertex 545, color None
# In vertex 545, color 82
# In node_coloring, vertex 546, color None
# In vertex 546, color 92
# In node_coloring, vertex 547, color None
# In vertex 547, color 81
# In node_coloring, vertex 548, color None
# In vertex 548, color 88
# In node_coloring, vertex 549, color None
# In vertex 549, color 4
# In node_coloring, vertex 550, color None
# In vertex 550, color 46
# In node_coloring, vertex 551, color None
# In vertex 551, color 43
# In node_coloring, vertex 552, color None
# In vertex 552, color 67
# In node_coloring, vertex 553, color None
# In vertex 553, color 76
# In node_coloring, vertex 554, color None
# In vertex 554, color 68
# In node_coloring, vertex 555, color None
# In vertex 555, color 92
# In node_coloring, vertex 557, color None
# In vertex 557, color 91
# In node_coloring, vertex 561, color None
# In vertex 561, color 39
# In node_coloring, vertex 562, color None
# In vertex 562, color 90
# In node_coloring, vertex 563, color None
# In vertex 563, color 52
# In node_coloring, vertex 564, color None
# In vertex 564, color 93
# In node_coloring, vertex 565, color None
# In vertex 565, color 65
# In node_coloring, vertex 567, color None
# In vertex 567, color 58
# In node_coloring, vertex 568, color None
# In vertex 568, color 94
# In node_coloring, vertex 569, color None
# In vertex 569, color 93
# In node_coloring, vertex 571, color None
# In vertex 571, color 95
# In node_coloring, vertex 572, color None
# In vertex 572, color 67
# In node_coloring, vertex 573, color None
# In vertex 573, color 96
# In node_coloring, vertex 575, color None
# In vertex 575, color 93
# In node_coloring, vertex 576, color None
# In vertex 576, color 96
# In node_coloring, vertex 577, color None
# In vertex 577, color 96
# In node_coloring, vertex 578, color None
# In vertex 578, color 92
# In node_coloring, vertex 580, color None
# In vertex 580, color 56
# In node_coloring, vertex 581, color None
# In vertex 581, color 86
# In node_coloring, vertex 583, color None
# In vertex 583, color 97
# In node_coloring, vertex 584, color None
# In vertex 584, color 85
# In node_coloring, vertex 585, color None
# In vertex 585, color 3
# In node_coloring, vertex 587, color None
# In vertex 587, color 98
# In node_coloring, vertex 588, color None
# In vertex 588, color 94
# In node_coloring, vertex 590, color None
# In vertex 590, color 97
# In node_coloring, vertex 591, color None
# In vertex 591, color 69
# In node_coloring, vertex 592, color None
# In vertex 592, color 99
# In node_coloring, vertex 593, color None
# In vertex 593, color 84
# In node_coloring, vertex 594, color None
# In vertex 594, color 95
# In node_coloring, vertex 595, color None
# In vertex 595, color 89
# In node_coloring, vertex 597, color None
# In vertex 597, color 86
# In node_coloring, vertex 598, color None
# In vertex 598, color 97
# In node_coloring, vertex 599, color None
# In vertex 599, color 94
# In node_coloring, vertex 601, color None
# In vertex 601, color 88
# In node_coloring, vertex 602, color None
# In vertex 602, color 100
# In node_coloring, vertex 604, color None
# In vertex 604, color 85
# In node_coloring, vertex 605, color None
# In vertex 605, color 98
# In node_coloring, vertex 610, color None
# In vertex 610, color 48
# In node_coloring, vertex 612, color None
# In vertex 612, color 93
# In node_coloring, vertex 613, color None
# In vertex 613, color 29
# In node_coloring, vertex 614, color None
# In vertex 614, color 99
# In node_coloring, vertex 615, color None
# In vertex 615, color 100
# In node_coloring, vertex 616, color None
# In vertex 616, color 63
# In node_coloring, vertex 617, color None
# In vertex 617, color 91
# In node_coloring, vertex 618, color None
# In vertex 618, color 37
# In node_coloring, vertex 619, color None
# In vertex 619, color 101
# In node_coloring, vertex 620, color None
# In vertex 620, color 101
# In node_coloring, vertex 621, color None
# In vertex 621, color 95
# In node_coloring, vertex 622, color None
# In vertex 622, color 87
# In node_coloring, vertex 624, color None
# In vertex 624, color 63
# In node_coloring, vertex 626, color None
# In vertex 626, color 102
# In node_coloring, vertex 627, color None
# In vertex 627, color 99
# In node_coloring, vertex 628, color None
# In vertex 628, color 87
# In node_coloring, vertex 629, color None
# In vertex 629, color 102
# In node_coloring, vertex 630, color None
# In vertex 630, color 30
# In node_coloring, vertex 631, color None
# In vertex 631, color 103
# In node_coloring, vertex 632, color None
# In vertex 632, color 98
# In node_coloring, vertex 634, color None
# In vertex 634, color 79
# In node_coloring, vertex 636, color None
# In vertex 636, color 103
# In node_coloring, vertex 637, color None
# In vertex 637, color 104
# In node_coloring, vertex 638, color None
# In vertex 638, color 26
# In node_coloring, vertex 640, color None
# In vertex 640, color 100
# In node_coloring, vertex 641, color None
# In vertex 641, color 105
# In node_coloring, vertex 642, color None
# In vertex 642, color 104
# In node_coloring, vertex 643, color None
# In vertex 643, color 32
# In node_coloring, vertex 644, color None
# In vertex 644, color 97
# In node_coloring, vertex 645, color None
# In vertex 645, color 100
# In node_coloring, vertex 647, color None
# In vertex 647, color 106
# In node_coloring, vertex 648, color None
# In vertex 648, color 32
# In node_coloring, vertex 649, color None
# In vertex 649, color 107
# In node_coloring, vertex 651, color None
# In vertex 651, color 108
# In node_coloring, vertex 652, color None
# In vertex 652, color 98
# In node_coloring, vertex 653, color None
# In vertex 653, color 90
# In node_coloring, vertex 655, color None
# In vertex 655, color 62
# In node_coloring, vertex 657, color None
# In vertex 657, color 96
# In node_coloring, vertex 658, color None
# In vertex 658, color 102
# In node_coloring, vertex 659, color None
# In vertex 659, color 78
# In node_coloring, vertex 660, color None
# In vertex 660, color 109
# In node_coloring, vertex 661, color None
# In vertex 661, color 110
# In node_coloring, vertex 662, color None
# In vertex 662, color 105
# In node_coloring, vertex 664, color None
# In vertex 664, color 91
# In node_coloring, vertex 665, color None
# In vertex 665, color 92
# In node_coloring, vertex 666, color None
# In vertex 666, color 97
# In node_coloring, vertex 669, color None
# In vertex 669, color 104
# In node_coloring, vertex 670, color None
# In vertex 670, color 106
# In node_coloring, vertex 671, color None
# In vertex 671, color 101
# In node_coloring, vertex 672, color None
# In vertex 672, color 109
# In node_coloring, vertex 673, color None
# In vertex 673, color 105
# In node_coloring, vertex 676, color None
# In vertex 676, color 102
# In node_coloring, vertex 678, color None
# In vertex 678, color 86
# In node_coloring, vertex 681, color None
# In vertex 681, color 31
# In node_coloring, vertex 683, color None
# In vertex 683, color 108
# In node_coloring, vertex 684, color None
# In vertex 684, color 71
# In node_coloring, vertex 685, color None
# In vertex 685, color 31
# In node_coloring, vertex 686, color None
# In vertex 686, color 104
# In node_coloring, vertex 687, color None
# In vertex 687, color 105
# In node_coloring, vertex 688, color None
# In vertex 688, color 47
# In node_coloring, vertex 689, color None
# In vertex 689, color 107
# In node_coloring, vertex 690, color None
# In vertex 690, color 100
# In node_coloring, vertex 691, color None
# In vertex 691, color 111
# In node_coloring, vertex 692, color None
# In vertex 692, color 34
# In node_coloring, vertex 693, color None
# In vertex 693, color 106
# In node_coloring, vertex 694, color None
# In vertex 694, color 112
# In node_coloring, vertex 695, color None
# In vertex 695, color 86
# In node_coloring, vertex 697, color None
# In vertex 697, color 107
# In node_coloring, vertex 698, color None
# In vertex 698, color 109
# In node_coloring, vertex 699, color None
# In vertex 699, color 113
# In node_coloring, vertex 700, color None
# In vertex 700, color 94
# In node_coloring, vertex 702, color None
# In vertex 702, color 2
# In node_coloring, vertex 704, color None
# In vertex 704, color 113
# In node_coloring, vertex 705, color None
# In vertex 705, color 104
# In node_coloring, vertex 706, color None
# In vertex 706, color 80
# In node_coloring, vertex 708, color None
# In vertex 708, color 110
# In node_coloring, vertex 709, color None
# In vertex 709, color 9
# In node_coloring, vertex 710, color None
# In vertex 710, color 114
# In node_coloring, vertex 711, color None
# In vertex 711, color 115
# In node_coloring, vertex 713, color None
# In vertex 713, color 116
# In node_coloring, vertex 714, color None
# In vertex 714, color 106
# In node_coloring, vertex 715, color None
# In vertex 715, color 114
# In node_coloring, vertex 716, color None
# In vertex 716, color 117
# In node_coloring, vertex 718, color None
# In vertex 718, color 108
# In node_coloring, vertex 719, color None
# In vertex 719, color 78
# In node_coloring, vertex 720, color None
# In vertex 720, color 117
# In node_coloring, vertex 721, color None
# In vertex 721, color 111
# In node_coloring, vertex 722, color None
# In vertex 722, color 38
# In node_coloring, vertex 724, color None
# In vertex 724, color 110
# In node_coloring, vertex 725, color None
# In vertex 725, color 112
# In node_coloring, vertex 726, color None
# In vertex 726, color 115
# In node_coloring, vertex 727, color None
# In vertex 727, color 91
# In node_coloring, vertex 728, color None
# In vertex 728, color 113
# In node_coloring, vertex 729, color None
# In vertex 729, color 118
# In node_coloring, vertex 731, color None
# In vertex 731, color 116
# In node_coloring, vertex 732, color None
# In vertex 732, color 109
# In node_coloring, vertex 733, color None
# In vertex 733, color 111
# In node_coloring, vertex 734, color None
# In vertex 734, color 99
# In node_coloring, vertex 737, color None
# In vertex 737, color 116
# In node_coloring, vertex 738, color None
# In vertex 738, color 112
# In node_coloring, vertex 739, color None
# In vertex 739, color 67
# In node_coloring, vertex 741, color None
# In vertex 741, color 113
# In node_coloring, vertex 743, color None
# In vertex 743, color 119
# In node_coloring, vertex 745, color None
# In vertex 745, color 118
# In node_coloring, vertex 746, color None
# In vertex 746, color 116
# In node_coloring, vertex 747, color None
# In vertex 747, color 117
# In node_coloring, vertex 749, color None
# In vertex 749, color 87
# In node_coloring, vertex 753, color None
# In vertex 753, color 120
# In node_coloring, vertex 754, color None
# In vertex 754, color 121
# In node_coloring, vertex 755, color None
# In vertex 755, color 83
# In node_coloring, vertex 756, color None
# In vertex 756, color 101
# In node_coloring, vertex 757, color None
# In vertex 757, color 83
# In node_coloring, vertex 758, color None
# In vertex 758, color 114
# In node_coloring, vertex 759, color None
# In vertex 759, color 118
# In node_coloring, vertex 761, color None
# In vertex 761, color 111
# In node_coloring, vertex 762, color None
# In vertex 762, color 112
# In node_coloring, vertex 763, color None
# In vertex 763, color 120
# In node_coloring, vertex 764, color None
# In vertex 764, color 103
# In node_coloring, vertex 765, color None
# In vertex 765, color 111
# In node_coloring, vertex 767, color None
# In vertex 767, color 120
# In node_coloring, vertex 768, color None
# In vertex 768, color 121
# In node_coloring, vertex 769, color None
# In vertex 769, color 66
# In node_coloring, vertex 770, color None
# In vertex 770, color 122
# In node_coloring, vertex 771, color None
# In vertex 771, color 123
# In node_coloring, vertex 772, color None
# In vertex 772, color 122
# In node_coloring, vertex 773, color None
# In vertex 773, color 97
# In node_coloring, vertex 774, color None
# In vertex 774, color 121
# In node_coloring, vertex 775, color None
# In vertex 775, color 117
# In node_coloring, vertex 776, color None
# In vertex 776, color 122
# In node_coloring, vertex 777, color None
# In vertex 777, color 100
# In node_coloring, vertex 778, color None
# In vertex 778, color 124
# In node_coloring, vertex 779, color None
# In vertex 779, color 50
# In node_coloring, vertex 782, color None
# In vertex 782, color 25
# In node_coloring, vertex 783, color None
# In vertex 783, color 123
# In node_coloring, vertex 784, color None
# In vertex 784, color 125
# In node_coloring, vertex 785, color None
# In vertex 785, color 123
# In node_coloring, vertex 787, color None
# In vertex 787, color 125
# In node_coloring, vertex 790, color None
# In vertex 790, color 126
# In node_coloring, vertex 791, color None
# In vertex 791, color 6
# In node_coloring, vertex 792, color None
# In vertex 792, color 124
# In node_coloring, vertex 793, color None
# In vertex 793, color 126
# In node_coloring, vertex 794, color None
# In vertex 794, color 125
# In node_coloring, vertex 795, color None
# In vertex 795, color 124
# In node_coloring, vertex 797, color None
# In vertex 797, color 126
# In node_coloring, vertex 799, color None
# In vertex 799, color 127
# In node_coloring, vertex 800, color None
# In vertex 800, color 128
# In node_coloring, vertex 801, color None
# In vertex 801, color 128
# In node_coloring, vertex 802, color None
# In vertex 802, color 129
# In node_coloring, vertex 803, color None
# In vertex 803, color 130
# In node_coloring, vertex 805, color None
# In vertex 805, color 129
# In node_coloring, vertex 806, color None
# In vertex 806, color 127
# In node_coloring, vertex 807, color None
# In vertex 807, color 130
# In node_coloring, vertex 808, color None
# In vertex 808, color 108
# In node_coloring, vertex 809, color None
# In vertex 809, color 76
# In node_coloring, vertex 810, color None
# In vertex 810, color 87
# In node_coloring, vertex 811, color None
# In vertex 811, color 56
# In node_coloring, vertex 812, color None
# In vertex 812, color 21
# In node_coloring, vertex 813, color None
# In vertex 813, color 44
# In node_coloring, vertex 814, color None
# In vertex 814, color 43
# In node_coloring, vertex 815, color None
# In vertex 815, color 128
# In node_coloring, vertex 817, color None
# In vertex 817, color 44
# In node_coloring, vertex 819, color None
# In vertex 819, color 119
# In node_coloring, vertex 820, color None
# In vertex 820, color 124
# In node_coloring, vertex 821, color None
# In vertex 821, color 118
# In node_coloring, vertex 823, color None
# In vertex 823, color 131
# In node_coloring, vertex 824, color None
# In vertex 824, color 120
# In node_coloring, vertex 826, color None
# In vertex 826, color 132
# In node_coloring, vertex 828, color None
# In vertex 828, color 132
# In node_coloring, vertex 829, color None
# In vertex 829, color 133
# In node_coloring, vertex 830, color None
# In vertex 830, color 105
# In node_coloring, vertex 831, color None
# In vertex 831, color 107
# In node_coloring, vertex 832, color None
# In vertex 832, color 89
# In node_coloring, vertex 833, color None
# In vertex 833, color 13
# In node_coloring, vertex 834, color None
# In vertex 834, color 131
# In node_coloring, vertex 835, color None
# In vertex 835, color 129
# In node_coloring, vertex 838, color None
# In vertex 838, color 134
# In node_coloring, vertex 839, color None
# In vertex 839, color 115
# In node_coloring, vertex 840, color None
# In vertex 840, color 135
# In node_coloring, vertex 841, color None
# In vertex 841, color 133
# In node_coloring, vertex 842, color None
# In vertex 842, color 108
# In node_coloring, vertex 843, color None
# In vertex 843, color 136
# In node_coloring, vertex 844, color None
# In vertex 844, color 136
# In node_coloring, vertex 847, color None
# In vertex 847, color 112
# In node_coloring, vertex 848, color None
# In vertex 848, color 2
# In node_coloring, vertex 849, color None
# In vertex 849, color 82
# In node_coloring, vertex 850, color None
# In vertex 850, color 137
# In node_coloring, vertex 852, color None
# In vertex 852, color 73
# In node_coloring, vertex 853, color None
# In vertex 853, color 106
# In node_coloring, vertex 854, color None
# In vertex 854, color 129
# In node_coloring, vertex 855, color None
# In vertex 855, color 111
# In node_coloring, vertex 856, color None
# In vertex 856, color 120
# In node_coloring, vertex 857, color None
# In vertex 857, color 124
# In node_coloring, vertex 858, color None
# In vertex 858, color 136
# In node_coloring, vertex 859, color None
# In vertex 859, color 134
# In node_coloring, vertex 860, color None
# In vertex 860, color 130
# In node_coloring, vertex 861, color None
# In vertex 861, color 138
# In node_coloring, vertex 862, color None
# In vertex 862, color 102
# In node_coloring, vertex 863, color None
# In vertex 863, color 137
# In node_coloring, vertex 864, color None
# In vertex 864, color 133
# In node_coloring, vertex 866, color None
# In vertex 866, color 113
# In node_coloring, vertex 867, color None
# In vertex 867, color 130
# In node_coloring, vertex 871, color None
# In vertex 871, color 132
# In node_coloring, vertex 872, color None
# In vertex 872, color 81
# In node_coloring, vertex 874, color None
# In vertex 874, color 59
# In node_coloring, vertex 876, color None
# In vertex 876, color 128
# In node_coloring, vertex 877, color None
# In vertex 877, color 123
# In node_coloring, vertex 878, color None
# In vertex 878, color 139
# In node_coloring, vertex 879, color None
# In vertex 879, color 91
# In node_coloring, vertex 880, color None
# In vertex 880, color 131
# In node_coloring, vertex 882, color None
# In vertex 882, color 101
# In node_coloring, vertex 884, color None
# In vertex 884, color 137
# In node_coloring, vertex 885, color None
# In vertex 885, color 140
# In node_coloring, vertex 888, color None
# In vertex 888, color 135
# In node_coloring, vertex 890, color None
# In vertex 890, color 139
# In node_coloring, vertex 891, color None
# In vertex 891, color 140
# In node_coloring, vertex 892, color None
# In vertex 892, color 137
# In node_coloring, vertex 893, color None
# In vertex 893, color 81
# In node_coloring, vertex 894, color None
# In vertex 894, color 90
# In node_coloring, vertex 895, color None
# In vertex 895, color 81
# In node_coloring, vertex 896, color None
# In vertex 896, color 135
# In node_coloring, vertex 897, color None
# In vertex 897, color 129
# In node_coloring, vertex 898, color None
# In vertex 898, color 110
# In node_coloring, vertex 899, color None
# In vertex 899, color 134
# In node_coloring, vertex 900, color None
# In vertex 900, color 138
# In node_coloring, vertex 901, color None
# In vertex 901, color 141
# In node_coloring, vertex 904, color None
# In vertex 904, color 121
# In node_coloring, vertex 905, color None
# In vertex 905, color 87
# In node_coloring, vertex 906, color None
# In vertex 906, color 142
# In node_coloring, vertex 908, color None
# In vertex 908, color 120
# In node_coloring, vertex 913, color None
# In vertex 913, color 143
# In node_coloring, vertex 914, color None
# In vertex 914, color 119
# In node_coloring, vertex 917, color None
# In vertex 917, color 127
# In node_coloring, vertex 920, color None
# In vertex 920, color 122
# In node_coloring, vertex 922, color None
# In vertex 922, color 126
# In node_coloring, vertex 923, color None
# In vertex 923, color 143
# In node_coloring, vertex 924, color None
# In vertex 924, color 138
# In node_coloring, vertex 925, color None
# In vertex 925, color 133
# In node_coloring, vertex 926, color None
# In vertex 926, color 142
# In node_coloring, vertex 927, color None
# In vertex 927, color 144
# In node_coloring, vertex 928, color None
# In vertex 928, color 90
# In node_coloring, vertex 930, color None
# In vertex 930, color 144
# In node_coloring, vertex 931, color None
# In vertex 931, color 98
# In node_coloring, vertex 932, color None
# In vertex 932, color 128
# In node_coloring, vertex 933, color None
# In vertex 933, color 141
# In node_coloring, vertex 936, color None
# In vertex 936, color 145
# In node_coloring, vertex 937, color None
# In vertex 937, color 131
# In node_coloring, vertex 939, color None
# In vertex 939, color 114
# In node_coloring, vertex 940, color None
# In vertex 940, color 141
# In node_coloring, vertex 941, color None
# In vertex 941, color 146
# In node_coloring, vertex 942, color None
# In vertex 942, color 114
# In node_coloring, vertex 943, color None
# In vertex 943, color 147
# In node_coloring, vertex 944, color None
# In vertex 944, color 145
# In node_coloring, vertex 945, color None
# In vertex 945, color 89
# In node_coloring, vertex 946, color None
# In vertex 946, color 127
# In node_coloring, vertex 947, color None
# In vertex 947, color 10
# In node_coloring, vertex 949, color None
# In vertex 949, color 148
# In node_coloring, vertex 951, color None
# In vertex 951, color 140
# In node_coloring, vertex 952, color None
# In vertex 952, color 140
# In node_coloring, vertex 953, color None
# In vertex 953, color 142
# In node_coloring, vertex 954, color None
# In vertex 954, color 146
# In node_coloring, vertex 955, color None
# In vertex 955, color 33
# In node_coloring, vertex 957, color None
# In vertex 957, color 103
# In node_coloring, vertex 958, color None
# In vertex 958, color 149
# In node_coloring, vertex 959, color None
# In vertex 959, color 103
# In node_coloring, vertex 961, color None
# In vertex 961, color 146
# In node_coloring, vertex 962, color None
# In vertex 962, color 144
# In node_coloring, vertex 963, color None
# In vertex 963, color 150
# In node_coloring, vertex 964, color None
# In vertex 964, color 85
# In node_coloring, vertex 965, color None
# In vertex 965, color 148
# In node_coloring, vertex 966, color None
# In vertex 966, color 136
# In node_coloring, vertex 967, color None
# In vertex 967, color 147
# In node_coloring, vertex 968, color None
# In vertex 968, color 131
# In node_coloring, vertex 970, color None
# In vertex 970, color 119
# In node_coloring, vertex 971, color None
# In vertex 971, color 151
# In node_coloring, vertex 972, color None
# In vertex 972, color 152
# In node_coloring, vertex 974, color None
# In vertex 974, color 118
# In node_coloring, vertex 978, color None
# In vertex 978, color 55
# In node_coloring, vertex 979, color None
# In vertex 979, color 148
# In node_coloring, vertex 981, color None
# In vertex 981, color 153
# In node_coloring, vertex 984, color None
# In vertex 984, color 84
# In node_coloring, vertex 985, color None
# In vertex 985, color 61
# In node_coloring, vertex 986, color None
# In vertex 986, color 151
# In node_coloring, vertex 988, color None
# In vertex 988, color 147
# In node_coloring, vertex 990, color None
# In vertex 990, color 70
# In node_coloring, vertex 991, color None
# In vertex 991, color 153
# In node_coloring, vertex 992, color None
# ...
# In node_coloring, vertex 735, color 168
# In node_coloring, vertex 736, color 146
# In node_coloring, vertex 737, color 116
# In node_coloring, vertex 738, color 112
# In node_coloring, vertex 740, color 176
# In node_coloring, vertex 743, color 119
# In node_coloring, vertex 744, color 129
# In node_coloring, vertex 747, color 117
# In node_coloring, vertex 748, color 177
# In node_coloring, vertex 750, color 171
# In node_coloring, vertex 751, color 178
# In node_coloring, vertex 752, color 154
# In node_coloring, vertex 755, color 83
# In node_coloring, vertex 757, color 83
# In node_coloring, vertex 759, color 118
# In node_coloring, vertex 760, color 78
# In node_coloring, vertex 762, color 112
# In node_coloring, vertex 764, color 103
# In node_coloring, vertex 765, color 111
# In node_coloring, vertex 767, color 120
# In node_coloring, vertex 768, color 121
# In node_coloring, vertex 769, color 66
# In node_coloring, vertex 771, color 123
# In node_coloring, vertex 772, color 122
# In node_coloring, vertex 773, color 97
# In node_coloring, vertex 774, color 121
# In node_coloring, vertex 775, color 117
# In node_coloring, vertex 776, color 122
# In node_coloring, vertex 777, color 100
# In node_coloring, vertex 778, color 124
# In node_coloring, vertex 781, color 82
# In node_coloring, vertex 783, color 123
# In node_coloring, vertex 784, color 125
# In node_coloring, vertex 785, color 123
# In node_coloring, vertex 786, color 169
# In node_coloring, vertex 787, color 125
# In node_coloring, vertex 789, color 179
# In node_coloring, vertex 790, color 126
# In node_coloring, vertex 791, color 6
# In node_coloring, vertex 792, color 124
# In node_coloring, vertex 793, color 126
# In node_coloring, vertex 794, color 125
# In node_coloring, vertex 795, color 124
# In node_coloring, vertex 798, color 179
# In node_coloring, vertex 799, color 127
# In node_coloring, vertex 800, color 128
# In node_coloring, vertex 802, color 129
# In node_coloring, vertex 803, color 130
# In node_coloring, vertex 805, color 129
# In node_coloring, vertex 806, color 127
# In node_coloring, vertex 807, color 130
# In node_coloring, vertex 809, color 76
# In node_coloring, vertex 810, color 87
# In node_coloring, vertex 811, color 56
# In node_coloring, vertex 813, color 44
# In node_coloring, vertex 814, color 43
# In node_coloring, vertex 815, color 128
# In node_coloring, vertex 818, color 174
# In node_coloring, vertex 819, color 119
# In node_coloring, vertex 820, color 124
# In node_coloring, vertex 821, color 118
# In node_coloring, vertex 822, color 189
# In node_coloring, vertex 823, color 131
# In node_coloring, vertex 825, color 186
# In node_coloring, vertex 826, color 132
# In node_coloring, vertex 828, color 132
# In node_coloring, vertex 830, color 105
# In node_coloring, vertex 831, color 107
# In node_coloring, vertex 832, color 89
# In node_coloring, vertex 833, color 13
# In node_coloring, vertex 836, color 164
# In node_coloring, vertex 837, color 175
# In node_coloring, vertex 838, color 134
# In node_coloring, vertex 839, color 115
# In node_coloring, vertex 840, color 135
# In node_coloring, vertex 841, color 133
# In node_coloring, vertex 843, color 136
# In node_coloring, vertex 844, color 136
# In node_coloring, vertex 846, color 74
# In node_coloring, vertex 848, color 2
# In node_coloring, vertex 849, color 82
# In node_coloring, vertex 850, color 137
# In node_coloring, vertex 851, color 177
# In node_coloring, vertex 852, color 73
# In node_coloring, vertex 853, color 106
# In node_coloring, vertex 857, color 124
# In node_coloring, vertex 858, color 136
# In node_coloring, vertex 859, color 134
# In node_coloring, vertex 860, color 130
# In node_coloring, vertex 861, color 138
# In node_coloring, vertex 863, color 137
# In node_coloring, vertex 864, color 133
# In node_coloring, vertex 865, color 109
# In node_coloring, vertex 866, color 113
# In node_coloring, vertex 868, color 115
# In node_coloring, vertex 869, color 184
# In node_coloring, vertex 872, color 81
# In node_coloring, vertex 873, color 94
# In node_coloring, vertex 874, color 59
# In node_coloring, vertex 875, color 181
# In node_coloring, vertex 877, color 123
# In node_coloring, vertex 878, color 139
# In node_coloring, vertex 880, color 131
# In node_coloring, vertex 881, color 178
# In node_coloring, vertex 882, color 101
# In node_coloring, vertex 887, color 164
# In node_coloring, vertex 888, color 135
# In node_coloring, vertex 890, color 139
# In node_coloring, vertex 891, color 140
# In node_coloring, vertex 892, color 137
# In node_coloring, vertex 893, color 81
# In node_coloring, vertex 897, color 129
# In node_coloring, vertex 898, color 110
# In node_coloring, vertex 900, color 138
# In node_coloring, vertex 902, color 21
# In node_coloring, vertex 903, color 11
# In node_coloring, vertex 905, color 87
# In node_coloring, vertex 906, color 142
# In node_coloring, vertex 907, color 126
# In node_coloring, vertex 908, color 120
# In node_coloring, vertex 910, color 80
# In node_coloring, vertex 911, color 170
# In node_coloring, vertex 913, color 143
# In node_coloring, vertex 915, color 182
# In node_coloring, vertex 916, color 177
# In node_coloring, vertex 917, color 127
# In node_coloring, vertex 918, color 183
# In node_coloring, vertex 919, color 145
# In node_coloring, vertex 921, color 182
# In node_coloring, vertex 923, color 143
# In node_coloring, vertex 925, color 133
# In node_coloring, vertex 926, color 142
# In node_coloring, vertex 927, color 144
# In node_coloring, vertex 928, color 90
# In node_coloring, vertex 929, color 162
# In node_coloring, vertex 932, color 128
# In node_coloring, vertex 935, color 180
# In node_coloring, vertex 937, color 131
# In node_coloring, vertex 938, color 183
# In node_coloring, vertex 939, color 114
# In node_coloring, vertex 940, color 141
# In node_coloring, vertex 941, color 146
# In node_coloring, vertex 945, color 89
# In node_coloring, vertex 946, color 127
# In node_coloring, vertex 948, color 184
# In node_coloring, vertex 949, color 148
# In node_coloring, vertex 950, color 124
# In node_coloring, vertex 951, color 140
# In node_coloring, vertex 952, color 140
# In node_coloring, vertex 954, color 146
# In node_coloring, vertex 955, color 33
# In node_coloring, vertex 958, color 149
# In node_coloring, vertex 959, color 103
# In node_coloring, vertex 961, color 146
# In node_coloring, vertex 963, color 150
# In node_coloring, vertex 964, color 85
# In node_coloring, vertex 965, color 148
# In node_coloring, vertex 966, color 136
# In node_coloring, vertex 967, color 147
# In node_coloring, vertex 968, color 131
# In node_coloring, vertex 969, color 138
# In node_coloring, vertex 970, color 119
# In node_coloring, vertex 972, color 152
 73 56 75 75 71 70 45 8 41 11 74 54 96 77 76 75 75 71 62 29 156 78 156 79 49 60 78 79 164 187 118 115 80 23 81 23 80 76 165 1 81 68 136 77 80 63 72 54 76 78 152 82 1 162 65 81 74 69 82 83 28 84 77 79 62 167 85 85 86 168 87 68 88 82 51 84 83 161 55 125 143 132 175 168 191 136 169 84 167 89 192 80 90 74 89 89 91 79 192 153 151 18 88 152 83 159 169 133 19 90 77 64 77 82 92 81 88 4 46 43 67 76 68 92 170 91 107 22 163 39 90 52 93 65 160 58 94 93 165 95 67 96 166 93 96 96 92 0 56 86 186 97 85 3 143 98 94 134 97 69 99 84 95 89 161 86 97 94 42 88 100 162 85 98 102 171 162 169 48 172 93 29 99 100 63 91 37 101 101 95 87 167 63 144 102 99 87 102 30 103 98 141 79 26 103 104 26 179 100 105 104 32 97 100 173 106 32 107 166 108 98 90 187 62 171 96 102 78 109 110 105 167 91 92 97 119 173 104 106 101 109 105 174 170 102 166 86 157 158 31 169 108 71 31 104 105 47 107 100 111 34 106 112 86 150 107 109 113 94 128 2 172 113 104 80 172 110 9 114 115 48 116 106 114 117 165 108 78 117 111 38 175 110 112 115 91 113 118 89 116 109 111 99 168 146 116 112 67 176 113 176 119 129 118 116 117 177 87 171 178 154 120 121 83 101 83 114 118 78 111 112 120 103 111 61 120 121 66 122 123 122 97 121 117 122 100 124 50 156 82 25 123 125 123 169 125 188 179 126 6 124 126 125 124 181 126 179 127 128 128 129 130 187 129 127 130 108 76 87 56 21 44 43 128 24 44 174 119 124 118 189 131 120 186 132 179 132 133 105 107 89 13 131 129 164 175 134 115 135 133 108 136 136 180 74 112 2 82 137 177 73 106 129 111 120 124 136 134 130 138 102 137 133 109 113 130 115 184 126 132 81 94 59 181 128 123 139 91 131 178 101 181 137 140 173 164 135 181 139 140 137 81 90 81 135 129 110 134 138 141 21 11 121 87 142 126 120 72 80 170 160 143 119 182 177 127 183 145 122 182 126 143 138 133 142 144 90 162 144 98 128 141 8 180 145 131 183 114 141 146 114 147 145 89 127 10 184 148 124 140 140 142 146 33 189 103 149 103 184 146 144 150 85 148 136 147 131 138 119 151 152 69 118 0 175 190 55 148 130 153 183 137 84 61 151 183 147 182 70 153 88 140 83 145 93 95 145 152

# %%
a = np.zeros((1,), dtype=np.int32)
index = [0]
a[index]
# Out:
# array([0])

# %%
filename = os.path.join(data_folder,'gc_11_16')
with open(filename, 'r') as input_data_file:
    input_data = input_data_file.read()
    
print(solve_it(input_data))
# Out:
# 3 0
# 1 0 1 2 0 1 0 0 0 1 1 1 1

# %%
filename = os.path.join(data_folder,'gc_4_1')
with open(filename, 'r') as input_data_file:
    input_data = input_data_file.read()
    
print(solve_it(input_data))
# Out:
# 2 0
# 1 0 1 1

# %%
filename = os.path.join(data_folder,'gc_1000_7')
with open(filename, 'r') as input_data_file:
    input_data = input_data_file.read()
    
output, vertex_colors, color_frequency = solve_it(input_data)
print('\n\nVertex colors\n', vertex_colors)
print('\n\nColors frequence\n', color_frequency)
print('\n\n Output\n', output)
# Out:
# ---------------Start graph coloring ------------------
# In vertex 579, color 0
# In vertex 0, color 1
# In vertex 1, color 2
# In vertex 2, color 3
# In vertex 3, color 4
# In vertex 4, color 1
# In vertex 7, color 2
# In vertex 8, color 5
# In vertex 9, color 3
# In vertex 10, color 6
# In vertex 11, color 4
# In vertex 12, color 3
# In vertex 13, color 6
# In vertex 14, color 7
# In vertex 15, color 8
# In vertex 16, color 8
# In vertex 17, color 2
# In vertex 18, color 9
# In vertex 19, color 7
# In vertex 20, color 10
# In vertex 21, color 1
# In vertex 22, color 9
# In vertex 23, color 3
# In vertex 24, color 9
# In vertex 25, color 11
# In vertex 26, color 8
# In vertex 27, color 4
# In vertex 28, color 11
# In vertex 29, color 2
# In vertex 32, color 10
# In vertex 33, color 12
# In vertex 34, color 11
# In vertex 36, color 12
# In vertex 37, color 13
# In vertex 38, color 13
# In vertex 39, color 5
# In vertex 40, color 14
# In vertex 45, color 15
# In vertex 46, color 5
# In vertex 47, color 16
# In vertex 48, color 12
# In vertex 49, color 7
# In vertex 50, color 4
# In vertex 51, color 17
# In vertex 52, color 17
# In vertex 53, color 14
# In vertex 54, color 13
# In vertex 55, color 18
# In vertex 57, color 18
# In vertex 58, color 19
# In vertex 63, color 17
# In vertex 64, color 15
# In vertex 65, color 9
# In vertex 66, color 19
# In vertex 68, color 18
# In vertex 69, color 16
# In vertex 70, color 6
# In vertex 72, color 16
# In vertex 73, color 20
# In vertex 74, color 18
# In vertex 75, color 20
# In vertex 76, color 21
# In vertex 79, color 15
# In vertex 80, color 21
# In vertex 81, color 13
# In vertex 83, color 22
# In vertex 84, color 23
# In vertex 85, color 19
# In vertex 86, color 16
# In vertex 87, color 24
# In vertex 88, color 25
# In vertex 89, color 24
# In vertex 90, color 12
# In vertex 92, color 12
# In vertex 93, color 22
# In vertex 94, color 23
# In vertex 96, color 26
# In vertex 98, color 10
# In vertex 99, color 25
# In vertex 100, color 26
# In vertex 101, color 27
# In vertex 102, color 28
# In vertex 103, color 28
# In vertex 104, color 27
# In vertex 105, color 29
# In vertex 108, color 29
# In vertex 110, color 26
# In vertex 111, color 30
# In vertex 113, color 27
# In vertex 115, color 9
# In vertex 116, color 25
# In vertex 117, color 1
# In vertex 118, color 30
# In vertex 119, color 31
# In vertex 120, color 19
# In vertex 121, color 24
# In vertex 122, color 31
# In vertex 123, color 29
# In vertex 126, color 32
# In vertex 128, color 30
# In vertex 129, color 22
# In vertex 131, color 27
# In vertex 132, color 8
# In vertex 134, color 33
# In vertex 135, color 32
# In vertex 136, color 24
# In vertex 137, color 33
# In vertex 138, color 34
# In vertex 139, color 28
# In vertex 140, color 4
# In vertex 141, color 31
# In vertex 142, color 10
# In vertex 143, color 33
# In vertex 146, color 34
# In vertex 147, color 14
# In vertex 149, color 35
# In vertex 150, color 32
# In vertex 151, color 30
# In vertex 152, color 35
# In vertex 153, color 7
# In vertex 155, color 36
# In vertex 157, color 37
# In vertex 159, color 37
# In vertex 160, color 38
# In vertex 161, color 34
# In vertex 163, color 36
# In vertex 164, color 27
# In vertex 165, color 14
# In vertex 166, color 39
# In vertex 167, color 32
# In vertex 168, color 40
# In vertex 170, color 25
# In vertex 173, color 40
# In vertex 174, color 20
# In vertex 175, color 38
# In vertex 176, color 41
# In vertex 178, color 1
# In vertex 181, color 40
# In vertex 182, color 35
# In vertex 183, color 42
# In vertex 185, color 20
# In vertex 187, color 42
# In vertex 189, color 33
# In vertex 190, color 11
# In vertex 192, color 43
# In vertex 193, color 40
# In vertex 194, color 4
# In vertex 195, color 41
# In vertex 196, color 17
# In vertex 197, color 34
# In vertex 198, color 43
# In vertex 199, color 13
# In vertex 200, color 41
# In vertex 201, color 26
# In vertex 202, color 44
# In vertex 203, color 45
# In vertex 205, color 38
# In vertex 206, color 41
# In vertex 209, color 46
# In vertex 210, color 45
# In vertex 211, color 7
# In vertex 214, color 42
# In vertex 215, color 46
# In vertex 216, color 39
# In vertex 217, color 44
# In vertex 220, color 38
# In vertex 223, color 6
# In vertex 224, color 36
# In vertex 226, color 47
# In vertex 227, color 40
# In vertex 230, color 47
# In vertex 231, color 48
# In vertex 233, color 49
# In vertex 235, color 48
# In vertex 236, color 48
# In vertex 237, color 43
# In vertex 238, color 49
# In vertex 239, color 48
# In vertex 240, color 50
# In vertex 241, color 37
# In vertex 242, color 51
# In vertex 243, color 44
# In vertex 244, color 52
# In vertex 245, color 15
# In vertex 246, color 50
# In vertex 247, color 52
# In vertex 249, color 49
# In vertex 251, color 51
# In vertex 252, color 43
# In vertex 253, color 29
# In vertex 255, color 52
# In vertex 256, color 53
# In vertex 258, color 54
# In vertex 259, color 23
# In vertex 260, color 47
# In vertex 261, color 48
# In vertex 262, color 38
# In vertex 263, color 35
# In vertex 265, color 51
# In vertex 266, color 53
# In vertex 267, color 54
# In vertex 268, color 46
# In vertex 269, color 55
# In vertex 271, color 21
# In vertex 273, color 54
# In vertex 275, color 55
# In vertex 276, color 39
# In vertex 277, color 56
# In vertex 278, color 56
# In vertex 280, color 45
# In vertex 281, color 3
# In vertex 282, color 32
# In vertex 283, color 56
# In vertex 285, color 57
# In vertex 287, color 58
# In vertex 288, color 59
# In vertex 290, color 57
# In vertex 291, color 50
# In vertex 293, color 60
# In vertex 294, color 59
# In vertex 295, color 58
# In vertex 296, color 29
# In vertex 299, color 44
# In vertex 300, color 53
# In vertex 301, color 57
# In vertex 304, color 61
# In vertex 305, color 61
# In vertex 306, color 58
# In vertex 308, color 30
# In vertex 309, color 62
# In vertex 312, color 63
# In vertex 313, color 57
# In vertex 314, color 64
# In vertex 315, color 16
# In vertex 316, color 36
# In vertex 318, color 63
# In vertex 319, color 58
# In vertex 320, color 54
# In vertex 321, color 64
# In vertex 322, color 28
# In vertex 325, color 62
# In vertex 326, color 65
# In vertex 327, color 65
# In vertex 328, color 63
# In vertex 329, color 64
# In vertex 330, color 55
# In vertex 331, color 65
# In vertex 332, color 66
# In vertex 333, color 60
# In vertex 334, color 49
# In vertex 335, color 66
# In vertex 336, color 66
# In vertex 337, color 52
# In vertex 338, color 59
# In vertex 339, color 37
# In vertex 340, color 60
# In vertex 343, color 28
# In vertex 345, color 67
# In vertex 346, color 51
# In vertex 347, color 58
# In vertex 348, color 68
# In vertex 349, color 67
# In vertex 350, color 61
# In vertex 351, color 68
# In vertex 352, color 13
# In vertex 354, color 62
# In vertex 355, color 24
# In vertex 356, color 16
# In vertex 357, color 64
# In vertex 358, color 53
# In vertex 359, color 68
# In vertex 360, color 56
# In vertex 361, color 69
# In vertex 362, color 52
# In vertex 363, color 70
# In vertex 364, color 69
# In vertex 367, color 10
# In vertex 368, color 37
# In vertex 369, color 5
# In vertex 370, color 71
# In vertex 372, color 60
# In vertex 373, color 61
# In vertex 375, color 72
# In vertex 376, color 70
# In vertex 377, color 71
# In vertex 378, color 65
# In vertex 379, color 72
# In vertex 380, color 42
# In vertex 382, color 73
# In vertex 383, color 74
# In vertex 386, color 73
# In vertex 387, color 17
# In vertex 389, color 73
# In vertex 391, color 75
# In vertex 392, color 67
# In vertex 393, color 76
# In vertex 394, color 70
# In vertex 396, color 77
# In vertex 397, color 76
# In vertex 399, color 74
# In vertex 401, color 75
# In vertex 402, color 76
# In vertex 403, color 72
# In vertex 404, color 77
# In vertex 406, color 22
# In vertex 407, color 75
# In vertex 408, color 50
# In vertex 409, color 75
# In vertex 410, color 78
# In vertex 411, color 69
# In vertex 414, color 78
# In vertex 415, color 53
# In vertex 417, color 35
# In vertex 418, color 79
# In vertex 419, color 48
# In vertex 420, color 79
# In vertex 422, color 66
# In vertex 423, color 20
# In vertex 424, color 73
# In vertex 425, color 56
# In vertex 426, color 57
# In vertex 427, color 1
# In vertex 428, color 74
# In vertex 429, color 70
# In vertex 431, color 80
# In vertex 432, color 77
# In vertex 433, color 81
# In vertex 434, color 76
# In vertex 435, color 80
# In vertex 436, color 46
# In vertex 437, color 81
# In vertex 438, color 67
# In vertex 439, color 8
# In vertex 441, color 79
# In vertex 442, color 78
# In vertex 443, color 81
# In vertex 445, color 63
# In vertex 446, color 45
# In vertex 447, color 22
# In vertex 448, color 33
# In vertex 449, color 82
# In vertex 450, color 55
# In vertex 451, color 74
# In vertex 453, color 83
# In vertex 455, color 82
# In vertex 456, color 83
# In vertex 457, color 83
# In vertex 458, color 71
# In vertex 459, color 80
# In vertex 464, color 72
# In vertex 465, color 55
# In vertex 466, color 23
# In vertex 467, color 84
# In vertex 468, color 59
# In vertex 469, color 85
# In vertex 472, color 84
# In vertex 473, color 86
# In vertex 475, color 85
# In vertex 476, color 87
# In vertex 477, color 72
# In vertex 478, color 88
# In vertex 479, color 88
# In vertex 480, color 86
# In vertex 481, color 36
# In vertex 483, color 81
# In vertex 484, color 89
# In vertex 486, color 90
# In vertex 487, color 84
# In vertex 488, color 89
# In vertex 489, color 79
# In vertex 490, color 89
# In vertex 491, color 90
# In vertex 492, color 25
# In vertex 493, color 82
# In vertex 494, color 91
# In vertex 495, color 87
# In vertex 496, color 88
# In vertex 498, color 33
# In vertex 499, color 34
# In vertex 500, color 91
# In vertex 502, color 92
# In vertex 503, color 92
# In vertex 504, color 65
# In vertex 505, color 93
# In vertex 506, color 88
# In vertex 507, color 82
# In vertex 508, color 89
# In vertex 510, color 64
# In vertex 519, color 93
# In vertex 521, color 19
# In vertex 523, color 78
# In vertex 524, color 62
# In vertex 525, color 83
# In vertex 526, color 45
# In vertex 527, color 94
# In vertex 528, color 95
# In vertex 529, color 96
# In vertex 533, color 92
# In vertex 534, color 96
# In vertex 536, color 90
# In vertex 540, color 91
# In vertex 541, color 97
# In vertex 542, color 98
# In vertex 543, color 98
# In vertex 544, color 94
# In vertex 545, color 93
# In vertex 546, color 97
# In vertex 547, color 87
# In vertex 548, color 81
# In vertex 549, color 80
# In vertex 550, color 97
# In vertex 551, color 99
# In vertex 552, color 96
# In vertex 553, color 65
# In vertex 554, color 99
# In vertex 555, color 64
# In vertex 557, color 58
# In vertex 561, color 39
# In vertex 562, color 96
# In vertex 563, color 91
# In vertex 564, color 69
# In vertex 565, color 42
# In vertex 567, color 100
# In vertex 568, color 66
# In vertex 569, color 100
# In vertex 571, color 100
# In vertex 572, color 101
# In vertex 573, color 102
# In vertex 575, color 101
# In vertex 576, color 85
# In vertex 577, color 56
# In vertex 578, color 97
# In vertex 580, color 103
# In vertex 581, color 104
# In vertex 583, color 95
# In vertex 584, color 80
# In vertex 585, color 86
# In vertex 587, color 103
# In vertex 588, color 36
# In vertex 590, color 105
# In vertex 591, color 103
# In vertex 592, color 98
# In vertex 593, color 106
# In vertex 594, color 107
# In vertex 595, color 105
# In vertex 597, color 104
# In vertex 598, color 98
# In vertex 599, color 102
# In vertex 601, color 101
# In vertex 602, color 104
# In vertex 604, color 106
# In vertex 605, color 105
# In vertex 610, color 49
# In vertex 612, color 95
# In vertex 613, color 2
# In vertex 614, color 84
# In vertex 615, color 90
# In vertex 616, color 99
# In vertex 617, color 108
# In vertex 618, color 108
# In vertex 619, color 102
# In vertex 620, color 107
# In vertex 621, color 100
# In vertex 622, color 46
# In vertex 624, color 93
# In vertex 626, color 51
# In vertex 627, color 92
# In vertex 628, color 106
# In vertex 629, color 109
# In vertex 630, color 110
# In vertex 631, color 107
# In vertex 632, color 105
# In vertex 634, color 87
# In vertex 636, color 101
# In vertex 637, color 106
# In vertex 638, color 111
# In vertex 640, color 112
# In vertex 641, color 108
# In vertex 642, color 76
# In vertex 643, color 99
# In vertex 644, color 112
# In vertex 645, color 112
# In vertex 647, color 113
# In vertex 648, color 72
# In vertex 649, color 109
# In vertex 651, color 5
# In vertex 652, color 110
# In vertex 653, color 88
# In vertex 655, color 113
# In vertex 657, color 79
# In vertex 658, color 84
# In vertex 659, color 40
# In vertex 660, color 53
# In vertex 661, color 112
# In vertex 662, color 113
# In vertex 664, color 104
# In vertex 665, color 107
# In vertex 666, color 96
# In vertex 669, color 111
# In vertex 670, color 110
# In vertex 671, color 112
# In vertex 672, color 85
# In vertex 673, color 114
# In vertex 676, color 85
# In vertex 678, color 104
# In vertex 681, color 41
# In vertex 683, color 21
# In vertex 684, color 115
# In vertex 685, color 114
# In vertex 686, color 33
# In vertex 687, color 116
# In vertex 688, color 117
# In vertex 689, color 118
# In vertex 690, color 117
# In vertex 691, color 59
# In vertex 692, color 3
# In vertex 693, color 105
# In vertex 694, color 119
# In vertex 695, color 67
# In vertex 697, color 118
# In vertex 698, color 115
# In vertex 699, color 117
# In vertex 700, color 119
# In vertex 702, color 118
# In vertex 704, color 115
# In vertex 705, color 94
# In vertex 706, color 112
# In vertex 708, color 120
# In vertex 709, color 119
# In vertex 710, color 121
# In vertex 711, color 122
# In vertex 713, color 50
# In vertex 714, color 120
# In vertex 715, color 121
# In vertex 716, color 116
# In vertex 718, color 21
# In vertex 719, color 119
# In vertex 720, color 116
# In vertex 721, color 73
# In vertex 722, color 89
# In vertex 724, color 43
# In vertex 725, color 10
# In vertex 726, color 120
# In vertex 727, color 123
# In vertex 728, color 121
# In vertex 729, color 124
# In vertex 731, color 122
# In vertex 732, color 124
# In vertex 733, color 125
# In vertex 734, color 91
# In vertex 737, color 124
# In vertex 738, color 122
# In vertex 739, color 123
# In vertex 741, color 126
# In vertex 743, color 111
# In vertex 745, color 114
# In vertex 746, color 44
# In vertex 747, color 103
# In vertex 749, color 119
# In vertex 753, color 123
# In vertex 754, color 125
# In vertex 755, color 126
# In vertex 756, color 109
# In vertex 757, color 90
# In vertex 758, color 121
# In vertex 759, color 95
# In vertex 761, color 125
# In vertex 762, color 122
# In vertex 763, color 106
# In vertex 764, color 39
# In vertex 765, color 91
# In vertex 767, color 31
# In vertex 768, color 127
# In vertex 769, color 90
# In vertex 770, color 128
# In vertex 771, color 118
# In vertex 772, color 128
# In vertex 773, color 95
# In vertex 774, color 128
# In vertex 775, color 38
# In vertex 776, color 14
# In vertex 777, color 126
# In vertex 778, color 26
# In vertex 779, color 127
# In vertex 782, color 129
# In vertex 783, color 129
# In vertex 784, color 130
# In vertex 785, color 130
# In vertex 787, color 129
# In vertex 790, color 131
# In vertex 791, color 131
# In vertex 792, color 131
# In vertex 793, color 132
# In vertex 794, color 120
# In vertex 795, color 71
# In vertex 797, color 132
# In vertex 799, color 86
# In vertex 800, color 133
# In vertex 801, color 133
# In vertex 802, color 134
# In vertex 803, color 135
# In vertex 805, color 134
# In vertex 806, color 136
# In vertex 807, color 130
# In vertex 808, color 136
# In vertex 809, color 127
# In vertex 810, color 125
# In vertex 811, color 123
# In vertex 812, color 132
# In vertex 813, color 108
# In vertex 814, color 137
# In vertex 815, color 137
# In vertex 817, color 132
# In vertex 819, color 15
# In vertex 820, color 134
# In vertex 821, color 114
# In vertex 823, color 135
# In vertex 824, color 136
# In vertex 826, color 110
# In vertex 828, color 138
# In vertex 829, color 81
# In vertex 830, color 128
# In vertex 831, color 98
# In vertex 832, color 73
# In vertex 833, color 124
# In vertex 834, color 116
# In vertex 835, color 131
# In vertex 838, color 126
# In vertex 839, color 138
# In vertex 840, color 139
# In vertex 841, color 139
# In vertex 842, color 130
# In vertex 843, color 140
# In vertex 844, color 140
# In vertex 847, color 139
# In vertex 848, color 102
# In vertex 849, color 118
# In vertex 850, color 105
# In vertex 852, color 137
# In vertex 853, color 141
# In vertex 854, color 141
# In vertex 855, color 142
# In vertex 856, color 92
# In vertex 857, color 78
# In vertex 858, color 140
# In vertex 859, color 143
# In vertex 860, color 125
# In vertex 861, color 141
# In vertex 862, color 138
# In vertex 863, color 142
# In vertex 864, color 143
# In vertex 866, color 124
# In vertex 867, color 144
# In vertex 871, color 144
# In vertex 872, color 136
# In vertex 874, color 117
# In vertex 876, color 133
# In vertex 877, color 130
# In vertex 878, color 145
# In vertex 879, color 145
# In vertex 880, color 146
# In vertex 882, color 142
# In vertex 884, color 143
# In vertex 885, color 146
# In vertex 888, color 74
# In vertex 890, color 113
# In vertex 891, color 147
# In vertex 892, color 148
# In vertex 893, color 109
# In vertex 894, color 18
# In vertex 895, color 121
# In vertex 896, color 147
# In vertex 897, color 146
# In vertex 898, color 94
# In vertex 899, color 6
# In vertex 900, color 149
# In vertex 901, color 144
# In vertex 904, color 99
# In vertex 905, color 139
# In vertex 906, color 148
# In vertex 908, color 101
# In vertex 913, color 134
# In vertex 914, color 150
# In vertex 917, color 136
# In vertex 920, color 116
# In vertex 922, color 149
# In vertex 923, color 141
# In vertex 924, color 151
# In vertex 925, color 152
# In vertex 926, color 148
# In vertex 927, color 68
# In vertex 928, color 149
# In vertex 930, color 150
# In vertex 931, color 143
# In vertex 932, color 140
# In vertex 933, color 81
# In vertex 936, color 147
# In vertex 937, color 146
# In vertex 939, color 121
# In vertex 940, color 153
# In vertex 941, color 152
# In vertex 942, color 19
# In vertex 943, color 153
# In vertex 944, color 12
# In vertex 945, color 153
# In vertex 946, color 148
# In vertex 947, color 150
# In vertex 949, color 145
# In vertex 951, color 122
# In vertex 952, color 154
# In vertex 953, color 155
# In vertex 954, color 154
# In vertex 955, color 156
# In vertex 957, color 155
# In vertex 958, color 156
# In vertex 959, color 30
# In vertex 961, color 68
# In vertex 962, color 153
# In vertex 963, color 19
# In vertex 964, color 157
# In vertex 965, color 145
# In vertex 966, color 104
# In vertex 967, color 155
# In vertex 968, color 75
# In vertex 970, color 157
# In vertex 971, color 157
# In vertex 972, color 135
# In vertex 974, color 107
# In vertex 978, color 158
# In vertex 979, color 159
# In vertex 981, color 158
# In vertex 984, color 82
# In vertex 985, color 152
# In vertex 986, color 63
# In vertex 988, color 160
# In vertex 990, color 160
# In vertex 991, color 161
# In vertex 992, color 156
# In vertex 993, color 162
# In vertex 994, color 162
# In vertex 995, color 159
# In vertex 997, color 161
# In vertex 998, color 158
# In vertex 999, color 163
# In vertex 77, color 0
# In vertex 5, color 164
# In vertex 30, color 115
# In vertex 31, color 152
# In vertex 35, color 164
# In vertex 41, color 165
# In vertex 42, color 127
# In vertex 43, color 161
# In vertex 56, color 163
# In vertex 59, color 159
# In vertex 60, color 166
# In vertex 61, color 17
# In vertex 67, color 163
# In vertex 71, color 151
# In vertex 82, color 129
# In vertex 91, color 166
# In vertex 95, color 139
# In vertex 97, color 135
# In vertex 106, color 167
# In vertex 107, color 164
# In vertex 112, color 167
# In vertex 114, color 162
# In vertex 124, color 154
# In vertex 130, color 168
# In vertex 133, color 151
# In vertex 144, color 132
# In vertex 154, color 142
# In vertex 156, color 80
# In vertex 162, color 77
# In vertex 169, color 169
# In vertex 171, color 158
# In vertex 172, color 70
# In vertex 177, color 162
# In vertex 179, color 138
# In vertex 180, color 168
# In vertex 184, color 147
# In vertex 186, color 169
# In vertex 191, color 48
# In vertex 204, color 167
# In vertex 207, color 128
# In vertex 208, color 165
# In vertex 212, color 143
# In vertex 221, color 170
# In vertex 222, color 170
# In vertex 225, color 25
# In vertex 229, color 165
# In vertex 232, color 72
# In vertex 234, color 57
# In vertex 248, color 160
# In vertex 250, color 123
# In vertex 254, color 42
# In vertex 257, color 162
# In vertex 264, color 171
# In vertex 270, color 172
# In vertex 272, color 136
# In vertex 274, color 23
# In vertex 279, color 35
# In vertex 284, color 169
# In vertex 286, color 171
# In vertex 289, color 173
# In vertex 292, color 174
# In vertex 297, color 172
# In vertex 303, color 97
# In vertex 307, color 163
# In vertex 310, color 9
# In vertex 311, color 168
# In vertex 341, color 175
# In vertex 353, color 174
# In vertex 365, color 137
# In vertex 366, color 173
# In vertex 371, color 176
# In vertex 374, color 82
# In vertex 385, color 170
# In vertex 388, color 174
# In vertex 390, color 171
# In vertex 395, color 175
# In vertex 400, color 177
# In vertex 405, color 167
# In vertex 412, color 149
# In vertex 416, color 168
# In vertex 421, color 100
# In vertex 430, color 173
# In vertex 440, color 57
# In vertex 444, color 146
# In vertex 454, color 177
# In vertex 460, color 176
# In vertex 462, color 55
# In vertex 463, color 165
# In vertex 470, color 178
# In vertex 471, color 129
# In vertex 474, color 140
# In vertex 485, color 178
# In vertex 497, color 11
# In vertex 501, color 144
# In vertex 509, color 172
# In vertex 512, color 68
# In vertex 513, color 176
# In vertex 515, color 172
# In vertex 517, color 140
# In vertex 518, color 170
# In vertex 520, color 177
# In vertex 531, color 149
# In vertex 535, color 160
# In vertex 537, color 10
# In vertex 538, color 151
# In vertex 539, color 161
# In vertex 556, color 133
# In vertex 558, color 115
# In vertex 559, color 179
# In vertex 560, color 179
# In vertex 566, color 180
# In vertex 570, color 178
# In vertex 574, color 171
# In vertex 586, color 181
# In vertex 589, color 182
# In vertex 603, color 114
# In vertex 606, color 136
# In vertex 607, color 112
# In vertex 608, color 92
# In vertex 609, color 181
# In vertex 611, color 169
# In vertex 623, color 179
# In vertex 625, color 180
# In vertex 633, color 153
# In vertex 635, color 168
# In vertex 646, color 183
# In vertex 650, color 177
# In vertex 656, color 174
# In vertex 663, color 127
# In vertex 667, color 180
# In vertex 668, color 183
# In vertex 674, color 182
# In vertex 675, color 137
# In vertex 677, color 184
# In vertex 679, color 184
# In vertex 680, color 185
# In vertex 682, color 177
# In vertex 696, color 175
# In vertex 701, color 185
# In vertex 703, color 156
# In vertex 707, color 47
# In vertex 712, color 49
# In vertex 717, color 178
# In vertex 723, color 158
# In vertex 730, color 183
# In vertex 735, color 66
# In vertex 736, color 54
# In vertex 740, color 166
# In vertex 742, color 184
# In vertex 748, color 162
# In vertex 750, color 184
# In vertex 751, color 186
# In vertex 760, color 157
# In vertex 766, color 186
# In vertex 780, color 148
# In vertex 786, color 100
# In vertex 789, color 187
# In vertex 798, color 187
# In vertex 827, color 59
# In vertex 836, color 88
# In vertex 837, color 137
# In vertex 845, color 188
# In vertex 846, color 188
# In vertex 851, color 120
# In vertex 865, color 102
# In vertex 868, color 187
# In vertex 873, color 167
# In vertex 875, color 189
# In vertex 881, color 186
# In vertex 883, color 179
# In vertex 886, color 188
# In vertex 887, color 189
# In vertex 889, color 189
# In vertex 903, color 185
# In vertex 907, color 178
# In vertex 909, color 89
# In vertex 910, color 61
# In vertex 911, color 109
# In vertex 912, color 189
# In vertex 915, color 175
# In vertex 916, color 106
# In vertex 918, color 190
# In vertex 919, color 155
# In vertex 934, color 8
# In vertex 935, color 191
# In vertex 938, color 185
# In vertex 948, color 34
# In vertex 960, color 151
# In vertex 969, color 190
# In vertex 973, color 17
# In vertex 976, color 192
# In vertex 980, color 192
# In vertex 982, color 190
# In vertex 983, color 193
# In vertex 996, color 185
# In vertex 6, color 0
# In vertex 109, color 71
# In vertex 127, color 192
# In vertex 145, color 169
# In vertex 188, color 193
# In vertex 218, color 173
# In vertex 219, color 193
# In vertex 228, color 186
# In vertex 298, color 131
# In vertex 317, color 51
# In vertex 323, color 181
# In vertex 324, color 31
# In vertex 342, color 134
# In vertex 381, color 142
# In vertex 384, color 194
# In vertex 398, color 195
# In vertex 413, color 185
# In vertex 461, color 194
# In vertex 482, color 104
# In vertex 511, color 195
# In vertex 514, color 196
# In vertex 532, color 196
# In vertex 582, color 195
# In vertex 596, color 182
# In vertex 600, color 154
# In vertex 639, color 150
# In vertex 654, color 197
# In vertex 744, color 197
# In vertex 752, color 160
# In vertex 781, color 191
# In vertex 788, color 196
# In vertex 804, color 197
# In vertex 818, color 191
# In vertex 822, color 198
# In vertex 825, color 199
# In vertex 869, color 194
# In vertex 902, color 24
# In vertex 921, color 176
# In vertex 950, color 194
# In vertex 956, color 192
# In vertex 977, color 150
# In vertex 987, color 200
# In vertex 870, color 0
# In vertex 62, color 200
# In vertex 78, color 198
# In vertex 125, color 199
# In vertex 148, color 201
# In vertex 158, color 201
# In vertex 213, color 173
# In vertex 302, color 166
# In vertex 516, color 60
# In vertex 522, color 202
# In vertex 530, color 202
# In vertex 929, color 200
# In vertex 975, color 199
# In vertex 989, color 32
# In vertex 44, color 0
# In vertex 452, color 154
# In vertex 796, color 164
# In vertex 816, color 0
# In vertex 344, color 165
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-8486591da3bc> in <module>()
#       3     input_data = input_data_file.read()
#       4
# ----> 5 output, vertex_colors, color_frequency = solve_it(input_data)
#       6 print('\n\nVertex colors\n', vertex_colors)
#       7 print('\n\nColors frequence\n', color_frequency)
#
# <ipython-input-32-61e4f5325a31> in solve_it(input_data)
#      22     print('---------------Start graph coloring ------------------')
#      23     num_colors, solution, vertices, color_frequency = graph_coloring(graph.vertices)
# ---> 24     vertex_colors = [(v.index, v.color) for v in vertices]
#      25     #print('Vertex color', [(v.index, v.color) for v in vertices])
#      26
#
# <ipython-input-32-61e4f5325a31> in <listcomp>(.0)
#      22     print('---------------Start graph coloring ------------------')
#      23     num_colors, solution, vertices, color_frequency = graph_coloring(graph.vertices)
# ---> 24     vertex_colors = [(v.index, v.color) for v in vertices]
#      25     #print('Vertex color', [(v.index, v.color) for v in vertices])
#      26
#
# AttributeError: 'int' object has no attribute 'index'

# %%
data_folder = 'C:/D/coursera/discrete_opt/coloring/data'
data_files = None
for dirpath, dirnames, filenames in os.walk(data_folder):
    data_files = [os.path.join(dirpath, fname) for fname in filenames if fname[:2] == 'gc' and fname[-3:] != 'txt'\
                 and fname[-3:] != 'put']
filepaths = list(reversed(data_files))

logfilename = os.path.join(data_folder, 'output.txt')
with open(logfilename, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    
    for filename in filepaths:
        with open(filename, 'r') as input_data_file:
            input_data = input_data_file.read()
        print('Input filename: ', os.path.split(filename)[-1])
        output = solve_it(input_data)
        results = output.split('\n')
        writer.writerow(results[0])
        print(output)
# Out:
# Input filename:  gc_70_9
# 34 0
# 1 2 1 3 0 4 5 3 2 6 31 7 5 8 9 9 10 1 5 11 12 11 13 14 15 4 12 16 15 14 17 18 6 19 20 21 13 18 21 22 23 24 8 25 6 19 20 26 27 22 17 25 10 16 26 27 24 28 29 30 6 31 32 13 2 25 32 33 31 0
# Input filename:  gc_70_7
# 23 0
# 15 1 1 2 2 16 3 4 0 3 5 4 6 7 5 0 5 6 20 8 7 9 7 10 16 2 10 8 11 8 18 2 9 4 21 17 1 0 10 11 3 12 13 14 12 1 8 19 3 11 15 15 0 12 13 6 16 16 5 22 17 17 14 9 18 17 13 19 9 16
# Input filename:  gc_70_5
# 15 0
# 1 1 12 2 1 3 0 2 10 2 14 1 3 2 3 2 2 4 0 4 5 5 7 2 3 5 6 4 7 4 8 8 3 4 0 5 8 0 6 8 9 8 9 4 10 8 3 3 9 10 9 10 12 11 4 13 10 11 3 11 5 13 13 6 6 12 0 7 13 12
# Input filename:  gc_70_3
# 11 0
# 1 1 1 2 2 0 0 1 2 4 2 6 1 1 3 2 2 2 5 0 1 5 0 0 0 5 3 4 7 3 9 2 1 3 8 5 6 0 3 0 0 3 5 0 4 2 4 7 3 4 5 4 7 3 8 9 9 1 5 2 2 5 4 6 8 5 0 4 6 10
# Input filename:  gc_70_1
# 5 0
# 3 1 0 1 3 1 0 2 1 2 1 0 2 1 0 1 1 0 0 2 0 1 2 1 1 1 0 0 0 1 0 0 0 1 2 2 4 2 1 0 1 2 2 4 1 1 0 2 0 0 4 3 0 2 2 2 3 3 1 0 1 1 1 2 0 3 0 2 0 1
# Input filename:  gc_50_9
# 25 0
# 1 24 2 3 4 1 2 5 2 6 7 5 4 8 9 10 7 9 11 8 4 6 12 13 5 8 14 13 0 11 15 16 17 10 12 16 18 19 17 20 15 17 0 1 18 21 22 9 23 19
# Input filename:  gc_50_7
# 18 0
 32 24 18 1 24 16 27 12 0 1 3 1 17 2 2 16 16 3 24 2 2 9 25 7 6 18 8 23 5 5 0 14 8 11 22 6 33 21 8 5 16 11 15 28 11 16 1 6 25 12 3 19 12 3 18 29 8 4 24 16 27 5 3 11 27 4 5 23 6 13 25 27 12 24 16 16 19 29 10 25 25 19 4 1 19 11 11 19 13 5 25 26 11 12 5 32 16 16 4 15 22 16 8 2 16 6 5 9 31 33 5 5 9 28 23 26 25 32 3 19 16 26 29 2 32 29 21 16 14 31 26 0 5 9 15 8 4 24 2 8 10 12 19 29 25 3 33 0 0 2 25 15 7 18 23 24 1 0 0 19 8 6 29 8 29 9 16 11 29 28 12 26 27 5 8 18 25 9 16 21 12 17 1 32 17 9 30 9 12 0 27 21 11 22 11 18 28 1 21 26 0 0 10 6 2 8 10 5 0 31 6 29 2 14 26 27 10 7 17 10 17 28 10 4 3 24 18 12 32 1 32 20 17 10 4 18 16 21 12 13 3 9 10 18 24 17 11 1 33 8 22 11 4 18 19 23 4 0 27 9 5 1 1 16 32 9 16 1 13 17 16 22 16 17 32 12 17 24 22 18 4 26 1 16 13 7 21 16 20 3 13 13 32 20 30 33 28 26 12 15 5 10 32 28 13 24 31 10 7 26 26 24 4 17 18 24 3 6 19 20 12 15 16 3 8 24 17 32 20 17 19 11 32 17 28 26 4 0 16 33 20 2 29 19 17 16 17 8 14 27 25 8 28 11 21 0 31 4 25 8 22 16 3 13 17 20 7 3 22 17 17 31 29 21 7 26 33 4 11 12 15 5 27 16 8 33 25 3 13 17 20 19 12 8 27 5 26 10 8 9 0 8 30 17 8 6 24 30 13 30 7 8 11 0 14 11 19 10 21 17 19 20 1 27 15 18 16 13 0 4 19 17 32 9 17 17 2 6 14 10 5 11 20 27 17 1 12 23 8 11 20 12 17 20 12 17 8 0 21 8 21 11 4 32 29 27 4 25 7 19 30 29 14 5 9 20 28 0 2 18 18 23 10 5 0 20 12 22 28 24 6 15 22 31 9 6 6 21 8 12 4 27 28

# %%
def graph_coloring(vertices, vertex_info):
    
    explored = set()
    colors = set()
    heapq.heapify(vertex_info)
    print('Original vertices\n', vertices)
    print('Sorted vertex info\n', vertex_info)
    
    lower_bound, upper_bound = vertex_info[0].degree, len(vertex_info)
    print('Lower c bound %d, higher bound %d ' % (lower_bound, upper_bound))
    
    while vertex_info:
        vinfo = heapq.heappop(vertex_info)
        index = vinfo.index
        
        if index in explored: continue
            
        if not vertices[index].color:
            # select color
            color = get_color(colors, lower_bound, upper_bound)
            # set color
            colors.add(color)
            vertices[index].color = color   
            print('New color %d' % color)
            # mark vertex as explored
            explored.add(index)
            
        for child in vertices[index].child_indices:
            # check child nodes
            if not vertices[child].color:
                # select color
                color = get_color(colors, lower_bound, upper_bound)
                # set color
                vertices[child].color = color
                colors.add(color)
                print('New color to child %d' % color)
                # mark as visited
                explored.add(child) 
            else:
                print('Parent node %d, parent color %d, child index %d, child color %d' % (index, vertices[index].color,
                    child, vertices[child].color))
        print('Explored node indices ', explored)
        print('Used colors ', colors)
